# %% [markdown]
# # Steam Data Analysis

# %% [markdown]
# # Data Cleaning
#
# ## Introduction
#
# Thanks to the data gathering, we now have two separate csv files:
#
# * `steamspy_appid.csv`: Full request to Steam Spy, for all available IDs (9 February 2022)
# * `steam_app_data.csv`: Full App Info from the Steam Storefront related to the previous IDs (8 February 2022)
#
# Almost all the data necessary for the analysis should be at the `steam_app_data.csv`. However, in `steamspy_appid.csv` we have additional information which might be very useful:
#
# * Positive Reviews (count)
# * Negative Reviews (count)
# * Average and Medians of Concurrent Players (several columns)
# * Peak Concurrent Players (ccu column)
# * Owners estimate, by using Steam Spy algorithm (wide ranges)
# * Tags (list)
#
# That is why we should consolidate both datasets in only one dataframe for our analysis. After all, the information is all observations about unique App Games from Steam. Also, we need to carefully check if there is any missing data, or data that might not be consistent as the Steam Storefront has been around for quite some years, and there might be different information in older apps, or newer apps might have less information... It is also quite probable that some columns have duplicated values (such as developers that are the same with multiple names)...
#
# It is also good to note that we also downloaded separately the metadata from the steam reviews and stored it in `steamreviews_data.csv`. We did this after noticing discrepancies in the number of reviews between the total in Steam Store, and the numbers in Steam Spy. Here we have the exact numbers and also the rating showed at Steam, so it will be probably used as baseline for this information.
#
# We will probably need to do the cleaning in two big steps, first any cleaning prior to merge the two dataframes, and then the final cleaning after inspecting the joined database. This makes sense as we will have more complete data after merging.
#
# Let us proceed with cleaning and joining, and that will allow us to do a good analysis.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time
import re

# third-party imports
import numpy as np
import seaborn as sns
import pandas as pd
import requests
import plotly.express as px
import matplotlib.pyplot as plt

# %%
spy = pd.read_csv("../data/download/steamspy_data.csv")
store = pd.read_csv("../data/download/steam_app_data.csv")
# Out:
# C:\Users\daydr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## Assessment - Pre-merge
#
# Later, we will do a full Exploratory Data Analysis, that will be focused on gaining insights. Here however we will focus just on an Assessment to detect Data Quality and Tidiness issues.
#
# We will look at any possible issues within the data, and make a list of necessary changes.
#
# After that, we will define some functions to make these changes and clean, join both databases. That way, if we need to gather again and clean the data later, we can do the whole process with few if any changes.
#
# Then we will clean again the data, after joining, as some columns will be merged.
#
# Let's start with a summary of how many data we have from each dataset, and what columns are available.

# %%
spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63968 entries, 0 to 63967
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            63968 non-null  int64
#  1   name             63865 non-null  object
#  2   developer        56705 non-null  object
#  3   publisher        56740 non-null  object
#  4   score_rank       48 non-null     float64
#  5   positive         63968 non-null  int64
#  6   negative         63968 non-null  int64
#  7   userscore        63968 non-null  int64
#  8   owners           63968 non-null  object
#  9   average_forever  63968 non-null  int64
#  10  average_2weeks   63968 non-null  int64
#  11  median_forever   63968 non-null  int64
#  12  median_2weeks    63968 non-null  int64
#  13  price            56854 non-null  float64
#  14  initialprice     56856 non-null  float64
#  15  discount         56856 non-null  float64
#  16  languages        56814 non-null  object
#  17  genre            56653 non-null  object
#  18  ccu              63968 non-null  int64
#  19  tags             63968 non-null  object
# dtypes: float64(4), int64(9), object(7)
# memory usage: 9.8+ MB

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66803 entries, 0 to 66802
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     66655 non-null  object
#  1   name                     66803 non-null  object
#  2   steam_appid              66803 non-null  int64
#  3   required_age             66655 non-null  object
#  4   is_free                  66655 non-null  object
#  5   controller_support       14422 non-null  object
#  6   dlc                      9342 non-null   object
#  7   detailed_description     66587 non-null  object
#  8   about_the_game           66585 non-null  object
#  9   short_description        66593 non-null  object
#  10  fullgame                 0 non-null      float64
#  11  supported_languages      66599 non-null  object
#  12  header_image             66655 non-null  object
#  13  website                  36119 non-null  object
#  14  pc_requirements          66655 non-null  object
#  15  mac_requirements         66655 non-null  object
#  16  linux_requirements       66655 non-null  object
#  17  legal_notice             19502 non-null  object
#  18  drm_notice               278 non-null    object
#  19  ext_user_account_notice  1124 non-null   object
#  20  developers               66495 non-null  object
#  21  publishers               66655 non-null  object
#  22  demos                    6009 non-null   object
#  23  price_overview           47350 non-null  object
#  24  packages                 47963 non-null  object
#  25  package_groups           66655 non-null  object
#  26  platforms                66655 non-null  object
#  27  metacritic               3726 non-null   object
#  28  reviews                  8872 non-null   object
#  29  categories               65699 non-null  object
#  30  genres                   66526 non-null  object
#  31  screenshots              66533 non-null  object
#  32  movies                   61673 non-null  object
#  33  recommendations          11674 non-null  object
#  34  achievements             30294 non-null  object
#  35  release_date             66655 non-null  object
#  36  support_info             66655 non-null  object
#  37  background               66547 non-null  object
#  38  content_descriptors      66655 non-null  object
# dtypes: float64(1), int64(1), object(37)
# memory usage: 19.9+ MB

# %% [markdown]
# Out of 65000 unique app ids, in Steam Spy we have non null data for almost all of them, while in the steam database there is missing information for a lot of columns.
#
# However for more than half of them there are at least more than 65k values. Even in those cases, we have to check why we have missing information - there may be valid reasons. One approach might be to just keep those games out of the analysis (i.e if they are very marginal games with few or no reviews, with a lot of missing data, or not games at all), but it might be interesting to check what they are first.
#
# There are clearly columns in the steam database with "optional" information, such us `dlc`, `controller_support`, `demos`, `reviews`, `metacritic`, `recommendations`, `achievements`, `drm_notice`, `ext_user_account_notice`. Some of them we will have to check, as probably they are null if the game does not have that feature at all, and in the case of external reviews/recommendations/metacritic, it is possible the game does have them but it was not included in the steam storefront (for instance, if the game had mostly negative reviews).
#
# Another issue that might be an opportunity, is that we have some overlap between Steam Spy and Steam Store data... we have the names, developers, publishers and price data available in both datasets, and at first glance it seems Steam Store has more data. But we should check them and consolidate prior to further cleaning.
#
# `store` vs `spy`
#
# `name` vs `name`
#
# `price_overview` vs `price`, `initial_price`, `discount`
#
# `genres` vs `genre`
#
# `developers` vs `developer`
#
# `publishers` vs `publisher`
#
# `supported_languages` vs `languages`
#
# Let's start to check out really how many games we have with important missing information, and decide if we should just drop them.

# %% [markdown]
# ### Unique IDs
#
# We just said the app ids are unique... But we should check if we have duplicated app ids in our dataframes. We used an iterative process, and it could be possible that some ids when requested redirect us to a new id. This has been observed trying to access directly in the Steam Store page with some of the "missing" ids. For instance, different versions of Guild Wars 2 all lead us to a unique store page on Steam, as the old versions do not exist anymore.

# %%
spy["appid"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicate ids for Steam Spy, which is great news!. It might make sense due to the reasoning above - Steam Spy just keeps the old records as well.

# %%
store["steam_appid"].duplicated().sum()
# Out:
# 0

# %%
store.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Well, it seems we were succesful rewriting the request functions to get only new ids and purge any duplicates! We can follow into just cleaning the database with the meaningful data.

# %% [markdown]
# ### Name

# %%
spy[spy["name"].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 1094 to 63967
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   appid            103 non-null    int64
#  1   name             0 non-null      object
#  2   developer        7 non-null      object
#  3   publisher        7 non-null      object
#  4   score_rank       0 non-null      float64
#  5   positive         103 non-null    int64
#  6   negative         103 non-null    int64
#  7   userscore        103 non-null    int64
#  8   owners           103 non-null    object
#  9   average_forever  103 non-null    int64
#  10  average_2weeks   103 non-null    int64
#  11  median_forever   103 non-null    int64
#  12  median_2weeks    103 non-null    int64
#  13  price            11 non-null     float64
#  14  initialprice     11 non-null     float64
#  15  discount         11 non-null     float64
#  16  languages        9 non-null      object
#  17  genre            8 non-null      object
#  18  ccu              103 non-null    int64
#  19  tags             103 non-null    object
# dtypes: float64(4), int64(9), object(7)
# memory usage: 16.9+ KB

# %%
store[store["name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [type, name, steam_appid, required_age, is_free, controller_support, dlc, detailed_description, about_the_game, short_description, fullgame, supported_languages, header_image, website, pc_requirements, mac_requirements, linux_requirements, legal_notice, drm_notice, ext_user_account_notice, developers, publishers, demos, price_overview, packages, package_groups, platforms, metacritic, reviews, categories, genres, screenshots, movies, recommendations, achievements, release_date, support_info, background, content_descriptors]
# Index: []
#
# [0 rows x 39 columns]

# %%
store[store["name"].isnull()]["steam_appid"]
# Out:
# Series([], Name: steam_appid, dtype: int64)

# %%
spy[spy["name"].isnull()]["appid"]
# Out:
# 1094       63970
# 3918      315210
# 6892      396420
# 9074      460250
# 13110     576960
#           ...
# 63961    1899160
# 63962    1899200
# 63963    1899430
# 63965    1900820
# 63967    1902210
# Name: appid, Length: 103, dtype: int64

# %% [markdown]
# #### Name overview
# Analyzing these briefly (viewing them manually at Steam), we see that there are 2 root causes for blank games in the Steam Spy database. Either the game uses some sort of emoticon in the game, or the game has been deleted from steam. Let's do a crosscheck between them.

# %%
store[store["steam_appid"].isin(spy[spy["name"].isnull()]["appid"].values)]
# Out:
#        type                                    name  steam_appid required_age  \
# 4835   game                              🐰RabbiruN🐰       806160            0
# 4837   game                      🚀👾Absolute Blue 👾🚀       806220            0
# 9800   game                   🚀 Human Rocket Person       965340            0
# 13052  game                     👾 Foreign Frugglers      1071920            0
# 39655  game                               🔴 Circles       460250          0.0
# ...     ...                                     ...          ...          ...
# 63957  game                              Puzzle Mix      1899160          0.0
# 63958  game                              Bombardier      1899200          0.0
# 63959  game  VEREDA - Mystery Escape Room Adventure      1899430          0.0
# 63961  game                          Mighty Castles      1900820          0.0
# 63963  game        Hidden Floating City Top-Down 3D      1902210          0.0
#
#       is_free controller_support       dlc  \
# 4835    False                NaN  [835480]
# 4837    False                NaN  [810280]
# 9800    False               full       NaN
# 13052   False               full       NaN
# 39655   False                NaN       NaN
# ...       ...                ...       ...
# 63957   False                NaN       NaN
# 63958   False                NaN       NaN
# 63959   False                NaN       NaN
# 63961   False                NaN       NaN
# 63963   False                NaN       NaN
#
#                                     detailed_description  \
# 4835   Rabbirun is a casual endless running game wher...
# 4837   Note: I am currently working on a new ambitiou...
# 9800   <img src="https://cdn.akamai.steamstatic.com/s...
# 13052  The Fruggle is real!<br />\r\nEight brave surv...
# 39655  Circles is a unique, intuitive puzzle game whe...
# ...                                                  ...
# 63957  We offer you a puzzle game. There are 70 puzzl...
# 63958  Bombardier is a 2 - 4 local multiplayer game o...
# 63959  <h2 class="bb_tag"> VEREDA - Mystery Escape Ro...
# 63961  Mighty Castles is a Tower Defense game with RP...
# 63963  Find the objects that are hidden on the map.<b...
#
#                                           about_the_game  \
# 4835   Rabbirun is a casual endless running game wher...
# 4837   Note: I am currently working on a new ambitiou...
# 9800   <img src="https://cdn.akamai.steamstatic.com/s...
# 13052  The Fruggle is real!<br />\r\nEight brave surv...
# 39655  Circles is a unique, intuitive puzzle game whe...
# ...                                                  ...
# 63957  We offer you a puzzle game. There are 70 puzzl...
# 63958  Bombardier is a 2 - 4 local multiplayer game o...
# 63959  <h2 class="bb_tag"> VEREDA - Mystery Escape Ro...
# 63961  Mighty Castles is a Tower Defense game with RP...
# 63963  Find the objects that are hidden on the map.<b...
#
#                                        short_description  ...  \
# 4835   Rabbirun is a casual endless running game wher...  ...
# 4837   Sidescrolling Shoot’em’up that will transport ...  ...
# 9800   Human Rocket Person is an absurd &amp; fun pla...  ...
# 13052  The Fruggle is real! Four brave survivors need...  ...
# 39655  Circles is an abstract puzzle game that takes ...  ...
# ...                                                  ...  ...
# 63957  We offer you a puzzle game. The meaning of the...  ...
# 63958  Bombardier is a quick and chaotic online multi...  ...
# 63959  Vereda is a 3d escape room puzzle adventure. P...  ...
# 63961  Mighty Castles is a Tower Defense game with RP...  ...
# 63963       Find the objects that are hidden on the map.  ...
#
#                                               categories  \
# 4835   [{'id': 2, 'description': 'Single-player'}, {'...
# 4837   [{'id': 2, 'description': 'Single-player'}, {'...
# 9800   [{'id': 2, 'description': 'Single-player'}, {'...
# 13052  [{'id': 2, 'description': 'Single-player'}, {'...
# 39655  [{'id': 2, 'description': 'Single-player'}, {'...
# ...                                                  ...
# 63957  [{'id': 2, 'description': 'Single-player'}, {'...
# 63958  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 63959        [{'id': 2, 'description': 'Single-player'}]
# 63961        [{'id': 2, 'description': 'Single-player'}]
# 63963  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres  \
# 4835   [{'id': '1', 'description': 'Action'}, {'id': ...
# 4837   [{'id': '1', 'description': 'Action'}, {'id': ...
# 9800   [{'id': '1', 'description': 'Action'}, {'id': ...
# 13052  [{'id': '1', 'description': 'Action'}, {'id': ...
# 39655  [{'id': '4', 'description': 'Casual'}, {'id': ...
# ...                                                  ...
# 63957  [{'id': '25', 'description': 'Adventure'}, {'i...
# 63958  [{'id': '1', 'description': 'Action'}, {'id': ...
# 63959  [{'id': '25', 'description': 'Adventure'}, {'i...
# 63961                [{'id': '3', 'description': 'RPG'}]
# 63963  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                              screenshots  \
# 4835   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4837   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 9800   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 13052  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 39655  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ...                                                  ...
# 63957  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 63958  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 63959  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 63961  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 63963  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies recommendations  \
# 4835   [{'id': 256711130, 'name': 'Rabbirun Trailer',...             NaN
# 4837   [{'id': 256708652, 'name': 'Gameplay Trailer',...             NaN
# 9800   [{'id': 256733564, 'name': 'Human Rocket Perso...             NaN
# 13052  [{'id': 256776726, 'name': 'Gameplay Trailer',...             NaN
# 39655  [{'id': 256662578, 'name': 'Circles Trailer', ...             NaN
# ...                                                  ...             ...
# 63957  [{'id': 256872607, 'name': 'robot87', 'thumbna...             NaN
# 63958  [{'id': 256872169, 'name': 'ClusterTruck9000',...             NaN
# 63959  [{'id': 256872306, 'name': 'Vereda Trailer', '...             NaN
# 63961  [{'id': 256872374, 'name': '1', 'thumbnail': '...             NaN
# 63963  [{'id': 256872545, 'name': '1', 'thumbnail': '...             NaN
#
#                                             achievements  \
# 4835   {'total': 156, 'highlighted': [{'name': '', 'p...
# 4837                                                 NaN
# 9800   {'total': 22, 'highlighted': [{'name': 'Apple ...
# 13052  {'total': 16, 'highlighted': [{'name': 'Ghetto...
# 39655  {'total': 8, 'highlighted': [{'name': '•', 'pa...
# ...                                                  ...
# 63957                                                NaN
# 63958                                                NaN
# 63959                                                NaN
# 63961                                                NaN
# 63963                                                NaN
#
#                                          release_date  \
# 4835   {'coming_soon': False, 'date': '27 Mar, 2018'}
# 4837   {'coming_soon': False, 'date': '21 Apr, 2018'}
# 9800   {'coming_soon': False, 'date': '14 Nov, 2018'}
# 13052  {'coming_soon': False, 'date': '26 Jun, 2019'}
# 39655  {'coming_soon': False, 'date': '17 Feb, 2017'}
# ...                                               ...
# 63957   {'coming_soon': True, 'date': '18 Feb, 2022'}
# 63958       {'coming_soon': True, 'date': 'Oct 2022'}
# 63959    {'coming_soon': True, 'date': '9 Mar, 2022'}
# 63961   {'coming_soon': True, 'date': '21 Feb, 2022'}
# 63963   {'coming_soon': True, 'date': '22 Feb, 2022'}
#
#                                             support_info  \
# 4835   {'url': 'http://palenogames.ru', 'email': 'con...
# 4837   {'url': 'http://intermediaware.com', 'email': ...
# 9800      {'url': '', 'email': 'feedback@2ndstudio.com'}
# 13052     {'url': '', 'email': 'games.ultimo@gmail.com'}
# 39655  {'url': '', 'email': 'support@illusivegames.com'}
# ...                                                  ...
# 63957          {'url': '', 'email': 'robot72@yandex.ru'}
# 63958    {'url': '', 'email': 'info@studiosquidinc.com'}
# 63959  {'url': 'https://www.m9games.co.uk/Contact/', ...
# 63961       {'url': '', 'email': '21eremin21@gmail.com'}
# 63963  {'url': 'http://hede.ru/', 'email': 'info@hede...
#
#                                               background  \
# 4835   https://cdn.akamai.steamstatic.com/steam/apps/...
# 4837   https://cdn.akamai.steamstatic.com/steam/apps/...
# 9800   https://cdn.akamai.steamstatic.com/steam/apps/...
# 13052  https://cdn.akamai.steamstatic.com/steam/apps/...
# 39655  https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                  ...
# 63957  https://cdn.akamai.steamstatic.com/steam/apps/...
# 63958  https://cdn.akamai.steamstatic.com/steam/apps/...
# 63959  https://cdn.akamai.steamstatic.com/steam/apps/...
# 63961  https://cdn.akamai.steamstatic.com/steam/apps/...
# 63963  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                      content_descriptors
# 4835                          {'ids': [], 'notes': None}
# 4837                          {'ids': [], 'notes': None}
# 9800   {'ids': [1, 5], 'notes': 'This game contains f...
# 13052                         {'ids': [], 'notes': None}
# 39655                         {'ids': [], 'notes': None}
# ...                                                  ...
# 63957                         {'ids': [], 'notes': None}
# 63958                         {'ids': [], 'notes': None}
# 63959                         {'ids': [], 'notes': None}
# 63961                         {'ids': [], 'notes': None}
# 63963                         {'ids': [], 'notes': None}
#
# [96 rows x 39 columns]

# %% [markdown]
# #### Are there any duplicate names?

# %%
store["name"].value_counts()
# Out:
# Alone                        5
# Lost                         4
# Bounce                       4
# Fireflies                    4
# Escape                       4
#                             ..
# Fire Guild                   1
# The Tragedy of little Joy    1
# 探灵警探                         1
# Lucen                        1
# Profectus                    1
# Name: name, Length: 66414, dtype: int64

# %%
store[store["name"]=="Alone"]
# Out:
#        type   name  steam_appid required_age is_free controller_support  dlc  \
# 5823   game  Alone       837930            0   False                NaN  NaN
# 6981   game  Alone       871870            0   False                NaN  NaN
# 27986  game  Alone      1640090            0   False               full  NaN
# 30153  game  Alone      1789460          0.0   False                NaN  NaN
# 59082  game  Alone      1686490            0   False                NaN  NaN
#
#                                     detailed_description  \
# 5823   <h2 class="bb_tag"><strong>The Sun Falls Behin...
# 6981   You wake up finding yourself alone in your cam...
# 27986  Alone is a <strong>precision platformer</stron...
# 30153  Alone is all about surviving in a deserted isl...
# 59082  <img src="https://cdn.akamai.steamstatic.com/s...
#
#                                           about_the_game  \
# 5823   <h2 class="bb_tag"><strong>The Sun Falls Behin...
# 6981   You wake up finding yourself alone in your cam...
# 27986  Alone is a <strong>precision platformer</stron...
# 30153  Alone is all about surviving in a deserted isl...
# 59082  <img src="https://cdn.akamai.steamstatic.com/s...
#
#                                        short_description  ...  \
# 5823   Alone is a Pixelated Survival Game set in the ...  ...
# 6981   Alone is a 3D Puzzle Sidescroller with heavy f...  ...
# 27986  An epic, unforgiving platformer in which you n...  ...
# 30153  An open world survival crafting game based mor...  ...
# 59082  Alone is a puzzle platformer where you control...  ...
#
#                                               categories  \
# 5823   [{'id': 2, 'description': 'Single-player'}, {'...
# 6981   [{'id': 2, 'description': 'Single-player'}, {'...
# 27986  [{'id': 2, 'description': 'Single-player'}, {'...
# 30153        [{'id': 2, 'description': 'Single-player'}]
# 59082        [{'id': 2, 'description': 'Single-player'}]
#
#                                                   genres  \
# 5823   [{'id': '25', 'description': 'Adventure'}, {'i...
# 6981   [{'id': '25', 'description': 'Adventure'}, {'i...
# 27986  [{'id': '1', 'description': 'Action'}, {'id': ...
# 30153  [{'id': '23', 'description': 'Indie'}, {'id': ...
# 59082  [{'id': '25', 'description': 'Adventure'}, {'i...
#
#                                              screenshots  \
# 5823   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 6981   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 27986  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 30153  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 59082  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies recommendations  \
# 5823   [{'id': 256712913, 'name': 'Alone - the Only S...             NaN
# 6981   [{'id': 256717925, 'name': 'Alone Gameplay Tra...             NaN
# 27986  [{'id': 256844155, 'name': 'Alone Trailer', 't...             NaN
# 30153  [{'id': 256859195, 'name': 'Alone Trailer', 't...             NaN
# 59082  [{'id': 256847947, 'name': 'Alone - Kickstarte...             NaN
#
#                                             achievements  \
# 5823   {'total': 20, 'highlighted': [{'name': 'Frozen...
# 6981   {'total': 7, 'highlighted': [{'name': 'First o...
# 27986  {'total': 7, 'highlighted': [{'name': 'You los...
# 30153                                                NaN
# 59082                                                NaN
#
#                                          release_date  \
# 5823    {'coming_soon': False, 'date': '1 May, 2018'}
# 6981   {'coming_soon': False, 'date': '21 Jun, 2018'}
# 27986  {'coming_soon': False, 'date': '29 Jul, 2021'}
# 30153  {'coming_soon': False, 'date': '11 Nov, 2021'}
# 59082   {'coming_soon': True, 'date': '15 Sep, 2022'}
#
#                                             support_info  \
# 5823   {'url': 'https://killedpixel.wixsite.com/home'...
# 6981     {'url': '', 'email': 'avasion.alone@gmail.com'}
# 27986         {'url': '', 'email': 'Contact@AdamJN.com'}
# 30153  {'url': '', 'email': 'achillesgamestudio@gmail...
# 59082  {'url': '', 'email': 'connorwarrington27@gmail...
#
#                                               background  \
# 5823   https://cdn.akamai.steamstatic.com/steam/apps/...
# 6981   https://cdn.akamai.steamstatic.com/steam/apps/...
# 27986  https://cdn.akamai.steamstatic.com/steam/apps/...
# 30153  https://cdn.akamai.steamstatic.com/steam/apps/...
# 59082  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#               content_descriptors
# 5823   {'ids': [], 'notes': None}
# 6981   {'ids': [], 'notes': None}
# 27986  {'ids': [], 'notes': None}
# 30153  {'ids': [], 'notes': None}
# 59082  {'ids': [], 'notes': None}
#
# [5 rows x 39 columns]

# %%
store[store["name"]=="['']"]
# Out:
# Empty DataFrame
# Columns: [type, name, steam_appid, required_age, is_free, controller_support, dlc, detailed_description, about_the_game, short_description, fullgame, supported_languages, header_image, website, pc_requirements, mac_requirements, linux_requirements, legal_notice, drm_notice, ext_user_account_notice, developers, publishers, demos, price_overview, packages, package_groups, platforms, metacritic, reviews, categories, genres, screenshots, movies, recommendations, achievements, release_date, support_info, background, content_descriptors]
# Index: []
#
# [0 rows x 39 columns]

# %% [markdown]
# We have some duplicate names, which seems a bit weird, but they are really different games.

# %% [markdown]
# Just in case, let's check also for some weird names.

# %%
store[store["name"].apply(lambda x: len(x) < 6)]["name"].value_counts()
# Out:
# Alone    5
# Lost     4
# Dodge    3
# Helix    3
# Surge    3
#         ..
# 就这消消乐    1
# GNOG     1
# Gogoo    1
# 大小串串烧    1
# 灵异AE     1
# Name: name, Length: 2551, dtype: int64

# %%
store[store["name"].isin(["none","None","na","Na","False","false",0,"","invalid","Invalid"])]
# Out:
#        type  name  steam_appid required_age is_free controller_support  dlc  \
# 65991  game  none       339860          0.0   False                NaN  NaN
# 66127  game  none       385020          0.0   False                NaN  NaN
# 66173  game  none       398970          0.0   False                NaN  NaN
#
#                    detailed_description                    about_the_game  \
# 65991                               NaN                               NaN
# 66127  - discontinued - (please remove)  - discontinued - (please remove)
# 66173                               NaN                               NaN
#
#                       short_description  ...  \
# 65991                               NaN  ...
# 66127  - discontinued - (please remove)  ...
# 66173                               NaN  ...
#
#                                               categories  \
# 65991  [{'id': 2, 'description': 'Single-player'}, {'...
# 66127  [{'id': 2, 'description': 'Single-player'}, {'...
# 66173  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                   genres screenshots movies  \
# 65991  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
# 66127  [{'id': '4', 'description': 'Casual'}, {'id': ...         NaN    NaN
# 66173  [{'id': '25', 'description': 'Adventure'}, {'i...         NaN    NaN
#
#       recommendations                                       achievements  \
# 65991             NaN  {'total': 3, 'highlighted': [{'name': 'Master ...
# 66127             NaN                                                NaN
# 66173             NaN  {'total': 35, 'highlighted': [{'name': "They'v...
#
#                                          release_date  \
# 65991  {'coming_soon': False, 'date': '27 Feb, 2015'}
# 66127   {'coming_soon': False, 'date': '4 Nov, 2015'}
# 66173   {'coming_soon': False, 'date': '5 Nov, 2015'}
#
#                    support_info background         content_descriptors
# 65991  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 66127  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
# 66173  {'url': '', 'email': ''}        NaN  {'ids': [], 'notes': None}
#
# [3 rows x 39 columns]

# %% [markdown]
# #### Name cleaning decision
# All games from the store database have valid names, except those three detected above that we should clearly remove. We keep the rest of the column from store as is.
#
# * Delete the rows with name = "none"
# * When merging both dataframes, regarding column `name`, keep `name` from Steam Storefront

# %%
def cleanName(store):
    store = store[store["name"] != "none"].copy()
    return store

# %% [markdown]
# ### Developers
#
# Compared to publishers where the store dataset has no null values, we have a few missing developers. Let's check them just in case.

# %%
store[store["developers"].isnull()&~store["recommendations"].isnull()]
# Out:
#            type                                               name  \
# 2360       game                      A Hat in Time - Modding Tools
# 14129      game                               妄想破绽 Broken Delusion
# 31140      game                              Tycoon City: New York
# 31180      game                                       Crash Time 2
# 31556      game                18 Wheels of Steel: Extreme Trucker
# 32499      game                                           Patterns
# 32625      game                                     Rise of Venice
# 32653      game  Teenage Mutant Ninja Turtles™: Out of the Shadows
# 32846      game                      Rain Blood Chronicles: Mirage
# 32870      game                                    Rayman® Legends
# 32882      game                                         Anachronox
# 32883      game                       Blood Omen 2: Legacy of Kain
# 32884      game                                          Daikatana
# 32924      game                                  Deathtrap Dungeon
# 32939      game                                          Flashback
# 32968      game                 Artemis Spaceship Bridge Simulator
# 32974      game                   Sniper Elite: Nazi Zombie Army 2
# 32986      game                               1953 - KGB Unleashed
# 32994      game                                            Iesabel
# 32995      game                                 A Walk in the Dark
# 32999      game                                             Vector
# 33015      game                                        Forge Quest
# 33090      game                                         The Shivah
# 33128      game                                      Sparkle 2 Evo
# 33138      game                                           Gorky 17
# 33139      game                                      Septerra Core
# 33144      game                         World War II: Panzer Claws
# 33241      game                                           Dead Sky
# 33244      game                                       Nimble Quest
# 34449      game                                      Shallow Space
# 34718      game                                         Space Hack
# 36069      game                                           gravilon
# 37561      game                                    Secret Of Magia
# 39309      game                                         SAMOLIOTIK
# 41114      game  The Lord of the Rings: Adventure Card Game - D...
# 65749      game                                Guardians of Graxia
# 65782      game                                       Max Payne RU
# 65787      game                                            Minimum
# 65819      game          PlayClaw 5 - Game Recording and Streaming
# 65836      game                                                Vox
# 66036  hardware                                         Steam Link
#
#        steam_appid required_age is_free controller_support  \
# 2360        734880            0   False                NaN
# 14129      1108320            0   False                NaN
# 31140         9730          0.0   False                NaN
# 31180        11390          0.0   False                NaN
# 31556        33730          0.0   False                NaN
# 32499       218980          0.0   False                NaN
# 32625       227020          0.0   False                NaN
# 32653       228560          0.0   False                NaN
# 32846       240660          0.0   False                NaN
# 32870       242550          0.0   False                NaN
# 32882       242940         12.0   False                NaN
# 32883       242960         16.0   False                NaN
# 32884       242980         16.0   False                NaN
# 32924       245010         15.0   False                NaN
# 32939       245730          0.0   False                NaN
# 32968       247350          0.0   False                NaN
# 32974       247910          0.0   False                NaN
# 32986       248490          0.0   False                NaN
# 32994       248710          0.0   False                NaN
# 32995       248730          0.0   False               full
# 32999       248970          0.0   False               full
# 33015       249950          0.0   False               full
# 33090       252370          0.0   False                NaN
# 33128       253650          0.0   False               full
# 33138       253920          0.0   False                NaN
# 33139       253940          0.0   False                NaN
# 33144       254100          0.0   False                NaN
# 33241       259700          0.0   False                NaN
# 33244       259780          0.0   False               full
# 34449       305840          0.0   False                NaN
# 34718       315260          0.0   False                NaN
# 36069       355150          0.0   False                NaN
# 37561       396160          0.0   False               full
# 39309       449680          0.0   False                NaN
# 41114       509580          0.0   False                NaN
# 65749        90500          0.0   False                NaN
# 65782       210350          0.0   False                NaN
# 65787       214190          0.0   False                NaN
# 65819       237370          0.0   False                NaN
# 65836       252770          0.0   False               full
# 66036       353380          0.0   False               full
#
#                             dlc  \
# 2360                        NaN
# 14129                 [1284010]
# 31140                       NaN
# 31180                       NaN
# 31556                       NaN
# 32499                       NaN
# 32625                  [260860]
# 32653                       NaN
# 32846                       NaN
# 32870                       NaN
# 32882                       NaN
# 32883                       NaN
# 32884                       NaN
# 32924                       NaN
# 32939                       NaN
# 32968                       NaN
# 32974                       NaN
# 32986                       NaN
# 32994                       NaN
# 32995                       NaN
# 32999                       NaN
# 33015                       NaN
# 33090                       NaN
# 33128                       NaN
# 33138          [985410, 986180]
# 33139        [1026171, 1026170]
# 33144                       NaN
# 33241                       NaN
# 33244                       NaN
# 34449                       NaN
# 34718                       NaN
# 36069                       NaN
# 37561                       NaN
# 39309                  [459240]
# 41114                  [862380]
# 65749                       NaN
# 65782                       NaN
# 65787                       NaN
# 65819  [407460, 439390, 470500]
# 65836                       NaN
# 66036                       NaN
#
#                                     detailed_description  \
# 2360                                                 NaN
# 14129  <img src="https://media.st.dl.pinyuncloud.com/...
# 32999  Vector is an exciting, arcade-style game featu...
# 33015  Forge Quest is a dungeon crawling rpg set in a...
# 33090  Russell Stone is a Jewish Rabbi at a poor syna...
# 33128  Control the evolution with the touch of your f...
# 33138  November 2008. NATO intelligence services repo...
# 33139  At the very heart of Septerra lies the Core, a...
# 33144  <strong>WORLD WAR II: PANZER CLAWS [aka Frontl...
# 33241  Dead Sky takes place admist the chaos of a mys...
# 33244  Nimble Quest! Lead a conga line of heroes to g...
# 34449  Construct your fleet ship-by-ship by foraging ...
# 34718  The colony ship, Maximus, was on a routine voy...
# 36069  <strong>gravilon</strong> is an inventive, tho...
# 37561  Secret of Magia is an action RPG.<br />\r\n<br...
# 39309  SAMOLIOTIK is a stylish shoot-em-up with diffe...
# 41114  <img src="https://cdn.cloudflare.steamstatic.c...
# 65749  Guardians of Graxia takes on the form of a car...
# 65782                                                NaN
# 65787  Are you a fan of old-school twitch shooters li...
# 65819  The amazing PlayClaw video capture tool gives ...
# 65836  Vox is a voxel based, action, adventure and cr...
# 66036  <h2 class="bb_tag">Remote Play Anywhere</h2><b...
#
#                                        short_description  ...  \
# 2360                                                 NaN  ...
# 14129  《妄想破绽》是一款文字冒险（AVG）游戏，数十万字精彩原创剧情，将带给大家一段近未来架空科技...  ...
# 31140  Here's your chance to make it big in the Big A...  ...
# 31180  Crash Time 2 is an open-world combat racing ga...  ...
# 31556  You ‘da Boss! Move it better and faster while ...  ...
# 32499  Create worlds beyond your imagination in Patte...  ...
# 32625  Venice: As a young man striving for success, p...  ...
# 32653  Teenage Mutant Ninja Turtles: Out of the Shado...  ...
# 32846  Told as a “Wuxia” story, which literally means...  ...
# 32870  Michel Ancel, the celebrated creator of Rayman...  ...
# 32882  Join Sylvester &quot;Sly&quot; Boots and Stile...  ...
# 32883  Cast down from power by a mysterious warlord c...  ...
# 32884  In 2455 AD, Kage Mishima used the magical powe...  ...
# 32924  Built by a mad baron to bring notoriety to his...  ...
# 32939  20 years after the original game’s launch, Con...  ...
# 32968  Artemis is designed for anyone who watched Sta...  ...
# 32974  ** Please note: a remastered and improved edit...  ...
# 32986  Developed by Phantomery Interactive, 1953 – KG...  ...
# 32994  In the times of darkness, only the mightiest o...  ...
# 32995  In this action platformer you play as a cat, B...  ...
# 32999  Vector is an exciting, arcade-style game featu...  ...
# 33015  Forge Quest is a dungeon crawling rpg set in a...  ...
# 33090  Russell Stone is a Jewish Rabbi at a poor syna...  ...
# 33128  Control the evolution with the touch of your f...  ...
# 33138  November 2008. NATO intelligence services repo...  ...
# 33139  At the very heart of Septerra lies the Core, a...  ...
# 33144  WORLD WAR II: PANZER CLAWS [aka Frontline Atta...  ...
# 33241  Dead Sky takes place admist the chaos of a mys...  ...
# 33244  Nimble Quest! Lead a conga line of heroes to g...  ...
# 34449  Construct your Taskforce and lead your forces ...  ...
# 34718  Space Hack is a sci-fi hack and slash action R...  ...
# 36069  An inventive, thought-provoking puzzle platfor...  ...
# 37561  Secret of Magia is an action RPG. Explore a hu...  ...
# 39309  SAMOLIOTIK is a stylish shoot-em-up with diffe...  ...
# 41114  Build a deck of iconic heroes and challenge th...  ...
# 65749  Guardians of Graxia takes on the form of a car...  ...
# 65782                                                NaN  ...
# 65787  Set in a minimalistic stylized universe, Minim...  ...
# 65819  The amazing PlayClaw video capture tool gives ...  ...
# 65836  Vox is a voxel based, action, adventure and cr...  ...
# 66036  Extend your Steam gaming experience to your mo...  ...
#
#                                               categories  \
# 2360                                                 NaN
# 14129  [{'id': 2, 'description': 'Single-player'}, {'...
# 31140        [{'id': 2, 'description': 'Single-player'}]
# 31180  [{'id': 2, 'description': 'Single-player'}, {'...
# 31556        [{'id': 2, 'description': 'Single-player'}]
# 32499  [{'id': 2, 'description': 'Single-player'}, {'...
# 32625  [{'id': 2, 'description': 'Single-player'}, {'...
# 32653  [{'id': 2, 'description': 'Single-player'}, {'...
# 32846  [{'id': 2, 'description': 'Single-player'}, {'...
# 32870  [{'id': 2, 'description': 'Single-player'}, {'...
# 32882        [{'id': 2, 'description': 'Single-player'}]
# 32883        [{'id': 2, 'description': 'Single-player'}]
# 32884        [{'id': 2, 'description': 'Single-player'}]
# 32924        [{'id': 2, 'description': 'Single-player'}]
# 32939        [{'id': 2, 'description': 'Single-player'}]
# 32968  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 32974  [{'id': 2, 'description': 'Single-player'}, {'...
# 32986  [{'id': 2, 'description': 'Single-player'}, {'...
# 32994        [{'id': 2, 'description': 'Single-player'}]
# 32995  [{'id': 2, 'description': 'Single-player'}, {'...
# 32999  [{'id': 2, 'description': 'Single-player'}, {'...
# 33015  [{'id': 2, 'description': 'Single-player'}, {'...
# 33090  [{'id': 2, 'description': 'Single-player'}, {'...
# 33128  [{'id': 2, 'description': 'Single-player'}, {'...
# 33138  [{'id': 2, 'description': 'Single-player'}, {'...
# 33139  [{'id': 2, 'description': 'Single-player'}, {'...
# 33144  [{'id': 2, 'description': 'Single-player'}, {'...
# 33241  [{'id': 2, 'description': 'Single-player'}, {'...
# 33244  [{'id': 2, 'description': 'Single-player'}, {'...
# 34449  [{'id': 2, 'description': 'Single-player'}, {'...
# 34718        [{'id': 2, 'description': 'Single-player'}]
# 36069  [{'id': 2, 'description': 'Single-player'}, {'...
# 37561  [{'id': 2, 'description': 'Single-player'}, {'...
# 39309  [{'id': 2, 'description': 'Single-player'}, {'...
# 41114  [{'id': 2, 'description': 'Single-player'}, {'...
# 65749  [{'id': 2, 'description': 'Single-player'}, {'...
# 65782                                                NaN
# 65787  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 65819  [{'id': 22, 'description': 'Steam Achievements'}]
# 65836  [{'id': 2, 'description': 'Single-player'}, {'...
# 66036  [{'id': 28, 'description': 'Full controller su...
#
#                                                   genres  \
# 2360                                                 NaN
# 14129  [{'id': '25', 'description': 'Adventure'}, {'i...
# 31140        [{'id': '28', 'description': 'Simulation'}]
# 31180  [{'id': '1', 'description': 'Action'}, {'id': ...
# 31556        [{'id': '28', 'description': 'Simulation'}]
# 32499  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 32625  [{'id': '28', 'description': 'Simulation'}, {'...
# 32653             [{'id': '1', 'description': 'Action'}]
# 32846  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32870  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32882                [{'id': '3', 'description': 'RPG'}]
# 32883             [{'id': '1', 'description': 'Action'}]
# 32884             [{'id': '1', 'description': 'Action'}]
# 32924  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32939  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32968  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32974  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32986  [{'id': '25', 'description': 'Adventure'}, {'i...
# 32994  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32995  [{'id': '1', 'description': 'Action'}, {'id': ...
# 32999  [{'id': '1', 'description': 'Action'}, {'id': ...
# 33015  [{'id': '1', 'description': 'Action'}, {'id': ...
# 33090  [{'id': '25', 'description': 'Adventure'}, {'i...
# 33128  [{'id': '1', 'description': 'Action'}, {'id': ...
# 33138  [{'id': '3', 'description': 'RPG'}, {'id': '2'...
# 33139                [{'id': '3', 'description': 'RPG'}]
# 33144           [{'id': '2', 'description': 'Strategy'}]
# 33241  [{'id': '1', 'description': 'Action'}, {'id': ...
# 33244  [{'id': '1', 'description': 'Action'}, {'id': ...
# 34449  [{'id': '3', 'description': 'RPG'}, {'id': '28...
# 34718  [{'id': '1', 'description': 'Action'}, {'id': ...
# 36069  [{'id': '25', 'description': 'Adventure'}, {'i...
# 37561  [{'id': '1', 'description': 'Action'}, {'id': ...
# 39309  [{'id': '1', 'description': 'Action'}, {'id': ...
# 41114  [{'id': '25', 'description': 'Adventure'}, {'i...
# 65749           [{'id': '2', 'description': 'Strategy'}]
# 65782                                                NaN
# 65787             [{'id': '1', 'description': 'Action'}]
# 65819  [{'id': '52', 'description': 'Audio Production...
# 65836  [{'id': '1', 'description': 'Action'}, {'id': ...
# 66036                                                NaN
#
#                                              screenshots  \
# 2360                                                 NaN
# 14129  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 31140  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 31180  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 31556  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32499  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32625  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32653  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32846  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32870  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32882  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32883  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32884  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32924  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32939  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32968  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32974  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32986  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32994  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32995  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 32999  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33015  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33090  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33128  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33138  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33139  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33144  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33241  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 33244  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34449  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 34718  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 36069  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 37561  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 39309  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 41114  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 65749  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 65782                                                NaN
# 65787  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 65819  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 65836  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 66036  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                   movies  recommendations  \
# 2360                                                 NaN   {'total': 126}
# 14129  [{'id': 256766448, 'name': '概念PV', 'thumbnail'...  {'total': 3788}
# 31140                                                NaN   {'total': 169}
# 31180  [{'id': 256810412, 'name': 'Crash Time 2 Steam...  {'total': 1079}
# 31556                                                NaN   {'total': 109}
# 32499  [{'id': 2028932, 'name': 'Patterns Trailer 2',...   {'total': 108}
# 32625  [{'id': 2029090, 'name': 'Rise of Venice Gamep...   {'total': 288}
# 32653                                                NaN   {'total': 632}
# 32846  [{'id': 2029042, 'name': 'Mirage- Featurette',...   {'total': 129}
# 32870  [{'id': 2029252, 'name': 'Rayman Legends Launc...  {'total': 4983}
# 32882                                                NaN   {'total': 309}
# 32883                                                NaN   {'total': 724}
# 32884                                                NaN   {'total': 521}
# 32924                                                NaN   {'total': 137}
# 32939  [{'id': 2029217, 'name': 'Flashback Trailer', ...   {'total': 430}
# 32968  [{'id': 2029323, 'name': 'Artemis crew saving ...   {'total': 287}
# 32974  [{'id': 2029987, 'name': 'Launch trailer', 'th...  {'total': 2810}
# 32986  [{'id': 2029381, 'name': 'Trailer English', 't...   {'total': 163}
# 32994  [{'id': 2029385, 'name': 'Trailer', 'thumbnail...   {'total': 429}
# 32995  [{'id': 2029559, 'name': 'Trailer', 'thumbnail...   {'total': 311}
# 32999  [{'id': 2030115, 'name': 'Vector', 'thumbnail'...   {'total': 614}
# 33015  [{'id': 2038463, 'name': 'Steam Trailer', 'thu...   {'total': 430}
# 33090  [{'id': 2030120, 'name': 'Shivah: Kosher Editi...   {'total': 443}
# 33128  [{'id': 2029859, 'name': 'Sparkle 2 Evo Traile...  {'total': 1512}
# 33138  [{'id': 2029352, 'name': 'Gorky 17 [aka Odium]...   {'total': 756}
# 33139  [{'id': 2029363, 'name': 'Septerra Core Traile...   {'total': 431}
# 33144  [{'id': 2029353, 'name': 'World War II: Panzer...   {'total': 107}
# 33241  [{'id': 2030194, 'name': 'Trailer', 'thumbnail...   {'total': 150}
# 33244  [{'id': 2030097, 'name': 'Nimble Quest Trailer...   {'total': 631}
# 34449  [{'id': 256668690, 'name': 'Galore', 'thumbnai...   {'total': 173}
# 34718  [{'id': 2033839, 'name': 'Trailer', 'thumbnail...   {'total': 200}
# 36069  [{'id': 256657384, 'name': 'steam trailer', 't...  {'total': 1117}
# 37561  [{'id': 256655742, 'name': 'Secret of Magia', ...   {'total': 662}
# 39309  [{'id': 256662503, 'name': 'CHTULHU', 'thumbna...  {'total': 1147}
# 41114  [{'id': 256770462, 'name': 'LOTR:ACG - Definit...  {'total': 1026}
# 65749                                                NaN   {'total': 140}
# 65782                                                NaN   {'total': 283}
# 65787  [{'id': 2035298, 'name': 'New Content', 'thumb...  {'total': 2990}
# 65819  [{'id': 2029346, 'name': 'PlayClaw 5 release t...   {'total': 351}
# 65836  [{'id': 2030112, 'name': 'Gameplay Trailer v0....   {'total': 242}
# 66036  [{'id': 256827040, 'name': 'Remote Play', 'thu...  {'total': 5203}
#
#                                             achievements  \
# 2360                                                 NaN
# 14129  {'total': 27, 'highlighted': [{'name': 'Broken...
# 31140                                                NaN
# 31180                                                NaN
# 31556                                                NaN
# 32499                                                NaN
# 32625  {'total': 56, 'highlighted': [{'name': 'Every ...
# 32653  {'total': 30, 'highlighted': [{'name': 'The Sw...
# 32846  {'total': 102, 'highlighted': [{'name': 'Rich ...
# 32870                                                NaN
# 32882                                                NaN
# 32883                                                NaN
# 32884                                                NaN
# 32924                                                NaN
# 32939                                                NaN
# 32968                                                NaN
# 32974  {'total': 36, 'highlighted': [{'name': 'Are th...
# 32986                                                NaN
# 32994  {'total': 48, 'highlighted': [{'name': 'The be...
# 32995  {'total': 27, 'highlighted': [{'name': 'Toughe...
# 32999  {'total': 57, 'highlighted': [{'name': 'Runner...
# 33015  {'total': 49, 'highlighted': [{'name': 'Papers...
# 33090  {'total': 10, 'highlighted': [{'name': 'Maven'...
# 33128  {'total': 22, 'highlighted': [{'name': 'Tutori...
# 33138                                       {'total': 0}
# 33139                                       {'total': 0}
# 33144                                       {'total': 0}
# 33241  {'total': 44, 'highlighted': [{'name': 'First ...
# 33244                                                NaN
# 34449                                                NaN
# 34718                                                NaN
# 36069                                                NaN
# 37561  {'total': 5, 'highlighted': [{'name': 'Into th...
# 39309  {'total': 14, 'highlighted': [{'name': "Let's ...
# 41114  {'total': 73, 'highlighted': [{'name': 'The Jo...
# 65749  {'total': 14, 'highlighted': [{'name': 'Guarde...
# 65782                                                NaN
# 65787  {'total': 7, 'highlighted': [{'name': 'Block B...
# 65819  {'total': 10, 'highlighted': [{'name': 'Verbal...
# 65836                                                NaN
# 66036                                                NaN
#
#                                          release_date  \
# 2360   {'coming_soon': False, 'date': '13 Oct, 2017'}
# 14129  {'coming_soon': False, 'date': '27 Nov, 2019'}
# 31140  {'coming_soon': False, 'date': '12 Mar, 2008'}
# 31180  {'coming_soon': False, 'date': '27 Aug, 2009'}
# 31556  {'coming_soon': False, 'date': '23 Sep, 2009'}
# 32499              {'coming_soon': False, 'date': ''}
# 32625  {'coming_soon': False, 'date': '27 Sep, 2013'}
# 32653  {'coming_soon': False, 'date': '28 Aug, 2013'}
# 32846  {'coming_soon': False, 'date': '11 Nov, 2013'}
# 32870  {'coming_soon': False, 'date': '29 Aug, 2013'}
# 32882  {'coming_soon': False, 'date': '17 Oct, 2013'}
# 32883  {'coming_soon': False, 'date': '24 Sep, 2013'}
# 32884   {'coming_soon': False, 'date': '1 Oct, 2013'}
# 32924   {'coming_soon': False, 'date': '3 Oct, 2013'}
# 32939   {'coming_soon': False, 'date': '1 Oct, 2013'}
# 32968  {'coming_soon': False, 'date': '16 Sep, 2013'}
# 32974  {'coming_soon': False, 'date': '31 Oct, 2013'}
# 32986  {'coming_soon': False, 'date': '20 Sep, 2013'}
# 32994  {'coming_soon': False, 'date': '11 Oct, 2013'}
# 32995   {'coming_soon': False, 'date': '7 Nov, 2013'}
# 32999   {'coming_soon': False, 'date': '3 Dec, 2013'}
# 33015  {'coming_soon': False, 'date': '29 May, 2015'}
# 33090  {'coming_soon': False, 'date': '21 Nov, 2013'}
# 33128  {'coming_soon': False, 'date': '24 Oct, 2013'}
# 33138  {'coming_soon': False, 'date': '27 Sep, 2013'}
# 33139  {'coming_soon': False, 'date': '27 Sep, 2013'}
# 33144  {'coming_soon': False, 'date': '27 Sep, 2013'}
# 33241  {'coming_soon': False, 'date': '22 Nov, 2013'}
# 33244   {'coming_soon': False, 'date': '6 Dec, 2013'}
# 34449  {'coming_soon': False, 'date': '21 Oct, 2015'}
# 34718   {'coming_soon': False, 'date': '5 Aug, 2014'}
# 36069  {'coming_soon': False, 'date': '30 Mar, 2015'}
# 37561  {'coming_soon': False, 'date': '21 Aug, 2015'}
# 39309  {'coming_soon': False, 'date': '25 Mar, 2016'}
# 41114  {'coming_soon': False, 'date': '29 Aug, 2019'}
# 65749   {'coming_soon': False, 'date': '1 Nov, 2010'}
# 65782              {'coming_soon': False, 'date': ''}
# 65787  {'coming_soon': False, 'date': '10 Sep, 2014'}
# 65819  {'coming_soon': False, 'date': '10 Sep, 2013'}
# 65836  {'coming_soon': False, 'date': '12 Nov, 2013'}
# 66036  {'coming_soon': False, 'date': '10 Nov, 2015'}
#
#                                             support_info  \
# 2360                            {'url': '', 'email': ''}
# 14129  {'url': 'http://game.bilibili.com/kf/', 'email...
# 31140                           {'url': '', 'email': ''}
# 31180                           {'url': '', 'email': ''}
# 31556  {'url': 'https://playhardgames.net/contact/', ...
# 32499  {'url': 'http://www.buildpatterns.com/#!commun...
# 32625  {'url': 'forum.kalypsomedia.com', 'email': 'su...
# 32653  {'url': 'https://support.activision.com/', 'em...
# 32846     {'url': '', 'email': 'mirage@origo-games.com'}
# 32870  {'url': 'http://www.support.ubi.com', 'email':...
# 32882  {'url': 'http://sqex.to/steamsupport', 'email'...
# 32883  {'url': 'http://sqex.to/steamsupport', 'email'...
# 32884  {'url': 'http://sqex.to/steamsupport', 'email'...
# 32924  {'url': 'http://sqex.to/steamsupport', 'email'...
# 32939  {'url': 'http://www.support.ubi.com', 'email':...
# 32968       {'url': '', 'email': 'artemissbs@gmail.com'}
# 32974  {'url': 'https://rebellion.com/support/', 'ema...
# 32986  {'url': 'http://uieg.de/', 'email': 'support@u...
# 32994  {'url': '', 'email': 'support@forever-entertai...
# 32995  {'url': 'http://a-walk-in-the-dark.com', 'emai...
# 32999   {'url': 'http://support.nekki.com', 'email': ''}
# 33015  {'url': '', 'email': 'support@forgequestrpg.com'}
# 33090  {'url': 'http://www.wadjeteyegames.com', 'emai...
# 33128  {'url': '', 'email': 'support@forever-entertai...
# 33138  {'url': 'http://replaynow.topware.com/en/gorky...
# 33139  {'url': 'http://replaynow.topware.com/en/septe...
# 33144  {'url': 'http://replaynow.topware.com/en/world...
# 33241  {'url': 'http://shoreboundstudios.com', 'email...
# 33244  {'url': 'http://support.nimblebit.com', 'email...
# 34449  {'url': 'https://shallowspace.co', 'email': 's...
# 34718      {'url': '', 'email': 'support@meridian4.com'}
# 36069         {'url': '', 'email': 'grvlndev@gmail.com'}
# 37561        {'url': '', 'email': 'ian@ip-builders.com'}
# 39309                           {'url': '', 'email': ''}
# 41114  {'url': 'https://asmodee.helpshift.com/a/asmod...
# 65749  {'url': '', 'email': 'support@petroglyphgames....
# 65782                           {'url': '', 'email': ''}
# 65787  {'url': 'http://support.playminimum.com', 'ema...
# 65819  {'url': 'http://playclaw.com/support', 'email'...
# 65836  {'url': 'http://www.vox-game.com', 'email': 'a...
# 66036  {'url': 'http://steamcommunity.com/app/353380'...
#
#                                               background  \
# 2360                                                 NaN
# 14129  https://cdn.akamai.steamstatic.com/steam/apps/...
# 31140  https://cdn.akamai.steamstatic.com/steam/apps/...
# 31180  https://cdn.akamai.steamstatic.com/steam/apps/...
# 33015  {'ids': [], 'notes': None}
# 33090  {'ids': [], 'notes': None}
# 33128  {'ids': [], 'notes': None}
# 33138  {'ids': [], 'notes': None}
# 33139  {'ids': [], 'notes': None}
# 33144  {'ids': [], 'notes': None}
# 33241  {'ids': [], 'notes': None}
# 33244  {'ids': [], 'notes': None}
# 34449  {'ids': [], 'notes': None}
# 34718  {'ids': [], 'notes': None}
# 36069  {'ids': [], 'notes': None}
# 37561  {'ids': [], 'notes': None}
# 39309  {'ids': [], 'notes': None}
# 41114  {'ids': [], 'notes': None}
# 65749  {'ids': [], 'notes': None}
# 65782  {'ids': [], 'notes': None}
# 65787  {'ids': [], 'notes': None}
# 65819  {'ids': [], 'notes': None}
# 65836  {'ids': [], 'notes': None}
# 66036  {'ids': [], 'notes': None}
#
# [41 rows x 39 columns]

# %% [markdown]
# There are around 160 entries without developers - there are some games which are no longer available, but if we filter by recommendations there are a few which are valid. These are mostly retro games which some publisher has the right to, but the developer is unlisted intentionally (it might not exist anymore, or they just do not care).

# %%
store["developers"].value_counts().head(60)
# Out:
# ['Choice of Games']                     144
# ['Laush Dmitriy Sergeevich']            113
# ['Creobit']                             102
# ['KOEI TECMO GAMES CO., LTD.']           93
# ['Sokpop Collective']                    90
# ['Boogygames Studios']                   88
# ['Hosted Games']                         85
# ['Elephant Games']                       75
# ['Blender Games']                        71
# ['SEGA']                                 67
# ['RewindApp']                            62
# ['Ripknot Systems']                      62
# ['Somer Games']                          60
# ['AMAX Interactive']                     58
# ['MAGIX Software GmbH']                  57
# ['ImperiumGame']                         57
# ['William at Oxford']                    55
# ['Eipix Entertainment']                  54
# ['Nikita "Ghost_RUS"']                   51
# ['玫瑰工作室']                                46
# ['Individual Software']                  44
# ['Snkl Studio']                          43
# ['HotFoodGames']                         42
# ['Dnovel']                               41
# ['Square Enix']                          41
# ['Telltale Games']                       40
# ['Dharker Studio']                       40
# ['Winged Cloud']                         38
# ['HexWar Games']                         37
# ['For Kids']                             37
# ['EnsenaSoft']                           37
# ['Sweet Games']                          37
# ['Cyber Keks']                           36
# ['Anamik Majumdar']                      36
# ['Luci Entertainment']                   36
# ['Humongous Entertainment']              36
# ['QuickBobber']                          36
# ['Milestone S.r.l.']                     36
# ['Racing Bros']                          36
# ['Stegalosaurus Game Development']       35
# ['Domini Games']                         35
# ['Warfare Studios']                      34
# ['IR Studio']                            34
# ['VR RETRO REMASTER']                    34
# ['Valve']                                33
# ['Winter Wolves']                        33
# ['NanningsGames']                        31
# ['HeR Interactive']                      31
# ['GreatHopeStudio']                      30
# ['CSM']                                  29
# ['Kedexa']                               29
# ['Minimol Games']                        29
# ['MumboJumbo']                           29
# ['United Independent Entertainment']     28
# ['CAPCOM Co., Ltd.']                     28
# ['LTZinc']                               28
# ['Arc System Works']                     28
# ['Nihon Falcom']                         27
# ['Miel']                                 27
# ['My Label Game Studio']                 26
# Name: developers, dtype: int64

# %%
store[store["developers"]=="['']"]
# Out:
# Empty DataFrame
# Columns: [type, name, steam_appid, required_age, is_free, controller_support, dlc, detailed_description, about_the_game, short_description, fullgame, supported_languages, header_image, website, pc_requirements, mac_requirements, linux_requirements, legal_notice, drm_notice, ext_user_account_notice, developers, publishers, demos, price_overview, packages, package_groups, platforms, metacritic, reviews, categories, genres, screenshots, movies, recommendations, achievements, release_date, support_info, background, content_descriptors]
# Index: []
#
# [0 rows x 39 columns]

# %% [markdown]
# You will understand in the publishers section why I checked that. It seems it is a placeholder in Steam for mandatory values which are not filled, or have been deleted.

# %%
spy[spy["appid"].isin(store[store["developers"].isnull()]["steam_appid"].values)]["developer"].value_counts().head(60)
# Out:
# dtp – young entertainment Gmbh &amp; Co. KG         5
# Softstar Technology (Beijing) Co.,Ltd               3
# CS-REPORTERS.INC                                    2
# ArenaNet®                                           2
# AIDIS                                               1
# Ubisoft                                             1
# Obsidian Entertainment                              1
# NEXON Korea Corp.                                   1
# Atomic Jelly                                        1
# MegaFun Games Ltd.                                  1
# MCGame                                              1
# KingsIsle Entertainment                             1
# IPBuilders                                          1
# Saber Interactive                                   1
# Climax Studios                                      1
# Rhaon Entertainment                                 1
# BitLight                                            1
# Gravity Interactive                                 1
# Gravity, Inc.                                       1
# Dragonfly                                           1
# N2Games                                             1
# Liar-soft                                           1
# G5 Entertainment                                    1
# Softstar Technology (Shanghai) Co., Ltd.            1
# Angel Star Studios                                  1
# SQUARE ENIX, GREE, Inc.                             1
# FIRE-POINT INTERACTIVE INC                          1
# Wally Hardmaker, Wally Hardmaker                    1
# Onson Soft                                          1
# Square Enix                                         1
# Valve                                               1
# Targem Games                                        1
# Eyedentity Games Inc.                               1
# Gravity Interactive, Inc.                           1
# SkyFallen Entertainment, 1C Company, 1C-SoftClub    1
# Nickelodeon                                         1
# Sammy Networks Co., Ltd.                            1
# 探X索, Explore X Studio                               1
# Christian tavares da silva                          1
# IMCGAMES CO., LTD.                                  1
# Vertigo Games                                       1
# Red Storm Entertainment                             1
# TT Games                                            1
# Haemimont Games                                     1
# House of Pandas                                     1
# Traveller's Tales                                   1
# EA - Maxis                                          1
# Name: developer, dtype: int64

# %% [markdown]
# #### Developers: Cleaning Decision
#
# * First we will merge store and spy, keeping store data unless we have a NaN
# * Since this process will be the same for other duplicate columns, we will do it first!
#
# * Then we will copy the publisher name into the developer, for the cases without developers. Games with other missing information we will take care of afterwards.

# %%
# To simplify cleaning, let's change appid and steam_appid to.. just id. And in fact, let's make that our index!
# Since we will be using df.fillna(df2) later, it would be useful to change similar column names so they are the same.
def renameIDs(store,spy):
    store = store.rename(columns={"steam_appid":"id"})
    store = store.set_index("id")
    spy = spy.rename(columns={"appid":"id", "genre":"genres", "developer":"developers", "publisher":"publishers",
                              "languages":"supported_languages"})
    spy = spy.set_index("id")
    return store, spy

# %%
store, spy = renameIDs(store,spy)

# %%
# In this function, the index from both df must be the same - the old appid in our case.
# Also, the column names where we will be getting our values should also be the same.
# Lastly, ideally we would the values to be formatted in the same way - but we can also check later.
def updateFromAlternateSource(maindf,subdf):
    df = maindf.copy()
    df = df.fillna(subdf)
    return df

# %% [markdown]
# Now we could actually run this function and update the developers from Steam Spy. But doing this will also mean we add any
# extra values from `genres` and `languages`. This might be a problem since they are formatted differently.
#
# We will have to take this into account when formatting these two columns, as the information from Steam Spy will be added for the NaN.
#
# Let's also define a new function to give us the name and links to any subseries of apps, for troubleshooting.

# %%
def getSteamLink(df):
    for item in df.index:
        print(df.loc[item]["name"]+" https://store.steampowered.com/app/"+str(item))

# %% [markdown]
# ### Publishers
#
# It seemed that the publishers were ok, as we have no NaN. However, there are a lot of blank names. This is probably a mandatory metadata from Steam, and some ids have managed to not put a publisher whatsoever doing that.
#
# Let's look at them, if there are valid ones (i.e ones who have a developer) we can consider them self-published and just do the same as before, copying the developer name into the publisher.

# %%
store[store["publishers"]==""]
# Out:
# Empty DataFrame
# Columns: [type, name, required_age, is_free, controller_support, dlc, detailed_description, about_the_game, short_description, fullgame, supported_languages, header_image, website, pc_requirements, mac_requirements, linux_requirements, legal_notice, drm_notice, ext_user_account_notice, developers, publishers, demos, price_overview, packages, package_groups, platforms, metacritic, reviews, categories, genres, screenshots, movies, recommendations, achievements, release_date, support_info, background, content_descriptors]
# Index: []
#
# [0 rows x 38 columns]

# %% [markdown]
# That's not right... While doing the cleaning process, I detected some empty strings... right?

# %%
store["publishers"].value_counts()
# Out:
# ['Big Fish Games']    416
# ['']                  377
# ['SEGA']              168
# ['8floor']            168
# ['Strategy First']    155
#                      ...
# ['SOUP STUDIOS']        1
# ['地心游戏']                1
# ['Cupfox Studio']       1
# ['mchernykh']           1
# ['Juno Morrow']         1
# Name: publishers, Length: 36353, dtype: int64

# %%
(store["publishers"]=="['']").sum()
# Out:
# 377

# %%
store[store["publishers"]=="['']"]
# Out:
#         type                                   name required_age is_free  \
# id
# 312860  game  Defense Grid 2: A Matter of Endurance          0.0   False
# 384930  game                         Pilot Crusader          0.0   False
# 636560  game          Runewards: Strategy Card Game          0.0    True
# 666870  game                          Perfect Crime         18.0   False
# 688150  game                      JUMPER : SPEEDRUN            0    True
# ...      ...                                    ...          ...     ...
# 616090  game                                   龙魂时刻          0.0   False
# 633130  game                                Nongünz          0.0   False
# 658440  game          Enshrouded World: Home Truths          0.0   False
# 669280  game                      Les Quatre Alices          0.0   False
# 674010  game                             TerkEngine          0.0   False
#
#        controller_support                 dlc  \
# id
# 312860                NaN                 NaN
# 384930                NaN                 NaN
# 636560                NaN                 NaN
# 666870                NaN  [1227610, 1327410]
# 688150                NaN                 NaN
# ...                   ...                 ...
# 616090                NaN                 NaN
# 633130               full                 NaN
# 658440                NaN                 NaN
# 669280                NaN                 NaN
# 674010                NaN                 NaN
#
#                                      detailed_description  \
# id
# 312860                                                NaN
# 384930  Pilot Crusader is a retro shoot-em-up with a s...
# 636560  Runewards is a free-to-play competitive strate...
# 666870  <h1>English Supported Completely!</h1><p><img ...
# 688150  <strong>JUMPER : SPEEDRUN</strong> is an FPS P...
# ...                                                   ...
# 616090  《龙魂时刻》是一款3D无锁定动作网游,拥有东西方文化碰撞的独特世界观/精彩刺激的PVP玩法和...
# 633130  <h1>NONGÜNZ IS OUT! THANK YOU!</h1><p><img src...
# 658440                                                NaN
# 669280  A young girl walks in a dark forest. <br>She m...
# 674010  A single game developed by TerkStudios, develo...
#
#                                            about_the_game  \
# id
# 312860                                                NaN
# 384930  Pilot Crusader is a retro shoot-em-up with a s...
# 636560  Runewards is a free-to-play competitive strate...
# 666870  <img src="https://cdn.akamai.steamstatic.com/s...
# 688150  <strong>JUMPER : SPEEDRUN</strong> is an FPS P...
# ...                                                   ...
# 616090  《龙魂时刻》是一款3D无锁定动作网游,拥有东西方文化碰撞的独特世界观/精彩刺激的PVP玩法和...
# 633130  <strong>Nongünz</strong> is a nihilistic actio...
# 658440                                                NaN
# 669280  A young girl walks in a dark forest. <br>She m...
# 674010  A single game developed by TerkStudios, develo...
#
#                                         short_description  fullgame  ...  \
# id                                                                   ...
# 312860                                                NaN       NaN  ...
# 384930  Take control of a powerful spaceship and wage ...       NaN  ...
# 636560  Runewards is a free-to-play competitive strate...       NaN  ...
# 666870  With superb script and calm narrative style, P...       NaN  ...
# 688150  JUMPER : SPEEDRUN is a new Type of FPS Platfor...       NaN  ...
# ...                                                   ...       ...  ...
# 616090  全新3D无锁定动作网游，独具特色的主角时刻，充满挑战的团队副本，全面革新的3D动作竞技，流畅...       NaN  ...
# 633130  Nongünz is a nihilistic action platformer rogu...       NaN  ...
# 658440                                                NaN       NaN  ...
# 669280  A short visual novel, made in RPG MAKER MV, wh...       NaN  ...
# 674010  Loneliness is a survival experience, mainly ta...       NaN  ...
#
#                                                categories  \
# id
# 312860                                                NaN
# 384930        [{'id': 2, 'description': 'Single-player'}]
# 636560  [{'id': 2, 'description': 'Single-player'}, {'...
# 666870  [{'id': 2, 'description': 'Single-player'}, {'...
# 688150        [{'id': 2, 'description': 'Single-player'}]
# ...                                                   ...
# 616090  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 633130  [{'id': 2, 'description': 'Single-player'}, {'...
# 658440        [{'id': 2, 'description': 'Single-player'}]
# 669280  [{'id': 2, 'description': 'Single-player'}, {'...
# 674010  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                    genres  \
# id
# 312860                                                NaN
# 384930  [{'id': '1', 'description': 'Action'}, {'id': ...
# 636560  [{'id': '37', 'description': 'Free to Play'}, ...
# 666870  [{'id': '23', 'description': 'Indie'}, {'id': ...
# 688150  [{'id': '23', 'description': 'Indie'}, {'id': ...
# ...                                                   ...
# 616090  [{'id': '1', 'description': 'Action'}, {'id': ...
# 633130  [{'id': '1', 'description': 'Action'}, {'id': ...
# 658440             [{'id': '1', 'description': 'Action'}]
# 669280  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 674010  [{'id': '1', 'description': 'Action'}, {'id': ...
#
#                                               screenshots  \
# id
# 312860                                                NaN
# 384930  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 636560  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 666870  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 688150  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# ...                                                   ...
# 616090  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 633130  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 658440                                                NaN
# 669280  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 674010  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                    movies recommendations  \
# id
# 312860                                                NaN             NaN
# 384930  [{'id': 2040586, 'name': 'Pilot Crusader Trail...             NaN
# 636560  [{'id': 256686468, 'name': 'Runewards - Game T...             NaN
# 666870  [{'id': 256760057, 'name': '宣传视频', 'thumbnail'...  {'total': 325}
# 688150  [{'id': 256691573, 'name': 'JUMPER : SPEEDRUN'...             NaN
# ...                                                   ...             ...
# 616090  [{'id': 256688609, 'name': 'x5-newCJ626', 'thu...             NaN
# 633130  [{'id': 256685374, 'name': 'Launch Trailer', '...  {'total': 179}
# 658440                                                NaN             NaN
# 669280  [{'id': 256694073, 'name': 'Gameplay Trailer',...             NaN
# 674010                                                NaN             NaN
#
#                                              achievements  \
# id
# 312860                                                NaN
# 384930                                                NaN
# 636560                                                NaN
# 666870  {'total': 40, 'highlighted': [{'name': 'People...
# 688150                                                NaN
# ...                                                   ...
# 616090                                                NaN
# 633130  {'total': 26, 'highlighted': [{'name': 'A', 'p...
# 658440  {'total': 10, 'highlighted': [{'name': 'Bona F...
# 669280  {'total': 9, 'highlighted': [{'name': "Let's b...
# 674010                                                NaN
#
#                                           release_date  \
# id
# 312860  {'coming_soon': False, 'date': '22 Sep, 2014'}
# 384930  {'coming_soon': False, 'date': '10 Jul, 2015'}
# 636560  {'coming_soon': False, 'date': '13 Feb, 2018'}
# 666870   {'coming_soon': False, 'date': '1 Oct, 2020'}
# 688150  {'coming_soon': False, 'date': '28 Aug, 2017'}
# ...                                                ...
# 616090  {'coming_soon': False, 'date': '27 Jun, 2017'}
# 633130  {'coming_soon': False, 'date': '19 May, 2017'}
# 658440  {'coming_soon': False, 'date': '26 Feb, 2018'}
# 669280  {'coming_soon': False, 'date': '28 Aug, 2017'}
# 674010   {'coming_soon': False, 'date': '9 Oct, 2017'}
#
#                                              support_info  \
# id
# 312860                           {'url': '', 'email': ''}
# 384930  {'url': 'http://radlabgaming.com', 'email': 's...
# 636560  {'url': 'https://forum.runewards.com/index.php...
# 666870           {'url': '', 'email': '570505836@qq.com'}
# 688150      {'url': '', 'email': 'aaent.games@gmail.com'}
# ...                                                   ...
# 616090       {'url': 'http://help.163.com/', 'email': ''}
# 633130  {'url': 'www.digerati.games', 'email': 'george...
# 658440  {'url': '', 'email': 'enshroudedworld@gmail.com'}
# 669280     {'url': 'http://miagames.net/en', 'email': ''}
# 674010  {'url': 'thempiresupport.blogspot.com', 'email...
#
#                                                background  \
# id
# 312860                                                NaN
# 384930  https://cdn.akamai.steamstatic.com/steam/apps/...
# 636560  https://cdn.akamai.steamstatic.com/steam/apps/...
# 666870  https://cdn.akamai.steamstatic.com/steam/apps/...
# 688150  https://cdn.akamai.steamstatic.com/steam/apps/...
# ...                                                   ...
# 616090  https://cdn.akamai.steamstatic.com/steam/apps/...
# 633130  https://cdn.akamai.steamstatic.com/steam/apps/...
# 658440                                                NaN
# 669280  https://cdn.akamai.steamstatic.com/steam/apps/...
# 674010  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                    content_descriptors
# id
# 312860      {'ids': [], 'notes': None}
# 384930      {'ids': [], 'notes': None}
# 636560      {'ids': [], 'notes': None}
# 666870  {'ids': [2, 5], 'notes': None}
# 688150      {'ids': [], 'notes': None}
# ...                                ...
# 616090      {'ids': [], 'notes': None}
# 633130      {'ids': [], 'notes': None}
# 658440      {'ids': [], 'notes': None}
# 669280      {'ids': [], 'notes': None}
# 674010      {'ids': [], 'notes': None}
#
# [377 rows x 38 columns]

# %% [markdown]
# That's just evil. Those publishers just put [''] in a string inside the field, just like that. We will change them to NaN. We might want to revisit names, developers... everything really, just in case. As this is really important (to check out the NaNs), we will do it before following with the assessment of the rest of variables.
#
# Checking the values manually, some of them are publishers which have asked to remove the game from steam. But if you put the id manually, it is still available (i.e https://store.steampowered.com/app/633130/Nongnz/ ). Maybe the publisher itself has asked to delete their account.
#
# Is it possible that some of these values were registered at some point by Steam Spy and conserved? Let's check that, if not we will simply treat them like NaNs.

# %%
(~spy[spy.index.isin(store[store["publishers"]=="['']"].index)]["publishers"].isnull()).sum()
# Out:
# 262

# %% [markdown]
# It seems we can recover up to 262 values from Steam Spy, now that we have discovered that this supposedly complete column had some NaNs..
#
# This is the reason I decided to split the cleaning section into a pre-merge and post-merge cleaning.

# %% [markdown]
# #### Publisher/Others: Cleaning Decision
#
# * I.e using `store = store.replace("['']", np.NaN)` we should catch any [''] false strings in the steam database, which we thought more complete. Then merge ids, using the Steam Store value (if available) and falling back to Steam Spy if possible.
#
#
# * If there is no publisher, but we have a developer, then we will use the developer as publisher as well. If there is no publisher or developer, we will simply delete the record.

# %%
def getOtherColumnValue(row,current,alternate):
    if pd.isna(row[current]):
        return row[alternate]
    else:
        return row[current]

def fixDevPub(store, spy):
    store = store.replace("['']", np.NaN)
    store = updateFromAlternateSource(store,spy)
    store["developers"] = store.apply(getOtherColumnValue, current="developers", alternate="publishers", axis=1)
    store["publishers"] = store.apply(getOtherColumnValue, current="publishers", alternate="developers", axis=1)
    return store

# %% [markdown]
# Running this function will get any values from steam spy which are useful from the repeated columns. We have also eliminated the empty string values and replaced them with NaN, to ensure our cleaning functions detect them properly.
#
# However, note that we have also updated genres and languages by doing it this way...

# %%
store = fixDevPub(store, spy)

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66803 entries, 10140 to 676480
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     66655 non-null  object
#  1   name                     66803 non-null  object
#  2   required_age             66655 non-null  object
#  3   is_free                  66655 non-null  object
#  4   controller_support       14422 non-null  object
#  5   dlc                      9342 non-null   object
#  6   detailed_description     66587 non-null  object
#  7   about_the_game           66585 non-null  object
#  8   short_description        66593 non-null  object
#  9   fullgame                 0 non-null      float64
#  10  supported_languages      66667 non-null  object
#  11  header_image             66655 non-null  object
#  12  website                  36119 non-null  object
#  13  pc_requirements          66655 non-null  object
#  14  mac_requirements         66655 non-null  object
#  15  linux_requirements       66655 non-null  object
#  16  legal_notice             19502 non-null  object
#  17  drm_notice               278 non-null    object
#  18  ext_user_account_notice  1124 non-null   object
#  19  developers               66653 non-null  object
#  20  publishers               66653 non-null  object
#  21  demos                    6009 non-null   object
#  22  price_overview           47350 non-null  object
#  23  packages                 47963 non-null  object
#  24  package_groups           66655 non-null  object
#  25  platforms                66655 non-null  object
#  26  metacritic               3726 non-null   object
#  27  reviews                  8872 non-null   object
#  28  categories               65699 non-null  object
#  29  genres                   66574 non-null  object
#  30  screenshots              66533 non-null  object
#  31  movies                   61673 non-null  object
#  32  recommendations          11674 non-null  object
#  33  achievements             30294 non-null  object
#  34  release_date             66655 non-null  object
#  35  support_info             66655 non-null  object
#  36  background               66547 non-null  object
#  37  content_descriptors      66655 non-null  object
# dtypes: float64(1), object(37)
# memory usage: 21.9+ MB

# %% [markdown]
# Before continuining, let's drop any rows where we dont have publisher and developer.

# %%
store = store[~store["publishers"].isnull()]

# %% [markdown]
# ### Genre
#
# There are 3 similar types of data here. We have genre, categories, and tags. However, genre is the only one present at both dataframes, so we will check it first. It is possible that we consolidate these 3 columns into one or two final ones.
#
# But it could be more complex. If we want to do any machine learning approach, we might need to turn these unique categories, tags etcetera into unique columns with 1/0 values. In any case, that is food for thought for later processes. What is important right now is that we do not lose any information.
#
# Recalling the first part of this section, genre had almost no NaNs on store, but a lot on spy. Let's check if we can complete it only with store, and compare the different formats.

# %%
store["genres"].value_counts()
# Out:
# [{'id': '1', 'description': 'Action'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                          3980
# [{'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                          3598
# [{'id': '1', 'description': 'Action'}, {'id': '25', 'description': 'Adventure'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                3425
# [{'id': '25', 'description': 'Adventure'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                                                      2856
# [{'id': '1', 'description': 'Action'}, {'id': '4', 'description': 'Casual'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                                    2081
#                                                                                                                                                                                                                                                                                                                                                       ...
# [{'id': '1', 'description': 'Action'}, {'id': '25', 'description': 'Adventure'}, {'id': '4', 'description': 'Casual'}, {'id': '37', 'description': 'Free to Play'}, {'id': '29', 'description': 'Massively Multiplayer'}, {'id': '9', 'description': 'Racing'}, {'id': '28', 'description': 'Simulation'}, {'id': '2', 'description': 'Strategy'}]       1
# [{'id': '25', 'description': 'Adventure'}, {'id': '4', 'description': 'Casual'}, {'id': '37', 'description': 'Free to Play'}, {'id': '9', 'description': 'Racing'}, {'id': '28', 'description': 'Simulation'}, {'id': '18', 'description': 'Sports'}]                                                                                                    1
# [{'id': '1', 'description': 'Action'}, {'id': '25', 'description': 'Adventure'}, {'id': '4', 'description': 'Casual'}, {'id': '37', 'description': 'Free to Play'}, {'id': '23', 'description': 'Indie'}, {'id': '9', 'description': 'Racing'}, {'id': '18', 'description': 'Sports'}]                                                                   1
# [{'id': '71', 'description': 'Sexual Content'}, {'id': '1', 'description': 'Action'}, {'id': '23', 'description': 'Indie'}]                                                                                                                                                                                                                              1
# [{'id': '1', 'description': 'Action'}, {'id': '4', 'description': 'Casual'}, {'id': '29', 'description': 'Massively Multiplayer'}, {'id': '28', 'description': 'Simulation'}, {'id': '2', 'description': 'Strategy'}]                                                                                                                                    1
# Name: genres, Length: 2181, dtype: int64

# %%
spy["genres"].value_counts()
# Out:
# Action, Indie                                                                                                        3626
# Casual, Indie                                                                                                        3360
# Action, Adventure, Indie                                                                                             2924
# Adventure, Indie                                                                                                     2495
# Action, Casual, Indie                                                                                                1944
#                                                                                                                      ...
# Action, Casual, Free to Play, Indie, Massively Multiplayer, Racing, Strategy, Early Access                              1
# Action, Adventure, Casual, Free to Play, Indie, Massively Multiplayer, Simulation, Sports, Strategy, Early Access       1
# Casual, Free to Play, Indie, RPG, Simulation, Early Access                                                              1
# Free to Play, Massively Multiplayer, Simulation, Sports, Strategy, Early Access                                         1
# Violent, Action, Indie, Simulation                                                                                      1
# Name: genres, Length: 1488, dtype: int64

# %% [markdown]
# If there are no single commas inside any genre, it would make sense to list them exactly like Steam Spy has done. If not, we will look for a different character, or even just splitting it into a list, but something clearer than this dict form in string available for the Steam Store.

# %%
store["genres"].iloc[12]
# Out:
# "[{'id': '3', 'description': 'RPG'}]"

# %%
store["genres"].isnull().sum()
# Out:
# 114

# %%
def extractDict(weirdList, key):
    if weirdList != weirdList:
        return np.NaN
    else:
        try:
            evalList = eval(weirdList)
            phrase = ""
            # Warning : this works for a list of dicts. If we got a single dict, it will loop
            if(type(evalList) == dict):
                return evalList[key]
            else:
                for dictionary in evalList:
                    phrase += dictionary[key] + ", "
                return phrase[:-2]
        except :
            return np.NaN

# %% [markdown]
# A little explanation of above. Most games are indeed formatted with a dict inside. But there are a few ones (48), that after closer inspection already had the genre column formatted into the games of the genres separated by commas. Of these ones, there is only one valid game (one game that still exists in the store), https://store.steampowered.com/app/22330/The_Elder_Scrolls_IV_Oblivion_Game_of_the_Year_Edition/
#
# This was actually recovered with the update function we defined and executed above with the developers and publishers, the information is coming from steam spy.
#
# In any case, since the other invalid games will be deleted later, we make an exception if there is no dict and just return the actual string with a try and except. We will have to do something similar with the languages.

# %%
store["genres"] = store["genres"].apply(extractDict, key="description")

# %%
store["genres"]
# Out:
# id
# 10140                                                Sports
# 10240                                             Adventure
# 11050                                     Adventure, Casual
# 11230                                 Casual, Indie, Racing
# 12430                                                Casual
#                                 ...
# 673400                                Design & Illustration
# 673730                  Indie, Simulation, Audio Production
# 674010                             Action, Adventure, Indie
# 675230    Adventure, Casual, Free to Play, Massively Mul...
# 676480                                                Indie
# Name: genres, Length: 66653, dtype: object

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66653 entries, 10140 to 676480
# Data columns (total 38 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     66606 non-null  object
#  1   name                     66653 non-null  object
#  2   required_age             66606 non-null  object
#  3   is_free                  66606 non-null  object
#  4   controller_support       14409 non-null  object
#  5   dlc                      9341 non-null   object
#  6   detailed_description     66555 non-null  object
#  7   about_the_game           66553 non-null  object
#  8   short_description        66560 non-null  object
#  9   fullgame                 0 non-null      float64
#  10  supported_languages      66633 non-null  object
#  11  header_image             66606 non-null  object
#  12  website                  36099 non-null  object
#  13  pc_requirements          66606 non-null  object
#  14  mac_requirements         66606 non-null  object
#  15  linux_requirements       66606 non-null  object
#  16  legal_notice             19499 non-null  object
#  17  drm_notice               278 non-null    object
#  18  ext_user_account_notice  1124 non-null   object
#  19  developers               66653 non-null  object
#  20  publishers               66653 non-null  object
#  21  demos                    6006 non-null   object
#  22  price_overview           47343 non-null  object
#  23  packages                 47956 non-null  object
#  24  package_groups           66606 non-null  object
#  25  platforms                66606 non-null  object
#  26  metacritic               3726 non-null   object
#  27  reviews                  8871 non-null   object
#  28  categories               65663 non-null  object
#  29  genres                   66491 non-null  object
#  30  screenshots              66498 non-null  object
#  31  movies                   61644 non-null  object
#  32  recommendations          11669 non-null  object
#  33  achievements             30270 non-null  object
#  34  release_date             66606 non-null  object
#  35  support_info             66606 non-null  object
#  36  background               66512 non-null  object
#  37  content_descriptors      66606 non-null  object
# dtypes: float64(1), object(37)
# memory usage: 19.8+ MB

# %% [markdown]
# Let's see what we have in categories.

# %%
store["categories"].apply(extractDict, key="description")
# Out:
# id
# 10140                                         Single-player
# 10240                                         Single-player
# 11050                                         Single-player
# 11230                           Single-player, Multi-player
# 12430                                         Single-player
#                                 ...
# 673400                                                  NaN
# 673730                                        Single-player
# 674010    Single-player, Steam Achievements, Steam Works...
# 675230    Multi-player, MMO, PvP, Online PvP, Co-op, Onl...
# 676480    Single-player, Steam Achievements, Full contro...
# Name: categories, Length: 66653, dtype: object

# %% [markdown]
# Looking at rows with NaN values, there are a lot of games abandoned, mixed with applications which should have not been listed as games. We will drop any row which has NaNs in categories.

# %%
store["categories"].value_counts()
# Out:
# [{'id': 2, 'description': 'Single-player'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    18057
# [{'id': 2, 'description': 'Single-player'}, {'id': 22, 'description': 'Steam Achievements'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    6492
# [{'id': 2, 'description': 'Single-player'}, {'id': 28, 'description': 'Full controller support'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               2520
# [{'id': 2, 'description': 'Single-player'}, {'id': 18, 'description': 'Partial Controller Support'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            2407
# [{'id': 2, 'description': 'Single-player'}, {'id': 22, 'description': 'Steam Achievements'}, {'id': 23, 'description': 'Steam Cloud'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          2255
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# [{'id': 2, 'description': 'Single-player'}, {'id': 1, 'description': 'Multi-player'}, {'id': 49, 'description': 'PvP'}, {'id': 36, 'description': 'Online PvP'}, {'id': 37, 'description': 'Shared/Split Screen PvP'}, {'id': 9, 'description': 'Co-op'}, {'id': 38, 'description': 'Online Co-op'}, {'id': 39, 'description': 'Shared/Split Screen Co-op'}, {'id': 24, 'description': 'Shared/Split Screen'}, {'id': 22, 'description': 'Steam Achievements'}, {'id': 28, 'description': 'Full controller support'}, {'id': 35, 'description': 'In-App Purchases'}, {'id': 44, 'description': 'Remote Play Together'}]                                                                                                                                                            1
# [{'id': 2, 'description': 'Single-player'}, {'id': 1, 'description': 'Multi-player'}, {'id': 20, 'description': 'MMO'}, {'id': 49, 'description': 'PvP'}, {'id': 36, 'description': 'Online PvP'}, {'id': 47, 'description': 'LAN PvP'}, {'id': 9, 'description': 'Co-op'}, {'id': 38, 'description': 'Online Co-op'}, {'id': 48, 'description': 'LAN Co-op'}, {'id': 27, 'description': 'Cross-Platform Multiplayer'}, {'id': 35, 'description': 'In-App Purchases'}, {'id': 18, 'description': 'Partial Controller Support'}]                                                                                                                                                                                                                                                    1
# [{'id': 2, 'description': 'Single-player'}, {'id': 22, 'description': 'Steam Achievements'}, {'id': 29, 'description': 'Steam Trading Cards'}, {'id': 13, 'description': 'Captions available'}, {'id': 31, 'description': 'VR Support'}, {'id': 40, 'description': 'SteamVR Collectibles'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# [{'id': 2, 'description': 'Single-player'}, {'id': 1, 'description': 'Multi-player'}, {'id': 49, 'description': 'PvP'}, {'id': 36, 'description': 'Online PvP'}, {'id': 47, 'description': 'LAN PvP'}, {'id': 9, 'description': 'Co-op'}, {'id': 38, 'description': 'Online Co-op'}, {'id': 48, 'description': 'LAN Co-op'}, {'id': 27, 'description': 'Cross-Platform Multiplayer'}, {'id': 22, 'description': 'Steam Achievements'}, {'id': 13, 'description': 'Captions available'}, {'id': 30, 'description': 'Steam Workshop'}, {'id': 35, 'description': 'In-App Purchases'}, {'id': 18, 'description': 'Partial Controller Support'}, {'id': 23, 'description': 'Steam Cloud'}, {'id': 15, 'description': 'Stats'}, {'id': 25, 'description': 'Steam Leaderboards'}]        1
# [{'id': 2, 'description': 'Single-player'}, {'id': 1, 'description': 'Multi-player'}, {'id': 9, 'description': 'Co-op'}, {'id': 39, 'description': 'Shared/Split Screen Co-op'}, {'id': 24, 'description': 'Shared/Split Screen'}, {'id': 22, 'description': 'Steam Achievements'}, {'id': 13, 'description': 'Captions available'}, {'id': 18, 'description': 'Partial Controller Support'}, {'id': 25, 'description': 'Steam Leaderboards'}, {'id': 44, 'description': 'Remote Play Together'}]                                                                                                                                                                                                                                                                                  1
# Name: categories, Length: 5516, dtype: int64

# %%
store["categories"].head()
# Out:
# id
# 10140          [{'id': 2, 'description': 'Single-player'}]
# 10240          [{'id': 2, 'description': 'Single-player'}]
# 11050          [{'id': 2, 'description': 'Single-player'}]
# 11230    [{'id': 2, 'description': 'Single-player'}, {'...
# 12430          [{'id': 2, 'description': 'Single-player'}]
# Name: categories, dtype: object

# %% [markdown]
# There are actually tons of useful metadata here. This seems to be what is shown at the steam store webpage at the right.
#
# We might want to extract useful data in separate columns, such as Single Player, Multiplayer and also get/compare metadata with other columns regarding Achivements, controller support.
# There might be additional features which could be good to add to our analysis, such as Steam Workshop or Steam Cloud functionality.
#
# Let's see which categories we have that may be interesting, and how much it is repeated through our games.

# %%
def getCategoryList(series):
    lista = pd.Series(data="Single-player", index=[2])
    numbers = pd.Series(data=0, index=[2])
    
    for idx, value in series.iteritems():
        try:
            value = eval(value)
            for item in value:
                lista[item["id"]] = item["description"]
                try:
                    numbers[item["id"]]+=1
                except:
                    numbers[item["id"]] = 1
        except:
            False
    data = {"category": lista, "numbers": numbers}
    lista = pd.concat(data, axis = 1)
    return lista

# %%
lista = getCategoryList(store["categories"])

# %%
lista.sort_values(by="numbers")
# Out:
#                       category  numbers
# 6           Mods (require HL2)        2
# 19                        Mods        2
# 40        SteamVR Collectibles       43
# 51              Steam Workshop       45
# 16         Includes Source SDK       56
# 32    Steam Turn Notifications      108
# 8     Valve Anti-Cheat enabled      110
# 31                  VR Support      253
# 14        Commentary available      260
# 48                   LAN Co-op      610
# 47                     LAN PvP      659
# 41        Remote Play on Phone      714
# 42       Remote Play on Tablet      876
# 20                         MMO     1130
# 13          Captions available     1422
# 30              Steam Workshop     1746
# 35            In-App Purchases     1851
# 17       Includes level editor     1856
# 43           Remote Play on TV     2042
# 27  Cross-Platform Multiplayer     2106
# 39   Shared/Split Screen Co-op     2940
# 15                       Stats     3445
# 37     Shared/Split Screen PvP     3684
# 38                Online Co-op     4010
# 24         Shared/Split Screen     5060
# 44        Remote Play Together     5581
# 25          Steam Leaderboards     6032
# 36                  Online PvP     6501
# 9                        Co-op     7068
# 49                         PvP     8905
# 18  Partial Controller Support     9226
# 29         Steam Trading Cards     9401
# 1                 Multi-player    14092
# 28     Full controller support    14409
# 23                 Steam Cloud    15198
# 22          Steam Achievements    30768
# 2                Single-player    62067

# %% [markdown]
# We will extract the following data:
#
# `controller_support` : Available as a separate column already, but that one only includes Full Controller Support. Here we have Full and Partial, so let's add also that information.
#
# `achievements`, `cloud`, `trading_cards`, `leaderboards`, `workshop`, `level_editor` : False or True. These are popular Steam Features.
#
# `in_app_purchases`: Not really common in steam, but we actually have quite some games with it. True or False.
#
#
#
# Now about Multiplayer, Online, and so on there are a LOT of options. Remote Play does not make much sense, as it is in theory available for any game. We will make an exception for Remote Play Together as it allows you to share the game with a friend and play in a kind of stream / split screen. We will consider it as "Co-op". Let's try to divide them in sensible columns to avoid having a lot of separate columns with mixed meanings with the following logic:
#
# `single-Player`: The id that already identifies it.
#
# `multiplayer`: Its tag, and just in case, any of the other multiplayer tags.
#
# `online`: Online Co-op, Online PvP, Remote Play Together, Cross Platform Multiplayer, MMO
#
# `pvp`: True if PvP, shared/split screen PvP, Lan PVP, Online PvP.
#
# `co-op`: True if Co-op, shared/split screen Co-op, Lan Co-op, Online Co-op, Remote Play Together
#
# `local_multiplayer`: True if shared/split screen, and shared/split screen PvP or Co-op.
#
# `lan`: True if we get any of the LAN possibilities.
#
# `mmo` : True if MMO
#
# We will ignore other minor features such as captions, commentary... VR does not make much sense as there are more games which support VR than what is shown by this category, as we can check simply by doing a search on Steam (At least 5k games support VR https://store.steampowered.com/search/?category1=998&vrsupport=402). We should look at this separately.

# %%
def extractCategories(df):
    df["singleplayer"] = False
    df["multiplayer"] = False
    df["pvp"] = False
    df["co-op"] = False
    df["online"] = False
    df["local_multiplayer"] = False
    df["mmo"] = False
    df["lan"] = False
    df["achievements"] = False
    df["cloud"] = False
    df["trading_cards"] = False
    df["leaderboards"] = False
    df["workshop"] = False
    df["in_app_purchases"] = False
    df["level_editor"] = False
    df["controller_support"] = df["controller_support"].fillna("none")
    
    for idx, value in df["categories"].iteritems():
        try:
            value = eval(value)
            for item in value:
                cat = item["description"]
                if cat == "Single-player":
                    df.at[idx,"singleplayer"] = True
                    
                elif cat == "Multi-player":
                    df.at[idx,"multiplayer"] = True
                    
                elif cat == "PvP":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"pvp"] = True
                    
                elif cat == "Co-op":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"co-op"] = True
                    
                elif cat == "Online PvP":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"pvp"] = True
                    df.at[idx,"online"] = True
                    
                elif cat == "Online Co-op":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"co-op"] = True
                    df.at[idx,"online"] = True
                    
                elif cat == "Shared/Split Screen":
                    df.at[idx,"local_multiplayer"] = True
                    df.at[idx,"multiplayer"] = True
                    
                elif cat == "Shared/Split Screen PvP":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"pvp"] = True
                    df.at[idx,"local_multiplayer"] = True
                    
                elif cat == "Shared/Split Screen Co-op":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"co-op"] = True
                    df.at[idx,"local_multiplayer"] = True  
                    
                elif cat == "Cross-Platform Multiplayer":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"online"] = True                  
                    
                elif cat == "MMO":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"mmo"] = True
                    df.at[idx,"online"] = True

                elif cat == "LAN PvP":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"pvp"] = True
                    df.at[idx,"lan"] = True
                    
                elif cat == "LAN Co-op":
                    df.at[idx,"multiplayer"] = True
                    df.at[idx,"co-op"] = True
                    df.at[idx,"lan"] = True
                    
                elif cat == "Partial Controller Support":
                    df.at[idx,"controller_support"] = "partial"

                elif cat == "Full controller support":
                    df.at[idx,"controller_support"] = "full"
                    
                elif cat == "Steam Achievements":
                    df.at[idx,"achievements"] = True

                elif cat == "Steam Cloud":
                    df.at[idx,"cloud"] = True
                    
                elif cat == "Steam Trading Cards":
                    df.at[idx,"trading_cards"] = True
                    
                elif cat == "Steam Leaderboards":
                    df.at[idx,"leaderboards"] = True

                elif cat == "Steam Workshop":
                    df.at[idx,"workshop"] = True                    

                elif cat == "Includes level editor":
                    df.at[idx,"level_editor"] = True                    

                elif cat == "In-App Purchases":
                    df.at[idx,"in_app_purchases"] = True                     
        except:
            False
    return df

# %%
store = extractCategories(store)

# %%
store["in_app_purchases"].value_counts()
# Out:
# False    64802
# True      1851
# Name: in_app_purchases, dtype: int64

# %%
store["level_editor"].value_counts()
# Out:
# False    64797
# True      1856
# Name: level_editor, dtype: int64

# %%
store["workshop"].value_counts()
# Out:
# False    64892
# True      1761
# Name: workshop, dtype: int64

# %%
store["singleplayer"].value_counts()
# Out:
# True     62067
# False     4586
# Name: singleplayer, dtype: int64

# %%
store["multiplayer"].value_counts()
# Out:
# False    52449
# True     14204
# Name: multiplayer, dtype: int64

# %%
store["mmo"].value_counts()
# Out:
# False    65523
# True      1130
# Name: mmo, dtype: int64

# %%
store["local_multiplayer"].value_counts()
# Out:
# False    60755
# True      5898
# Name: local_multiplayer, dtype: int64

# %%
store["online"].value_counts()
# Out:
# False    58126
# True      8527
# Name: online, dtype: int64

# %%
store["achievements"].value_counts()
# Out:
# False    35885
# True     30768
# Name: achievements, dtype: int64

# %%
store["cloud"].value_counts()
# Out:
# False    51455
# True     15198
# Name: cloud, dtype: int64

# %%
store["trading_cards"].value_counts()
# Out:
# False    57252
# True      9401
# Name: trading_cards, dtype: int64

# %%
store["controller_support"].value_counts()
# Out:
# none       43031
# full       14396
# partial     9226
# Name: controller_support, dtype: int64

# %% [markdown]
# ´

# %%
store["pvp"].value_counts()
# Out:
# False    57639
# True      9014
# Name: pvp, dtype: int64

# %%
store["lan"].value_counts()
# Out:
# False    65697
# True       908
# Name: lan, dtype: int64

# %%
store["co-op"].value_counts()
# Out:
# False    59515
# True      7090
# Name: co-op, dtype: int64

# %% [markdown]
# Now that we've done this, let's at least check for games that do not have single player or multiplayer. Which does not make any sense.

# %%
store[~store["multiplayer"] & ~store["singleplayer"]]
# Out:
#         type                                            name is_free  \
# id
# 312860  game           Defense Grid 2: A Matter of Endurance   False
# 339510  game                                        Psy High   False
# 516130  game                                         Runner3   False
# 681410  game                          Adventures of the Worm   False
# 685770  game                               2D Mahjong Temple   False
# ...      ...                                             ...     ...
# 670470  game           MAGIX Video deluxe 2018 Steam Edition   False
# 671190  game                                   Pro Motion NG   False
# 672760  game                    Oneiric Masterpieces - Paris   False
# 672870  game                                      ScreenPlay    True
# 673400  game  Home Architect - Design your floor plans in 3D   False
#
#        controller_support    dlc  \
# id
# 312860               none  False
# 339510               none  False
# 516130               full   True
# 681410               none  False
# 685770               none  False
# ...                   ...    ...
# 670470               none  False
# 671190               none   True
# 672760               none  False
# 672870               none  False
# 673400               none  False
#
#                                      detailed_description  \
# id
# 312860                                                NaN
# 339510  When the kids at your high school start develo...
# 516130  The rhythm-music platformer gameplay of BIT.TR...
# 681410  Adventures of the Worm is a puzzle game in whi...
# 685770  <h1>🔥 Upcoming games - Wishlist now!</h1><p><a...
# ...                                                   ...
# 670470  <h1>New Version</h1><p><a href="https://store....
# 671190  An industry standard for two decades, talent f...
# 672760  The Oneiric Collection is the new way to visit...
# 672870  ScreenPlay is an Open Source cross-platform ap...
# 673400  <h1>Exclusive to the PREMIUM EDITION</h1><p><i...
#
#                                            about_the_game  \
# id
# 312860                                                NaN
# 339510  When the kids at your high school start develo...
# 516130  The rhythm-music platformer gameplay of BIT.TR...
# 681410  Adventures of the Worm is a puzzle game in whi...
# 685770  Experience Far Eastern Mahjong fun and help th...
# ...                                                   ...
# 670470  Introduction to video editing: <strong>Video d...
# 671190  An industry standard for two decades, talent f...
# 672760  The Oneiric Collection is the new way to visit...
# 672870  ScreenPlay is an Open Source cross-platform ap...
# 673400  <strong>Build and visit your dream house in a ...
#
#                                         short_description  fullgame  \
# id
# 312860                                                NaN       NaN
# 339510  Interactive teen supernatural mystery! You and...       NaN
# 516130  The rhythm-music gameplay of BIT.TRIP RUNNER a...       NaN
# 681410  Adventures of the Worm is a puzzle game in whi...       NaN
# 685770  Experience Far Eastern Mahjong fun and help th...       NaN
# ...                                                   ...       ...
# 670470  Create amazing videos with Video deluxe 2018 S...       NaN
# 671190  Pro Motion is not only a powerhouse of tools f...       NaN
# 672760  Oneiric Masterpieces - Paris is the most compl...       NaN
# 672870  ScreenPlay is an Open Source cross-platform ap...       NaN
# 673400  Home Architect – Design your floor plans in 3D...       NaN
#
#                                       supported_languages  ... trading_cards  \
# id                                                         ...
# 312860                             English, Not supported  ...         False
# 339510                                            English  ...         False
# 516130  English<strong>*</strong>, French, Italian, Ge...  ...         False
# 681410  English<strong>*</strong>, Czech<strong>*</str...  ...         False
# 685770  English, French, Italian, German, Spanish - Sp...  ...         False
# ...                                                   ...  ...           ...
# 670470  English, French, Italian, German, Spanish - Sp...  ...         False
# 671190                                            English  ...         False
# 672760  English<strong>*</strong><br><strong>*</strong...  ...         False
# 672870  English, German, French, Spanish - Spain, Russ...  ...         False
# 673400  English, French, Italian, German, Spanish - Sp...  ...         False
#
#        leaderboards  workshop in_app_purchases level_editor mature  \
# id
# 312860        False     False            False        False  False
# 339510        False     False            False        False  False
# 516130         True     False            False        False  False
# 681410        False     False            False        False  False
# 685770        False     False            False        False  False
# ...             ...       ...              ...          ...    ...
# 670470        False     False            False        False  False
# 671190        False     False            False        False  False
# 672760        False     False            False        False  False
# 672870        False      True            False        False  False
# 673400        False     False            False        False  False
#
#         total_positive total_negative total_reviews     rating
# id
# 312860               4             10            14  38.054619
# 339510             108             30           138  71.862434
# 516130             153             49           202  70.542298
# 681410               8              0             8  74.194375
# 685770               3              3             6  50.000000
# ...                ...            ...           ...        ...
# 670470              12             10            22  52.776746
# 671190              91              6            97  82.794006
# 672760               1              1             2  50.000000
# 672870               0              0             0   0.500000
# 673400               1              8             9  30.555556
#
# [1239 rows x 46 columns]

# %% [markdown]
# ### Metadata - Store
#
# The following columns have useful information (mostly only available at the storefront dataframe), and curiously all of them have the same non-null values . It could be interesting to check if all missing are from the same app ids. Since we will be missing crucial information with those games (specially the release date), we could just delete these rows.
#
# * type
# * required_age
# * is_free
# * header_image
# * pc_requirements
# * mac_requirements
# * linux_requirements
# * package_groups
# * platforms
# * release_date
# * support_info

# %%
store[store["type"].notnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66606 entries, 10140 to 676480
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     66606 non-null  object
#  1   name                     66606 non-null  object
#  2   required_age             66606 non-null  object
#  3   is_free                  66606 non-null  object
#  4   controller_support       66606 non-null  object
#  5   dlc                      9341 non-null   object
#  6   detailed_description     66555 non-null  object
#  7   about_the_game           66553 non-null  object
#  8   short_description        66560 non-null  object
#  9   fullgame                 0 non-null      float64
#  10  supported_languages      66586 non-null  object
#  11  header_image             66606 non-null  object
#  12  website                  36099 non-null  object
#  13  pc_requirements          66606 non-null  object
#  14  mac_requirements         66606 non-null  object
#  15  linux_requirements       66606 non-null  object
#  16  legal_notice             19499 non-null  object
#  17  drm_notice               278 non-null    object
#  18  ext_user_account_notice  1124 non-null   object
#  19  developers               66606 non-null  object
#  20  publishers               66606 non-null  object
#  21  demos                    6006 non-null   object
#  22  price_overview           47343 non-null  object
#  23  packages                 47956 non-null  object
#  24  package_groups           66606 non-null  object
#  25  platforms                66606 non-null  object
#  26  metacritic               3726 non-null   object
#  27  reviews                  8871 non-null   object
#  28  categories               65663 non-null  object
#  29  genres                   66491 non-null  object
#  30  screenshots              66498 non-null  object
#  31  movies                   61644 non-null  object
#  32  recommendations          11669 non-null  object
#  33  achievements             66606 non-null  bool
#  34  release_date             66606 non-null  object
#  35  support_info             66606 non-null  object
#  36  background               66512 non-null  object
#  37  content_descriptors      66606 non-null  object
#  38  singleplayer             66606 non-null  bool
#  39  multiplayer              66606 non-null  bool
#  40  pvp                      66606 non-null  bool
#  41  co-op                    66606 non-null  bool
#  42  online                   66606 non-null  bool
#  43  local_multiplayer        66606 non-null  bool
#  44  mmo                      66606 non-null  bool
#  45  lan                      66606 non-null  bool
#  46  cloud                    66606 non-null  bool
#  47  trading_cards            66606 non-null  bool
#  48  leaderboards             66606 non-null  bool
#  49  workshop                 66606 non-null  bool
#  50  in_app_purchases         66606 non-null  bool
#  51  level_editor             66606 non-null  bool
# dtypes: bool(15), float64(1), object(36)
# memory usage: 20.3+ MB

# %%
store[store["type"].isnull()]
# Out:
#         type                                               name required_age  \
# id
# 681810   NaN                 (Chinese PaladinSword and Fairy 6)          NaN
# 681820   NaN                 (Chinese PaladinSword and Fairy 4)          NaN
# 681830   NaN                 (Chinese PaladinSword and Fairy 5)          NaN
# 681840   NaN           Chinese PaladinSword and Fairy 5 Prequel          NaN
# 698600   NaN                                     Tooth and Claw          NaN
# 700740   NaN         Teenage Mutant Ninja Turtles: Portal Power          NaN
# 710130   NaN               (Hidden Dragon Legend: Shadow Trace)          NaN
# 799960   NaN                                          Wizard101          NaN
# 804780   NaN                                 VRでレムと異世界生活-膝枕&添寝編          NaN
# 806560   NaN                               VRでエミリアと異世界生活-膝枕&添寝編          NaN
# 847780   NaN                Castle of the Underdogs : Episode 1          NaN
# 881050   NaN                                      獣王/BEAST KING          NaN
# 895970   NaN                              BlackShot: Revolution          NaN
# 1094820  NaN                                  Adabana Odd Tales          NaN
# 1219160  NaN                               Granado Espada Japan          NaN
# 1242700  NaN                                    Ashland:Explore          NaN
# 1499560  NaN                                        LastCloudia          NaN
# 11610    NaN                                        Dragon Nest          NaN
# 12650    NaN                                     Fetch It Again          NaN
# 12660    NaN                                    Miss Popularity          NaN
# 15350    NaN                                          Brain Spa          NaN
# 19030    NaN                                      Rocket Knight          NaN
# 19080    NaN                                            Biozone          NaN
# 19810    NaN                               The Sum of All Fears          NaN
# 21130    NaN                       LEGO Harry Potter: Years 1-4          NaN
# 22490    NaN                                 Fallout: New Vegas          NaN
# 24720    NaN                          SPORE Galactic Adventures          NaN
# 29540    NaN                Guild Wars Game of the Year Edition          NaN
# 29570    NaN                                 Guild Wars Trilogy          NaN
# 33550    NaN                                    Time of Shadows          NaN
# 33700    NaN                      Paws and Claws: Pampered Pets          NaN
# 33710    NaN                         Paws and Claws: Pet School          NaN
# 33720    NaN                            Paws and Claws: Pet Vet          NaN
# 204120   NaN                       LEGO Harry Potter: Years 5-7          NaN
# 211070   NaN                                      Check vs Mate          NaN
# 212200   NaN                                           Mabinogi          NaN
# 212410   NaN                                          Inversion          NaN
# 215100   NaN                                    Ragnarok Online          NaN
# 230330   NaN  FINAL FANTASY XI: Ultimate Collection Seekers ...          NaN
# 710130                NaN       NaN  ...  False             False  False
# 799960                NaN       NaN  ...  False             False  False
# 804780                NaN       NaN  ...  False             False  False
# 806560                NaN       NaN  ...  False             False  False
# 847780                NaN       NaN  ...  False             False  False
# 881050                NaN       NaN  ...  False             False  False
# 895970                NaN       NaN  ...  False             False  False
# 1094820               NaN       NaN  ...  False             False  False
# 1219160               NaN       NaN  ...  False             False  False
# 1242700               NaN       NaN  ...  False             False  False
# 1499560               NaN       NaN  ...  False             False  False
# 11610                 NaN       NaN  ...  False             False  False
# 12650                 NaN       NaN  ...  False             False  False
# 12660                 NaN       NaN  ...  False             False  False
# 15350                 NaN       NaN  ...  False             False  False
# 19030                 NaN       NaN  ...  False             False  False
# 19080                 NaN       NaN  ...  False             False  False
# 19810                 NaN       NaN  ...  False             False  False
# 21130                 NaN       NaN  ...  False             False  False
# 22490                 NaN       NaN  ...  False             False  False
# 24720                 NaN       NaN  ...  False             False  False
# 29540                 NaN       NaN  ...  False             False  False
# 29570                 NaN       NaN  ...  False             False  False
# 33550                 NaN       NaN  ...  False             False  False
# 33700                 NaN       NaN  ...  False             False  False
# 33710                 NaN       NaN  ...  False             False  False
# 33720                 NaN       NaN  ...  False             False  False
# 204120                NaN       NaN  ...  False             False  False
# 211070                NaN       NaN  ...  False             False  False
# 212200                NaN       NaN  ...  False             False  False
# 212410                NaN       NaN  ...  False             False  False
# 215100                NaN       NaN  ...  False             False  False
# 230330                NaN       NaN  ...  False             False  False
# 231060                NaN       NaN  ...  False             False  False
# 239660                NaN       NaN  ...  False             False  False
# 289780                NaN       NaN  ...  False             False  False
# 300970                NaN       NaN  ...  False             False  False
# 328060                NaN       NaN  ...  False             False  False
# 362070                NaN       NaN  ...  False             False  False
# 433290                NaN       NaN  ...  False             False  False
# 660570                NaN       NaN  ...  False             False  False
#
#            lan  cloud trading_cards leaderboards workshop in_app_purchases  \
# id
# 681810   False  False         False        False    False            False
# 681820   False  False         False        False    False            False
# 681830   False  False         False        False    False            False
# 681840   False  False         False        False    False            False
# 698600   False  False         False        False    False            False
# 700740   False  False         False        False    False            False
# 710130   False  False         False        False    False            False
# 799960   False  False         False        False    False            False
# 804780   False  False         False        False    False            False
# 806560   False  False         False        False    False            False
# 847780   False  False         False        False    False            False
# 881050   False  False         False        False    False            False
# 895970   False  False         False        False    False            False
# 1094820  False  False         False        False    False            False
# 1219160  False  False         False        False    False            False
# 1242700  False  False         False        False    False            False
# 1499560  False  False         False        False    False            False
# 11610    False  False         False        False    False            False
# 12650    False  False         False        False    False            False
# 12660    False  False         False        False    False            False
# 15350    False  False         False        False    False            False
# 19030    False  False         False        False    False            False
# 19080    False  False         False        False    False            False
# 19810    False  False         False        False    False            False
# 21130    False  False         False        False    False            False
# 22490    False  False         False        False    False            False
# 24720    False  False         False        False    False            False
# 29540    False  False         False        False    False            False
# 29570    False  False         False        False    False            False
# 33550    False  False         False        False    False            False
# 33700    False  False         False        False    False            False
# 33710    False  False         False        False    False            False
# 33720    False  False         False        False    False            False
# 204120   False  False         False        False    False            False
# 211070   False  False         False        False    False            False
# 212200   False  False         False        False    False            False
# 212410   False  False         False        False    False            False
# 215100   False  False         False        False    False            False
# 230330   False  False         False        False    False            False
# 231060   False  False         False        False    False            False
# 239660   False  False         False        False    False            False
# 289780   False  False         False        False    False            False
# 300970   False  False         False        False    False            False
# 328060   False  False         False        False    False            False
# 362070   False  False         False        False    False            False
# 433290   False  False         False        False    False            False
# 660570   False  False         False        False    False            False
#
#         level_editor
# id
# 681810         False
# 681820         False
# 681830         False
# 681840         False
# 698600         False
# 700740         False
# 710130         False
# 799960         False
# 804780         False
# 806560         False
# 847780         False
# 881050         False
# 895970         False
# 1094820        False
# 1219160        False
# 1242700        False
# 1499560        False
# 11610          False
# 12650          False
# 12660          False
# 15350          False
# 19030          False
# 19080          False
# 19810          False
# 21130          False
# 22490          False
# 24720          False
# 29540          False
# 29570          False
# 33550          False
# 33700          False
# 33710          False
# 33720          False
# 204120         False
# 211070         False
# 212200         False
# 212410         False
# 215100         False
# 230330         False
# 231060         False
# 239660         False
# 289780         False
# 300970         False
# 328060         False
# 362070         False
# 433290         False
# 660570         False
#
# [47 rows x 52 columns]

# %%
store["type"].value_counts()
# Out:
# game           66605
# advertising        1
# Name: type, dtype: int64

# %% [markdown]
# It can be useful to at least check the value_counts of each column to detect any strange values.

# %%
store["required_age"].value_counts()
# Out:
# 0                                                                             41448
# 0.0                                                                           17165
# 0.0                                                                            6951
# 18                                                                              241
# 18.0                                                                            195
# 16                                                                              105
# 16.0                                                                            103
# 18.0                                                                             84
# 16.0                                                                             50
# 12                                                                               43
# 12.0                                                                             36
# 17.0                                                                             27
# 12.0                                                                             17
# 13.0                                                                             16
# 17.0                                                                             13
# 15.0                                                                             13
# 17                                                                               11
# 15                                                                               11
# 3.0                                                                               9
# 7                                                                                 8
# 3                                                                                 7
# 7.0                                                                               7
# 15.0                                                                              7
# 10.0                                                                              4
# 13.0                                                                              4
# 13                                                                                4
# 10                                                                                3
# 7.0                                                                               3
# 14                                                                                2
# 14.0                                                                              2
# 11                                                                                2
# 20                                                                                2
# 18+                                                                               2
# 19                                                                                1
# 6                                                                                 1
# 4                                                                                 1
# 3.0                                                                               1
# 5                                                                                 1
# javascript:ToggleCheckbox('checkbox_app_game_ratings_pegi_use_age_gate_');        1
# 1.0                                                                               1
# 99999                                                                             1
# 11.0                                                                              1
# 6.0                                                                               1
# １８                                                                                1
# Name: required_age, dtype: int64

# %%
getSteamLink(store[store["required_age"]==12.0])
# Out:
# Anachronox https://store.steampowered.com/app/242940
# Startopia https://store.steampowered.com/app/243040
# Starlight Inception™ https://store.steampowered.com/app/250720
# //N.P.P.D. RUSH//- The milk of Ultraviolet https://store.steampowered.com/app/270090
# LARA CROFT AND THE TEMPLE OF OSIRIS™ https://store.steampowered.com/app/289690
# Final Fantasy IV (3D Remake) https://store.steampowered.com/app/312750
# Tallowmere https://store.steampowered.com/app/340520
# CroNix https://store.steampowered.com/app/343630
# Ascent - The Space Game https://store.steampowered.com/app/345010
# FINAL FANTASY IV: THE AFTER YEARS https://store.steampowered.com/app/346830
# Poppy Kart https://store.steampowered.com/app/352530
# FINAL FANTASY X/X-2 HD Remaster https://store.steampowered.com/app/359870
# Contradiction - Spot The Liar! https://store.steampowered.com/app/373390
# FINAL FANTASY IX https://store.steampowered.com/app/377840
# Dungeon Nightmares II : The Memory https://store.steampowered.com/app/382090
# Mad Snowboarding https://store.steampowered.com/app/399900
# EARTH DEFENSE FORCE 4.1 The Shadow of New Despair https://store.steampowered.com/app/410320
# DRAGON QUEST HEROES™ Slime Edition https://store.steampowered.com/app/410850
# Dance of Death https://store.steampowered.com/app/430020
# Elemental Heroes https://store.steampowered.com/app/432290
# EARTH'S DAWN https://store.steampowered.com/app/494600
# G Prime https://store.steampowered.com/app/497430
# Nightshade／百花百狼 https://store.steampowered.com/app/512180
# Lost Crew https://store.steampowered.com/app/522010
# WORLD OF FINAL FANTASY® https://store.steampowered.com/app/552700
# Fastigium https://store.steampowered.com/app/552960
# DRAGON QUEST HEROES™ II https://store.steampowered.com/app/574050
# STAR OCEAN™ - THE LAST HOPE -™ 4K & Full HD Remaster https://store.steampowered.com/app/609150
# The Glade https://store.steampowered.com/app/637640
# Code51:Mecha Arena https://store.steampowered.com/app/640760
# Spartan VR https://store.steampowered.com/app/645860
# FINAL FANTASY®  XI: Ultimate Collection Seekers Edition https://store.steampowered.com/app/230350
# GRAY TANK https://store.steampowered.com/app/596570
# FINAL FANTASY V (Old ver.) https://store.steampowered.com/app/382890
# FINAL FANTASY VI (Old ver.) https://store.steampowered.com/app/382900
# MOBIUS FINAL FANTASY™ https://store.steampowered.com/app/536930

# %% [markdown]
# This column is really messy. Almost all games have a "0" value, which probably means no restriction, with then some with 18... and a lot of strange age values.
#
# According to PEGI the values should be 3, 7, 12, 16 and 18.
#
# This sounds like something that might be informed by the "content_descriptors" column.

# %%
store["content_descriptors"].value_counts()
# Out:
# {'ids': [], 'notes': None}                                                                                                                                                                                                                                                                                                                  55590
# {'ids': [2, 5], 'notes': None}                                                                                                                                                                                                                                                                                                                925
# {'ids': [1, 5], 'notes': None}                                                                                                                                                                                                                                                                                                                267
# {'ids': [5], 'notes': None}                                                                                                                                                                                                                                                                                                                   232
# {'ids': [1, 2, 5], 'notes': None}                                                                                                                                                                                                                                                                                                             178
#                                                                                                                                                                                                                                                                                                                                             ...
# {'ids': [1, 2, 5], 'notes': 'This game contains crude humor, minimal blood, infrequent use of strong language and a different view of the afterlife.\r\n\r\nThe player runs around killing robots and non-human creatures.   \r\n\r\nin the recent update, I added cut scene cinematic to the game which includes violence and nudity.'}        1
# {'ids': [2, 5], 'notes': 'Violence and gore\r\n'}                                                                                                                                                                                                                                                                                               1
# {'ids': [1, 2, 5], 'notes': '- There are lights that some players may be sensitive to.\r\n- There are gores (corpses) in the game.\r\n- There are sexual contents (nudity).'}                                                                                                                                                                   1
# {'ids': [5], 'notes': 'May contain content that is not appropriate for all ages. Some violence, blood and general mature content is present in the game.'}                                                                                                                                                                                      1
# It seems that content descriptor [2,5] adds this statement:
#
# The developers describe the content like this:
#
# This Game may contain content not appropriate for all ages, or may not be appropriate for viewing at work: Frequent Violence or Gore, General Mature Content
#
# They may add a note, but the keynote here is that [2] is frequent violence or gore, [5] means mature content.
# More details here:
# https://steamcommunity.com/games/593110/announcements/detail/1708442022337025126
#
# Honestly, seeing the stats from pegi https://pegi.info/page/statistics-about-pegi (around 16% of games are 18+), only about a thousand +18 seems bad.
#
# Anyhow, it seems these two columns should be simplified to +18 or nothing, since everything seems to be quite unregulated, and probably popular titles which are +18 are at least correctly rated. It is unclear if this information would be useful, but this is the only source available and this makes the most sensible choice to at least show some value.
#
# Let's check a very popular +18 title and see if it makes sense.
# https://store.steampowered.com/app/271590/Grand_Theft_Auto_V/

# %%
print(store.loc[271590]["required_age"], store.loc[271590]["content_descriptors"])
# Out:
# 17.0 {'ids': [5], 'notes': None}

# %% [markdown]
# It seems it might make sense to put as +18 any title with required age 17 or more, OR if it has the id 5 which means mature content.

# %%
store["is_free"].value_counts()
# Out:
# False    59073
# True      7533
# Name: is_free, dtype: int64

# %%
store["pc_requirements"].value_counts()
# Out:
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 7</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    226
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    82
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10, Windows 8, Windows 7 32-bit<br></li><li><strong>Processor:</strong> Quad-core Intel or AMD processor, 2 GHz or faster<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> 1 Gb<br></li><li><strong>DirectX:</strong> Version 10<br></li><li><strong>Storage:</strong> 1 GB available space</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10, Windows 8, Windows 7 32-bit<br></li><li><strong>Processor:</strong> Quad-core Intel or AMD processor, 2.5 GHz or faster<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> 2 Gb<br></li><li><strong>DirectX:</strong> Version 11<br></li><li><strong>Storage:</strong> 1 GB available space</li></ul>'}     80
# []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             74
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> 7</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             65
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system<br></li><li><strong>OS:</strong> Microsoft Windows 10<br></li><li><strong>Graphics:</strong> Geforce GTX 1050 Ti<br></li><li><strong>Network:</strong> Broadband Internet connection</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li>Requires a 64-bit processor and operating system</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows xp<br></li><li><strong>Memory:</strong> 1 GB RAM<br></li><li><strong>Storage:</strong> 70 MB available space</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 7<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Storage:</strong> 100 MB available space</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> windows 7+<br></li><li><strong>Processor:</strong> Intel i5+<br></li><li><strong>Memory:</strong> 2 GB RAM<br></li><li><strong>Graphics:</strong> Nvidia 450 GTS / Radeon HD 5750 or better<br></li><li><strong>DirectX:</strong> Version 9.0<br></li><li><strong>Storage:</strong> 500 MB available space</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 7+<br></li><li><strong>Processor:</strong> Intel i5+<br></li><li><strong>Memory:</strong> 4 GB RAM<br></li><li><strong>Graphics:</strong> Nvidia GTX 460 / Radeon HD 7800 or better<br></li><li><strong>DirectX:</strong> Version 9.0<br></li><li><strong>Storage:</strong> 500 MB available space</li></ul>'}                                                                  1
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows 10<br></li><li><strong>Additional Notes:</strong> Requires a 64-bit processor and operating system</li></ul>', 'recommended': '<strong>Recommended:</strong><br><ul class="bb_ul"><li><strong>Additional Notes:</strong> Requires a 64-bit processor and operating system</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# {'minimum': '<strong>Minimum:</strong><br><ul class="bb_ul"><li><strong>OS:</strong> Windows XP, Vista, 7, 8, or 10<br></li><li><strong>Processor:</strong> 2.0 ghz<br></li><li><strong>Memory:</strong> 1 GB RAM<br></li><li><strong>Graphics:</strong> 128MB<br></li><li><strong>Storage:</strong> 80 MB available space</li></ul>'}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1
# Name: pc_requirements, Length: 60671, dtype: int64

# %% [markdown]
# This could be useful information, but it is html formatted, and not standard. We will keep not clean it at all, and we will separate it from our main table at the end, in case someone needs this information. The same happens with the mac and linux requirements.
#
# If a developer wants to look what systems the users have, it is better to just use the steam survey: https://store.steampowered.com/hwsurvey

# %%
print(store.iloc[0]["header_image"])
# Out:
# https://cdn.akamai.steamstatic.com/steam/apps/10140/header.jpg?t=1534443458

# %% [markdown]
# This column just gives us a link to a header image. This could be useful in the visualization phase, if we want to highlight any particular game.

# %%
store.iloc[0]["package_groups"]
# Out:
# "[{'name': 'default', 'title': 'Buy 3D Ultra™ Minigolf Adventures', 'description': '', 'selection_text': 'Select a purchase option', 'save_text': '', 'display_type': 0, 'is_recurring_subscription': 'false', 'subs': [{'packageid': 1873, 'percent_savings_text': ' ', 'percent_savings': 0, 'option_text': '3D Ultra Mini Golf Adventures - 9,99€', 'option_description': '', 'can_get_free_license': '0', 'is_free_license': False, 'price_in_cents_with_discount': 999}]}]"

# %% [markdown]
# This seems the information about in which packs is this game available. Let's try looking for a game which is by itself and in a pack to confirm it.
# https://store.steampowered.com/app/413410/Danganronpa_Trigger_Happy_Havoc/

# %%
store.loc[413410]["package_groups"]
# Out:
# '[{\'name\': \'default\', \'title\': \'Buy Danganronpa: Trigger Happy Havoc\', \'description\': \'\', \'selection_text\': \'Select a purchase option\', \'save_text\': \'\', \'display_type\': 0, \'is_recurring_subscription\': \'false\', \'subs\': [{\'packageid\': 82833, \'percent_savings_text\': \'-60% \', \'percent_savings\': 0, \'option_text\': \'Danganronpa: Trigger Happy Havoc - <span class="discount_original_price">19,99€</span> 7,99€\', \'option_description\': \'\', \'can_get_free_license\': \'0\', \'is_free_license\': False, \'price_in_cents_with_discount\': 799}]}]'

# %% [markdown]
# Well... the packs are not visible here, only the game by itself. We have some metadata related to the buy box, and also a discount which was present at the time. Depending on how the price_overview is, this might be useful to complete it. But the format is a bit messy (not standard, see those two examples), so it would be best to avoid it and erase this column.

# %%
store["platforms"].value_counts()
# Out:
# {'windows': True, 'mac': False, 'linux': False}    49841
# {'windows': True, 'mac': True, 'linux': True}       7895
# {'windows': True, 'mac': True, 'linux': False}      6965
# {'windows': True, 'mac': False, 'linux': True}      1883
# {'windows': False, 'mac': True, 'linux': False}       15
# {'windows': False, 'mac': False, 'linux': True}        6
# {'windows': False, 'mac': True, 'linux': True}         1
# Name: platforms, dtype: int64

# %% [markdown]
# We will need to change the format to separated comma values, but the information is good.

# %%
store["release_date"].value_counts()
# Out:
# {'coming_soon': True, 'date': '2022'}                                1125
# {'coming_soon': True, 'date': 'TBA'}                                  834
# {'coming_soon': True, 'date': 'Coming Soon'}                          653
# {'coming_soon': True, 'date': ''}                                     399
# {'coming_soon': True, 'date': 'TBD'}                                  251
#                                                                      ...
# {'coming_soon': True, 'date': 'early access is planned for 2022'}       1
# {'coming_soon': True, 'date': 'Date Soon'}                              1
# {'coming_soon': True, 'date': '12 Sep, 2022'}                           1
# {'coming_soon': True, 'date': 'Early 2022 - Wishlist Now! 🔔'}           1
# {'coming_soon': True, 'date': 'Падажжите скора будет'}                  1
# Name: release_date, Length: 6363, dtype: int64

# %% [markdown]
# Here we have two different fields, one if the game has already released or not (coming_soon) and we also have the date. The date seems to be free text for the unreleased games, but we should check if it has always the same format for the already released.

# %%
store["release_date"].sample(n=10)
# Out:
# id
# 740990      {'coming_soon': False, 'date': '6 Dec, 2017'}
# 1341230    {'coming_soon': False, 'date': '19 Nov, 2020'}
# 1037570    {'coming_soon': False, 'date': '28 Apr, 2019'}
# 1277360    {'coming_soon': False, 'date': '25 Apr, 2020'}
# 833440     {'coming_soon': False, 'date': '11 Oct, 2018'}
# 1508660     {'coming_soon': False, 'date': '7 Feb, 2021'}
# 1112950    {'coming_soon': False, 'date': '25 Jul, 2019'}
# 1264050    {'coming_soon': False, 'date': '26 Mar, 2021'}
# 363960      {'coming_soon': False, 'date': '6 Oct, 2015'}
# 1254160    {'coming_soon': False, 'date': '29 Jun, 2020'}
# Name: release_date, dtype: object

# %% [markdown]
# After testing a few, it looks like that, free text if it is not released, but formated in  day Month, year otherwise. We will revisit this when we change it. Since the free text will be troublesome, maybe we can keep this in one columns with the real date if it has been release, and False if it has not released.

# %%
store["support_info"].value_counts()
# Out:
# {'url': '', 'email': ''}                                                                                  1008
# {'url': 'https://bigfishgames.custhelp.com/app/home', 'email': 'info@bigfishgames.com'}                    221
# {'url': 'https://www.facebook.com/8FloorGames', 'email': 'mikhail.zverev@8floor.net'}                      195
# {'url': '', 'email': 'support@quanticlab.com'}                                                             136
# {'url': '', 'email': 'mail@garage-games.ru'}                                                               118
#                                                                                                           ...
# {'url': '', 'email': 'josh@broodlingstudios.com'}                                                            1
# {'url': 'http://www.poorrolemodel.com/', 'email': ''}                                                        1
# {'url': '', 'email': 'evgeniy7000@gmail.com'}                                                                1
# {'url': 'gnosgames.com', 'email': 'gnosgames@gmail.com'}                                                     1
# {'url': 'http://knightandninjagames.com/pages/contact.html', 'email': 'knightandninjagames@gmail.com'}       1
# Name: support_info, Length: 44737, dtype: int64

# %% [markdown]
# This information is listed on each steam store page, but it does not seem to be mandatory. That makes sense, as steam hosts a forum for each game, called "steam discussions". We can safely delete this column as it has no use for our analysis. It could be perhaps used to enrich developer or publisher data, but we have those columns quite clean.
#
# In case it is useful for anybody, we will keep it separated.

# %%
store["website"].value_counts()
# Out:
# https://www.facebook.com/8FloorGames/            171
# https://www.choiceofgames.com/                   152
# https://steamcommunity.com/groups/alawargames     71
# http://www.exosyphen.com                          68
# https://www.facebook.com/DnovelGames/             65
#                                                 ...
# https://pqube.co.uk/gal-gun-returns/               1
# http://www.daedalus-thegame.com/                   1
# http://www.octodadgame.com                         1
# http://www.gamecity.com.tw/souzou/                 1
# http://deanforge.com/                              1
# Name: website, Length: 30002, dtype: int64

# %%
store["ext_user_account_notice"].value_counts()
# Out:
# Uplay (Supports Linking to Steam Account)                                                                                                                                                   40
# EA Account (Supports Linking to Steam Account)                                                                                                                                              30
# Slitherine PBEM++ for Multiplayer                                                                                                                                                           27
# PlayFab (Supports Linking to Steam Account)                                                                                                                                                 25
# Ubisoft Account (Supports Linking to Steam Account)                                                                                                                                         23
#                                                                                                                                                                                             ..
# Nonage                                                                                                                                                                                       1
# Su Hack - El Tech (Supports Linking to Steam Account)                                                                                                                                        1
# andre monteiro de paula                                                                                                                                                                      1
# Download of Companion App from Google Play                                                                                                                                                   1
# The 30XX Editor requires a (totally free) account to use. The base 30XX game does not require a third party account of any kind - you only need to create an account to use the Editor.      1
# Name: ext_user_account_notice, Length: 782, dtype: int64

# %% [markdown]
# #### Metadata - Store: First Columns
#
# We can confirm that there is a group of "metadata" columns had the same rows with nans, so we will drop those rows. Looking at the IDs directly on steam, we cannot even catch its webpage - they mostly seem betas,old non-functional demos or tests...
#
# * To clean the following columns from NaN, we will simply keep the rows with values from any of the columns as the missing info is from the same rows.
# `type  required_age  is_free  header_image  pc_requirements  mac_requirements  linux_requirements package_groups  platforms  release_date  support_info`
#
# Additional cleaning required:
#
# `type`
# * We will drop the only 2 app_ids which are not games.
#
# `required_age content_descriptors`
# * A new column will be created with Mature being True or False. If the game is 17+, or it has an id in content_descriptors of a mature game, it will be considered Mature.
#
# `is_free`
# * Already clean, True or False.
#
# `header_image`
# * Will be kept to aid our visualizations. Might be interested for Image based ML.
#
# `pc_requirements  mac_requirements  linux_requirements`
# * We will not treat this, it will be separated from the main dataframe as it is not useful and poorly formatted.
#
# `package_groups`
# * Eventually this will be dropped, but we will see if it could be used for any errors in the price column.
#
# `platforms`
# * We need to change it into separated comma values.
#
# `release_date`
# * The format will be changed to a single date if it has been released, or False if it has not been released yet.
#
# `support_info`
# * We will not treat this, it will be separated from the main dataframe as it is not useful.
#
# After some review, as we have a few additional columns that is clear that we will not use, but could be useful for a ML image oriented approach... we will also separate `movies`, `screenshots`, `background`, `website` in this step.

# %% [markdown]
# #### Metadata - Store: Columns with a lot of NaNs
#
# Next we have the following columns:
#
# * `metacritic` : The numeric value if available, False if it has no value.
# * `reviews` : It is free text, so we will change it to True or False. Meaning True = there was a profesional review linked.
# * `recommendations` : After inspecting this, it seems linked to the user reviews on Steam. But we got only the total recommendations and also we have tons of NaN, which makes no sense. We will get this information from other places.
#
#
#
# * `demos`
# * `drm_notice`
# * `dlc`
#
# In this case, this group deals with features. The game may have a demo, it uses DRM, it has DLC. We will check these and see if they can be turned into a True / False column with no NaNs.
#
# * `fullgame`: Useless column filled with NaNs.
# * `legal_notice`: This has no useful information for us.
# * `ext_user_account_notice`: This tells us if we need to link an external account (such as uplay for Ubisoft, or Origin in case of EA). It is not clear if it will be useful but we will keep it anyway. Let's add False for all these cases where we got no notice.

# %%
def isAgeMature(age):
    age = str(age)
    try:
        x = re.search("\d+", age).group()
        x = int(x)
    except:
        return False
    if 16 < x < 30:
        return True
    else:
        return False

def isDescriptorMature(descriptor):
    try :
        ids = eval(descriptor)["ids"]
        if 5 in ids:
            return True
        else:
            return False
    except :
        return False

def getMatureMetadata(store):
    store["required_age"] = store["required_age"].apply(isAgeMature)
    store["content_descriptors"] = store["content_descriptors"].apply(isDescriptorMature)
    store["mature"] = store["required_age"] | store["content_descriptors"]
    store = store.drop(columns=["required_age", "content_descriptors"])
    return store

def getMyPlatform(value):
    if value == "{'windows': True, 'mac': False, 'linux': False}":
        return "Windows"
    elif value == "{'windows': True, 'mac': True, 'linux': True}":
        return "Windows, Mac, Linux"
    elif value == "{'windows': True, 'mac': True, 'linux': False}":
        return "Windows, Mac"
    elif value == "{'windows': False, 'mac': True, 'linux': False}":
        return "Mac"
    elif value == "{'windows': False, 'mac': False, 'linux': True}":
        return "Linux"
    elif value == "{'windows': True, 'mac': False, 'linux': True}":
        return "Windows, Linux"
    else:
        return "Mac, Linux"

def getPlatforms(store):
    store["platforms"] = store["platforms"].apply(getMyPlatform)
    return store

def getReleaseDate(value):
    if extractDict(value,"coming_soon") == True:
        return False
    else:
        thisDate = extractDict(value, "date")
        return pd.to_datetime(thisDate)

def getMetacritic(value):
    try :
        score = eval(value)["score"]
        return int(score)
    except :
        return False
    
def getCleanMetadata(store):
    # This takes care of both cleaning the NaN without these metadata, and the types we do not want
    store = store[store["type"]=="game"].copy()
    
    store = getMatureMetadata(store)
    
    extra = store.loc[:,["name","support_info", "header_image", "website",
                         "pc_requirements","mac_requirements","linux_requirements",
                         "background","screenshots","movies"]].copy()
    
    store = getPlatforms(store)
    
    store["metacritic"] = store["metacritic"].apply(getMetacritic)
    
    store["demos"] = ~store["demos"].isna()
    
    store["reviews"] = ~store["reviews"].isna()
    
    store["drm_notice"] = ~store["drm_notice"].isna()
    
    store["dlc"] = ~store["dlc"].isna()
    
    store["release_date"] = store["release_date"].apply(getReleaseDate)
    
    store["ext_user_account_notice"] = store["ext_user_account_notice"].fillna(False)
    
    store = store.rename(columns={"drm_notice":"drm"})
    
    store = store.drop(columns=["pc_requirements","mac_requirements","linux_requirements",
                         "background","screenshots","movies","support_info",
                               "website", "fullgame"])
    
    
    return store, extra

# %%
store, extra = getCleanMetadata(store)

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66605 entries, 10140 to 676480
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     66605 non-null  object
#  1   name                     66605 non-null  object
#  2   is_free                  66605 non-null  object
#  3   controller_support       66605 non-null  object
#  4   dlc                      66605 non-null  bool
#  5   detailed_description     66554 non-null  object
#  6   about_the_game           66552 non-null  object
#  7   short_description        66559 non-null  object
#  8   fullgame                 0 non-null      float64
#  9   supported_languages      66585 non-null  object
#  10  header_image             66605 non-null  object
#  11  legal_notice             19498 non-null  object
#  12  drm                      66605 non-null  bool
#  13  ext_user_account_notice  1124 non-null   object
#  14  developers               66605 non-null  object
#  15  publishers               66605 non-null  object
#  16  demos                    66605 non-null  bool
#  17  price_overview           47343 non-null  object
#  18  packages                 47956 non-null  object
#  19  package_groups           66605 non-null  object
#  20  platforms                66605 non-null  object
#  21  metacritic               66605 non-null  object
#  22  reviews                  66605 non-null  bool
#  23  categories               65663 non-null  object
#  24  genres                   66491 non-null  object
#  25  recommendations          11669 non-null  object
#  26  achievements             66605 non-null  bool
#  27  release_date             66507 non-null  object
#  28  singleplayer             66605 non-null  bool
#  29  multiplayer              66605 non-null  bool
#  30  pvp                      66605 non-null  bool
#  31  co-op                    66605 non-null  bool
#  32  online                   66605 non-null  bool
#  33  local_multiplayer        66605 non-null  bool
#  34  mmo                      66605 non-null  bool
#  35  lan                      66605 non-null  bool
#  36  cloud                    66605 non-null  bool
#  37  trading_cards            66605 non-null  bool
#  38  leaderboards             66605 non-null  bool
#  39  workshop                 66605 non-null  bool
#  40  in_app_purchases         66605 non-null  bool
#  41  level_editor             66605 non-null  bool
#  42  mature                   66605 non-null  bool
# dtypes: bool(20), float64(1), object(22)
# memory usage: 13.5+ MB

# %% [markdown]
# The most noticeable thing is that we got missing

# %% [markdown]
# ### Reviews/Recommendations
#
# This is one of the more important features we want. What is the number of total reviews / recommendations, which might give us insights on how many copies were sold, and has the game been received positively?

# %%
store["recommendations"]
# Out:
# id
# 10140                NaN
# 10240                NaN
# 11050     {'total': 166}
# 11230     {'total': 310}
# 12430     {'total': 101}
#                ...
# 673400               NaN
# 673730               NaN
# 674010               NaN
# 675230               NaN
# 676480               NaN
# Name: recommendations, Length: 66605, dtype: object

# %% [markdown]
# This column is the number of total user reviews in steam. There are some NaNs, and if we check the Steam Store it does not show the same numbers. We have to tackle this column together with the positive/negative reviews from steam spy.
#
# Here we must make a decision. Steam does not give us any metric of success except the number of total reviews. From Steam Spy, we can calculate the ratio of positive / total number of reviews. Should we forget about this column from Steam, and instead only keep records with positive/negative information from Steam Spy?

# %%
store["reviews"]
# Out:
# id
# 10140     False
# 10240     False
# 11050      True
# 11230     False
# 12430     False
#           ...
# 673400    False
# 673730    False
# 674010    False
# 675230    False
# 676480     True
# Name: reviews, Length: 66605, dtype: bool

# %%
store["metacritic"]
# Out:
# id
# 10140     False
# 10240     False
# 11050        70
# 11230     False
# 12430     False
#           ...
# 673400    False
# 673730    False
# 674010    False
# 675230    False
# 676480    False
# Name: metacritic, Length: 66605, dtype: object

# %%
getSteamLink(store.head())
# Out:
# 3D Ultra™ Minigolf Adventures https://store.steampowered.com/app/10140
# A Stroke of Fate: Operation Valkyrie https://store.steampowered.com/app/10240
# Dracula: Origin https://store.steampowered.com/app/11050
# Gumboy Tournament https://store.steampowered.com/app/11230
# SlamIt Pinball Big Score https://store.steampowered.com/app/12430

# %% [markdown]
# I am just going to check Dracula origins to understand what these fields are telling us.
#
# Ok, so from `reviews` it seems the game has a professional review listed here, chosen by hand as it is a positive one. It might be worth it to make this into a True False (professional reviews) as we cannot get the data about the score.
#
# The same game shows the `metacritic` score, even if it is not a very good one, we might want to parse this into the numeric score or False if it does not have a metacritic score.
#
# Let's get back to user reviews in Steam.

# %%
print(spy.loc[10]["name"]+" "+"+"+str(spy.loc[10]["positive"])+"/"+str(spy.loc[10]["positive"]+spy.loc[10]["negative"]))
# Out:
# Counter-Strike +193046/197986

# %%
print(store.loc[10]["name"]+" "+str(store.loc[10]["recommendations"]))
# Out:
# Counter-Strike {'total': 118156}

# %%
getSteamLink(store[store["name"].str.contains("Counter-Strike")])
# Out:
# Counter-Strike https://store.steampowered.com/app/10
# Counter-Strike: Condition Zero https://store.steampowered.com/app/80
# Counter-Strike: Source https://store.steampowered.com/app/240
# Counter-Strike: Global Offensive https://store.steampowered.com/app/730
# Counter-Strike Nexon: Studio https://store.steampowered.com/app/273110

# %% [markdown]
# Looking at Steam directly, the number of total recommendations from the Steam Store is actually accurate (around 119k). So why do we have in this case (one of the first games available on Steam) such a huge divergence? Let's try comparing a newer game. Maybe some of these accounts got disabled in time, or steam at some point redid the review system...
#
# https://store.steampowered.com/app/548430/Deep_Rock_Galactic/
#
# 97% of 98762 reviews are positive. This was taken almost a month after the data from the APIs.

# %%
print(spy.loc[548430]["name"]+" "+"+"+str(spy.loc[548430]["positive"])+"/"+str(spy.loc[548430]["positive"]+spy.loc[548430]["negative"])+" "+str(spy.loc[548430]["positive"]*100/(spy.loc[548430]["positive"]+spy.loc[548430]["negative"])))
# Out:
# Deep Rock Galactic +117228/120917 96.94914693550122

# %%
print(store.loc[548430]["name"]+" "+str(store.loc[548430]["recommendations"]))
# Out:
# Deep Rock Galactic {'total': 96680}

# %% [markdown]
# At least the percentage matches.
# Let's try a newer game, one from 3rd Quarter 2021. It will not make sense checking the webpage directly, as now there will be a lot of newer reviews.
#
# https://store.steampowered.com/app/1551360/Forza_Horizon_5/
# (59,855) 86%

# %%
print(spy.loc[1551360]["name"]+" "+"+"+str(spy.loc[1551360]["positive"])+"/"+str(spy.loc[1551360]["positive"]+spy.loc[1551360]["negative"])+" "+str(spy.loc[1551360]["positive"]*100/(spy.loc[1551360]["positive"]+spy.loc[1551360]["negative"])))
# Out:
# Forza Horizon 5 +53761/62209 86.41997138677684

# %%
print(store.loc[1551360]["name"]+" "+str(store.loc[1551360]["recommendations"]))
# Out:
# Forza Horizon 5 {'total': 54837}

# %% [markdown]
# In any case, the metrics are similar, and the most important one (percentage) could be obtained with steam spy and matches the steam store page. As we have a lot of NaNs from steam, we will trust Steam Spy here, although it is puzzling why the numbers do not match. Maybe Steam Spy registers re-reviews as two different reviews?.
#
# Looking for an alternative, it seems possible to get the information from Steam API (partners) directly. Initially I thought it was not going to be possible as it is in the partners side. See this query for example:
#
# https://store.steampowered.com/appreviews/10?json=1?&num_per_page=0?&language=all
#
# Note: it is important to put language=all, otherwise we get fewer results for the totals.
#
# At the end, we went this route and documented everything in the data collection section. As a result we got the following dataset: `steamreviews_data.csv`

# %%
steamreviews = pd.read_csv('../data/download/steamreviews_data.csv')

# %%
steamreviews
# Out:
#         appid  review_score review_score_desc  total_positive  total_negative  \
# 0       10140             5             Mixed              59              32
# 1       10240             5             Mixed              16               8
# 2       11050             5             Mixed             114              56
# 3       11230             6   Mostly Positive             224              84
# 4       12430             4   Mostly Negative              33              68
# ...       ...           ...               ...             ...             ...
# 66798  673400             0    9 user reviews               1               8
# 66799  673730             0    1 user reviews               1               0
# 66800  674010             0    2 user reviews               0               2
# 66801  675230             0   No user reviews               0               0
# 66802  676480             6   Mostly Positive              55              15
#
#        total_reviews
# 0                 91
# 1                 24
# 2                170
# 3                308
# 4                101
# ...              ...
# 66798              9
# 66799              1
# 66800              2
# 66801              0
# 66802             70
#
# [66803 rows x 6 columns]

# %% [markdown]
# Here we have several columns but with dependant information. In reality, only total positive and total negative are unique values. What will be important for us later on?
#
# * Total reviews: Gives us insight on number of sales
# * Review score: Gives us insight on how well appreciated the game is.
#
# So in that sense, we should only care about two columns. But since this is key information, we will keep total_positive, total_negative, total_reviews and feature a new column for the score.
#
# Let's take steamdb advice on how to calculate the rating: https://steamdb.info/stats/gameratings/
# In summary, what will happen is that games with very few reviews will tend to have a 50% rating, and in a logarithmic scale we will get more sure (twice sure) that the actual ratio of positive/total reviews is correct.
#
# So a game with 1 positive review is actually 50% regardless of the review, a game with 10 out of 10 positives reviews will be 50% x 0.5 + 100% x 0.5 = 75%. If we have 100 reviews (all positive) then it would be 87.5%.
#
# Let's see if this might be unfair. Do we have many games below 50% pure rating?

# %%
steamreviews["review_score"].value_counts()
# Out:
# 0    36853
# 8     8178
# 5     7630
# 7     6444
# 6     5331
# 4     1313
# 9      746
# 3      264
# 2       37
# 1        7
# Name: review_score, dtype: int64

# %% [markdown]
# Mostly there are unrated games (which at this point means less than 10 reviews), then we have around 26k games between 5 and 8. There are only about 1.5k bad games (1 to 4), and most of them are just bad (4). And we have 746 excellent games.
#
# So it seems that it is reasonable to use the algorithm above to calculate the rating.

# %%
steamreviews["rating"] = (steamreviews["total_positive"]/steamreviews["total_reviews"] - (steamreviews["total_positive"]/steamreviews["total_reviews"] -0.5)*np.power(2,-np.log10(steamreviews["total_reviews"]+1)))*100

# %%
steamreviews.head()
# Out:
#    appid  review_score review_score_desc  total_positive  total_negative  \
# 0  10140             5             Mixed              59              32
# 1  10240             5             Mixed              16               8
# 2  11050             5             Mixed             114              56
# 3  11230             6   Mostly Positive             224              84
# 4  12430             4   Mostly Negative              33              68
#
#    total_reviews     rating
# 0             91  61.032103
# 1             24  60.342157
# 2            170  63.430130
# 3            308  68.681559
# 4            101  36.979205

# %%
steamreviews.sort_values(by="rating", ascending=False).head()
# Out:
#          appid  review_score        review_score_desc  total_positive  \
# 30898      620             9  Overwhelmingly Positive          227794
# 14429  1118200             9  Overwhelmingly Positive           90690
# 38521   427520             9  Overwhelmingly Positive          107963
# 15275  1145360             9  Overwhelmingly Positive          164786
# 32114   105600             9  Overwhelmingly Positive          715943
#
#        total_negative  total_reviews     rating
# 30898            2760         230554  97.616870
# 14429             946          91636  97.396651
# 38521            1222         109185  97.393155
# 15275            2217         167003  97.369054
# 32114           14293         730236  97.217507

# %% [markdown]
# Let's see which are these fantastic games!

# %%
store.loc[steamreviews.sort_values(by="rating", ascending=False).head()["appid"]]
# Out:
#          type               name is_free controller_support    dlc  \
# id
# 620      game           Portal 2   False               full   True
# 1118200  game  People Playground   False               none  False
# 427520   game           Factorio   False               none   True
# 1145360  game              Hades   False               full   True
# 105600   game           Terraria   False               full   True
#
#                                       detailed_description  \
# id
# 620      Portal 2 draws from the award-winning formula ...
# 1118200  <img src="https://cdn.cloudflare.steamstatic.c...
# 427520   <strong>Factorio</strong> is a game in which y...
# 1145360  <img src="https://cdn.cloudflare.steamstatic.c...
# 105600   Dig, Fight, Explore, Build:  The very world is...
#
#                                             about_the_game  \
# id
# 620      Portal 2 draws from the award-winning formula ...
# 1118200  <img src="https://cdn.cloudflare.steamstatic.c...
# 427520   <strong>Factorio</strong> is a game in which y...
# 1145360  <img src="https://cdn.cloudflare.steamstatic.c...
# 105600   Dig, Fight, Explore, Build:  The very world is...
#
#                                          short_description  fullgame  \
# id
# 620      The &quot;Perpetual Testing Initiative&quot; h...       NaN
# 1118200  Shoot, stab, burn, poison, tear, vaporise, or ...       NaN
# 427520   Factorio is a game about building and creating...       NaN
# 1145360  Defy the god of the dead as you hack and slash...       NaN
# 105600   Dig, fight, explore, build! Nothing is impossi...       NaN
#
#                                        supported_languages  ...  \
# id                                                          ...
# 620      English<strong>*</strong>, French<strong>*</st...  ...
# 1118200                                            English  ...
# 427520   English, French, Italian, German, Spanish - Sp...  ...
# 1145360  English<strong>*</strong>, French, Italian, Ge...  ...
# 105600   English, French, Italian, German, Spanish - Sp...  ...
#
#         local_multiplayer    mmo    lan cloud trading_cards leaderboards  \
# id
# 620                  True  False  False  True          True        False
# 1118200             False  False  False  True          True        False
# 427520              False  False   True  True         False        False
# 1145360             False  False  False  True          True        False
# 105600              False  False  False  True          True        False
#
#          workshop in_app_purchases level_editor mature
# id
# 620          True            False         True  False
# 1118200      True            False        False   True
# 427520      False            False         True  False
# 1145360     False            False        False  False
# 105600      False            False        False  False
#
# [5 rows x 43 columns]

# %% [markdown]
# This correlates with what we see at https://steamdb.info/stats/gameratings/ . As you can see, the numbers of reviews are slightly different, but we decided to go with the reviews extracted directly from Steam.

# %%
steamreviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66803 entries, 0 to 66802
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   appid              66803 non-null  int64
#  1   review_score       66803 non-null  int64
#  2   review_score_desc  66803 non-null  object
#  3   total_positive     66803 non-null  int64
#  4   total_negative     66803 non-null  int64
#  5   total_reviews      66803 non-null  int64
#  6   rating             47799 non-null  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 3.6+ MB

# %% [markdown]
# In the mathematical operations we got a lot of NaNs, due to games with 0 total reviews. Let's assign them a score of 50%, as the medium point. This is the same approach used in the algorithm above.

# %%
steamreviews["rating"] = steamreviews["rating"].fillna(50.0)

# %%
steamreviews = steamreviews.rename(columns={"appid":"id"})
steamreviews = steamreviews.set_index("id")

# %%
steamreviews = steamreviews.drop(["review_score", "review_score_desc"], axis=1)

# %%
store = store.join(steamreviews)
store = store.drop(columns=["recommendations"])

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66605 entries, 10140 to 676480
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     66605 non-null  object
#  1   name                     66605 non-null  object
#  2   is_free                  66605 non-null  object
#  3   controller_support       66605 non-null  object
#  4   dlc                      66605 non-null  bool
#  5   detailed_description     66554 non-null  object
#  6   about_the_game           66552 non-null  object
#  7   short_description        66559 non-null  object
#  8   fullgame                 0 non-null      float64
#  9   supported_languages      66585 non-null  object
#  10  header_image             66605 non-null  object
#  11  legal_notice             19498 non-null  object
#  12  drm                      66605 non-null  bool
#  13  ext_user_account_notice  1124 non-null   object
#  14  developers               66605 non-null  object
#  15  publishers               66605 non-null  object
#  16  demos                    66605 non-null  bool
#  17  price_overview           47343 non-null  object
#  18  packages                 47956 non-null  object
#  19  package_groups           66605 non-null  object
#  20  platforms                66605 non-null  object
#  21  metacritic               66605 non-null  object
#  22  reviews                  66605 non-null  bool
#  23  categories               65663 non-null  object
#  24  genres                   66491 non-null  object
#  25  achievements             66605 non-null  bool
#  26  release_date             66507 non-null  object
#  27  singleplayer             66605 non-null  bool
#  28  multiplayer              66605 non-null  bool
#  29  pvp                      66605 non-null  bool
#  30  co-op                    66605 non-null  bool
#  31  online                   66605 non-null  bool
#  32  local_multiplayer        66605 non-null  bool
#  33  mmo                      66605 non-null  bool
#  34  lan                      66605 non-null  bool
#  35  cloud                    66605 non-null  bool
#  36  trading_cards            66605 non-null  bool
#  37  leaderboards             66605 non-null  bool
#  38  workshop                 66605 non-null  bool
#  39  in_app_purchases         66605 non-null  bool
#  40  level_editor             66605 non-null  bool
#  41  mature                   66605 non-null  bool
#  42  total_positive           66605 non-null  int64
#  43  total_negative           66605 non-null  int64
#  44  total_reviews            66605 non-null  int64
#  45  rating                   66605 non-null  float64
# dtypes: bool(20), float64(2), int64(3), object(21)
# memory usage: 17.0+ MB

# %% [markdown]
# We still have two important features left: Price and Language. and we will also need to do a bit further cleaning with the few NaNs lost in there. Let's go with Price first.
#
# ## Price
#
# The information for price is stored in `price_overview`. We also noticed that there was information on `package_groups`. Let's try getting the information form overview and see if we need extra from other sources.

# %%
print(store.iloc[0]["price_overview"])
print(store.iloc[1]["price_overview"])
print(store.iloc[2]["price_overview"])
# Out:
# {'currency': 'EUR', 'initial': 999, 'final': 999, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '9,99€'}
# {'currency': 'EUR', 'initial': 699, 'final': 699, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '6,99€'}
# {'currency': 'EUR', 'initial': 999, 'final': 999, 'discount_percent': 0, 'initial_formatted': '', 'final_formatted': '9,99€'}

# %% [markdown]
# DOWNLOAD?? REUSE BELOW??
# https://store.steampowered.com/api/appdetails/?appids=1608290
#
#
# example of an id. He expected applist df with the ids for the download related to STEAM, we have to get the appids again from the previous dataframe (and erase the steamspy thingie)

# %%
# sns.pairplot(store,y_vars=["rating","total_reviews"])
