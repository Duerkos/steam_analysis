# %% [markdown]
# # Steam Data Analysis

# %% [markdown]
# ## Project Goals
#
# <!-- PELICAN_BEGIN_SUMMARY -->
#
# The motivation is gather, process and analyze Steam Store data to get insights about trends in the videogame market. As it is an online marketplace with public available data, it offers us more possibilities than analyzing console games data, where we would have to rely on an existing dataset.
#
# We want to focus on two main aspects, first a general market analysis to know which genres are the most popular, pricing strategies and so on, which could be interesting for a new developer trying to make a new game or deciding a price policy. This has been studied already by other enthusiasts in internet, and also by Marketing companies helping publishers.
#
# But to offer a different analysis, we want to also focus on the developers and publishers, to see which ones are the most successfull, how they have improved / worsen between the years, which titles have cemented their success and so on. In the light of recent years we have seen many acquisitions by large publishers such as Tencent, Microsoft and Sony, so this is very interesting concept.
#
# This will be a complete data project, with a data acquisition section (by using some APIs and web scrapping), then data cleaning and joining data from different sources, an exploratory data analysis, and finally some key conclusions.
#
#
# ## Data Acquisition
#
# This is the section where I struggled initially. There were several datasets available at [kaggle](https://www.kaggle.com/datasets), reddit and similar websites, but most were outdated or did not contain all the information I wanted to explore. Also I wanted to extract it directly from an API or use web scrapping, if possible, to learn a bit more (I already had experience with Twitter which has an excellent API).
#
# [SteamSpy](https://steamspy.com/about) is a webpage which offers data about Steam games. In the past it was even able to deliver a good guess of sales, but that has become harder throughout the years. Check [VG Insights](https://vginsights.com/insights/article/how-to-estimate-steam-video-game-sales) for more information. It is also a good webpage if you want to explore market data on your own.
# The most important thing for Steamspy is that it has its own API [here](https://steamspy.com/api.php). It can provide us easily with an already filtered list of games (not other apps or DLCs), and also some metrics not available at Steam directly such as an estimate of sales and the positive or negative reviews (Steam only gives us total number reviews).
#
# Regarding Steam directly, the API is available at https://partner.steamgames.com/ , however you need a developer key and some (most of the functions) are tied to your key as they are intended to be used to manage your own products at the Steam store. Thanks to [Nik Davis](http://nik-davis.github.io) I discovered there were also a few API functions via the WEB API which can be used without a key at all. See here for more details: [StorefrontAPI](https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI).
#
# Getting the information from Steam will be a bit more difficult, but it will give us additional metrics, such as release date, genre...
#
# We will retrieve first the list of appids and the information available at Steam Spy, then get for each appid the information from Steam and combine them in an unique dataframe. There will be no loss of information as app ids are unique. Afterwards, we will perform cleaning and finally start analyzing our dataset.
#
# ## Process:
#
# - Create an app list and gather available data from SteamSpy API using 'all' request
# - Retrieve individual app data from Steam API, by iterating through app list
# - Export app list, Steam data and SteamSpy data to csv files
#
# ## API references:
#
# - https://partner.steamgames.com/doc/webapi
# - https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI
# - https://steamapi.xpaw.me/#
# - https://steamspy.com/api.php
#
#
# ## Credits
#
# The most important source I found while looking how to connect to the API was Nik Davis, check his blog for a different analysis on steam data (from 2019) http://nik-davis.github.io
# Download functions for the APIs are based on his notebook for "Steam Data Download". I had to make some changes and simplify a bit.
#
# Steamspy seems to have changed its API, so I had to change the download method to instead download all the data by page (set of 1000 ids). The functions defined for Steam API itself still work as is.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests

# customisations - ensure tables show all columns
pd.set_option("max_columns", 100)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The next function uses requests library to get JSON response from web APIs. It is based on Nik Davis previous work, and it is quite standard as (thankfully) web APIs use a standard format, and requests makes it really easy.

# %%
def get_request(url,parameters=None, steamspy=False):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(5, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recursively try again
        return get_request(url, parameters, steamspy)
    
    if response:
        return response.json()
    else:
        # We do not know how many pages steamspy has... and it seems to work well, so we will use no response to stop.
        if steamspy:
            return "stop"
        else :
            # response is none usually means too many requests. Wait and try again 
            print('No response, waiting 10 seconds...')
            time.sleep(10)
            print('Retrying.')
            return get_request(url, parameters, steamspy)

# %% [markdown]
# ## Steam Spy API
#
# APPs on steam have an unique ID. The requests to Steam API (which has more information than Steam Spy) have to be made for a specific ID. This means we have to get first a list of ids.
#
# We can do this in several ways, but this is what I decided to follow:
#
# * Using Steam Spy API (see https://steamspy.com/api.php) to get the list of IDs and also the metadata from Steam Spy (at the same time). Alternatively, we could use Steam API to get a list of apps, then filter them (see https://api.steampowered.com/ISteamApps/GetAppList/v2/? or https://steamapi.xpaw.me/#IStoreService/GetAppInfo ).
#
# * Then using Steam API to loop for each ID from the list and getting the complete info.
#
# We are going to use this request: https://steamspy.com/api.php?request=all&page=1 - return apps 1,000-1,999 of all apps.

# %%
url = "https://steamspy.com/api.php"
parameters = {"request": "all"}
i=0

# request 'all' from steam spy and parse into dataframe
parameters["page"] = i
json_data = get_request(url, parameters=parameters, steamspy=True)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')
i=i+1

while (True):
    parameters["page"] = i
    json_data = get_request(url, parameters=parameters, steamspy=True)
    if json_data == "stop":
        #We reached the end of steamspy
        break
    steam_spy_next_page = pd.DataFrame.from_dict(json_data, orient='index')
    steam_spy_all = steam_spy_all.append(steam_spy_next_page)
    time.sleep(1)
    i=i+1

steam_spy_all.to_csv("../data/download/steamspy_appid.csv")
# generate sorted app_list from steamspy data
# app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)


# display first few rows
# app_list.head()

# %% [markdown]
# We did not know how many appids were registered in steamspy at 26/1/2022 (steamspy ranks them by user average, it seems), and it seems there are 51k appids.
#
# The code above stops if it fails using the steamspy flag, because steamspy API is quite generous and has let us download all the data with just 1s pause between requests (although in their API it says we should wait 60s for a full page request).
#
# Instead of telling us that a new page does not exist (by returning a null, in example) it gives us a server error, so this is a way to do it. Steam just returns null in this scenario.

# %%
df_steam_spy = pd.read_csv("../data/download/steamspy_appid.csv")
# generate sorted app_list from steamspy data
app_list = df_steam_spy[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# %%
df_steam_spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51353 entries, 0 to 51352
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       51353 non-null  int64
#  1   appid            51353 non-null  int64
#  2   name             51340 non-null  object
#  3   developer        51137 non-null  object
#  4   publisher        51202 non-null  object
#  5   score_rank       43 non-null     float64
#  6   positive         51353 non-null  int64
#  7   negative         51353 non-null  int64
#  8   userscore        51353 non-null  int64
#  9   owners           51353 non-null  object
#  10  average_forever  51353 non-null  int64
#  11  average_2weeks   51353 non-null  int64
#  12  median_forever   51353 non-null  int64
#  13  median_2weeks    51353 non-null  int64
#  14  price            51324 non-null  float64
#  15  initialprice     51331 non-null  float64
#  16  discount         51331 non-null  float64
#  17  ccu              51353 non-null  int64
# dtypes: float64(4), int64(10), object(4)
# memory usage: 7.1+ MB

# %% [markdown]
# ## Define Download Logic
#
# Here I just use Nik Davis previous work, to get the info about the app IDs from Steam. Now that I know the polling rate of the API storefront, I could probably do something less sofisticated, but I prefer to focus on the analysis rather than in the acquisition phase. I will keep the original comments from Nik Davis `in quotes` to let the reader understand the process.
#
# `Now we have the app_list dataframe, we can iterate over the app IDs and request individual app data from the servers. Here we set out our logic to retrieve and process this information, then finally store the data as a csv file.`
#
# `Because it takes a long time to retrieve the data, it would be dangerous to attempt it all in one go as any errors or connection time-outs could cause the loss of all our data. For this reason we define a function to download and process the requests in batches, appending each batch to an external file and keeping track of the highest index written in a separate file.`
#
# `This not only provides security, allowing us to easily restart the process if an error is encountered, but also means we can complete the download across multiple sessions.`
#
# `Again, we provide verbose output for rows exported, batches complete, time taken and estimated time remaining.`

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %% [markdown]
# `Next we define some functions to handle and prepare the external files.`
#
# `We use reset_index for testing and demonstration, allowing us to easily reset the index in the stored file to 0, effectively restarting the entire download process.`
#
# `We define get_index to retrieve the index from file, maintaining persistence across sessions. Every time a batch of information (app data) is written to file, we write the highest index within app_data that was retrieved. As stated, this is partially for security, ensuring that if there is an error during the download we can read the index from file and continue from the end of the last successful batch. Keeping track of the index also allows us to pause the download, continuing at a later time.`
#
# `Finally, the prepare_data_file function readies the csv for storing the data. If the index we retrieved is 0, it means we are either starting for the first time or starting over. In either case, we want a blank csv file with only the header row to begin writing to, se we wipe the file (by opening in write mode) and write the header. Conversely, if the index is anything other than 0, it means we already have downloaded information, and can leave the csv file alone.`

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    f= open(rel_path, 'w')
    f.write("0")
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %% [markdown]
# ## Download Steam Data
#
# `Now we are ready to start downloading data and writing to file. We define our logic particular to handling the steam API - in fact if no data is returned we return just the name and appid - then begin setting some parameters. We define the files we will write our data and index to, and the columns for the csv file. The API doesn't return every column for every app, so it is best to explicitly set these.`
#
# `Next we run our functions to set up the files, and make a call to process_batches to begin the process. Some additional parameters have been added for demonstration, to constrain the download to just a few rows and smaller batches. Removing these would allow the entire download process to be repeated.`
#
# I retouched many of these parameters just to check if the download could made in batches (requesting several steamapps at the same time), or even putting a faster polling rate (right now it is one second).
#
# The storefront API (http://store.steampowered.com/api/) is very much undocumented, but the key getaway is that is not possible. The official SteamWorks API lets us do other things and it is quite well documented, but we cannot get the data available at a steam webpage, which are the things interesting for us.
#
# The storefront API is only accessible with these [requests](https://wiki.teamfortress.com/wiki/User:RJackson/StorefrontAPI), and according to this [stackoverflow discussion](https://stackoverflow.com/questions/46330864/steam-api-all-games):
# `There is a general API rate limit for each unique IP adress of 200 requests in five minutes which is one request every 1.5 seconds.` This matches our experience, Nik Davis put a pause between requests of just 1 second, and with this we get some but a few reconnect errors. If we put no pause at all, at the end we are limited by the 200 requests every 5 minutes.
#
# That means that for a volume of around 50k at January 2022 (the steam apps available also at steam spy, already filtered by game and some owner data...) this download will take around 21 hours. Thankfully we can resume it and do it in several batches.
#
# If we were to build a web app and we wanted to update the information daily, we could instead try pulling the full applist from steam along with the "last updated" and only request the full appid information for those ids. This is probably what Steam Spy does, and SteamDB instead uses a more sofisticated approach by being notified of any changes to appids via steamworks.
#
# In any case, for a one shot analysis (and not a web page where the user could explore the information), the full download approach is fine.

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid, "key":"CFDD73A08F5BD5ACD3197173F81E5563"}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# Set file parameters
download_path = '../data/download'
steam_app_data = 'steam_app_data.csv'
steam_index = 'steam_index.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
# reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)

# Wipe or create data file and write headers if index is 0
prepare_data_file(download_path, steam_app_data, index, steam_columns)

# Set end and chunksize for demonstration - remove to run through entire app list
process_batches(
    parser=parse_steam_request,
    app_list=app_list,
    download_path=download_path,
    data_filename=steam_app_data,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index,
    #end=10,
    #batchsize=5
)
# Out:
# Starting at index 18000:
#
# Exported lines 18000-18099 to steam_app_data.csv. Batch 0 time: 0:02:28 (avg: 0:02:28, remaining: 13:40:52)
# Exported lines 18100-18199 to steam_app_data.csv. Batch 1 time: 0:02:30 (avg: 0:02:29, remaining: 13:44:44)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 18200-18299 to steam_app_data.csv. Batch 2 time: 0:02:43 (avg: 0:02:34, remaining: 14:07:28)
# Exported lines 18300-18399 to steam_app_data.csv. Batch 3 time: 0:02:28 (avg: 0:02:32, remaining: 13:57:35)
# Exported lines 18400-18499 to steam_app_data.csv. Batch 4 time: 0:02:27 (avg: 0:02:31, remaining: 13:49:26)
# Exported lines 18500-18599 to steam_app_data.csv. Batch 5 time: 0:02:31 (avg: 0:02:31, remaining: 13:46:37)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 18600-18699 to steam_app_data.csv. Batch 6 time: 0:02:39 (avg: 0:02:32, remaining: 13:50:16)
# Exported lines 18700-18799 to steam_app_data.csv. Batch 7 time: 0:02:29 (avg: 0:02:32, remaining: 13:45:37)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 18800-18899 to steam_app_data.csv. Batch 8 time: 0:02:39 (avg: 0:02:33, remaining: 13:47:37)
# Exported lines 18900-18999 to steam_app_data.csv. Batch 9 time: 0:02:29 (avg: 0:02:32, remaining: 13:43:00)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 19000-19099 to steam_app_data.csv. Batch 10 time: 0:02:39 (avg: 0:02:33, remaining: 13:43:49)
# Exported lines 19100-19199 to steam_app_data.csv. Batch 11 time: 0:02:32 (avg: 0:02:33, remaining: 13:40:57)
# Exported lines 19200-19299 to steam_app_data.csv. Batch 12 time: 0:02:31 (avg: 0:02:33, remaining: 13:37:30)
# Exported lines 19300-19399 to steam_app_data.csv. Batch 13 time: 0:02:32 (avg: 0:02:33, remaining: 13:34:35)
# Exported lines 19400-19499 to steam_app_data.csv. Batch 14 time: 0:02:32 (avg: 0:02:33, remaining: 13:31:38)
# Exported lines 19500-19599 to steam_app_data.csv. Batch 15 time: 0:02:31 (avg: 0:02:33, remaining: 13:28:27)
# Exported lines 19600-19699 to steam_app_data.csv. Batch 16 time: 0:02:30 (avg: 0:02:32, remaining: 13:25:15)
# Exported lines 19700-19799 to steam_app_data.csv. Batch 17 time: 0:02:34 (avg: 0:02:33, remaining: 13:23:18)
# Exported lines 19800-19899 to steam_app_data.csv. Batch 18 time: 0:02:31 (avg: 0:02:32, remaining: 13:20:27)
# Exported lines 19900-19999 to steam_app_data.csv. Batch 19 time: 0:02:31 (avg: 0:02:32, remaining: 13:17:27)
# Exported lines 20000-20099 to steam_app_data.csv. Batch 20 time: 0:02:29 (avg: 0:02:32, remaining: 13:14:06)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 20100-20199 to steam_app_data.csv. Batch 21 time: 0:02:40 (avg: 0:02:33, remaining: 13:13:22)
# Exported lines 20200-20299 to steam_app_data.csv. Batch 22 time: 0:02:29 (avg: 0:02:32, remaining: 13:10:05)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 20300-20399 to steam_app_data.csv. Batch 23 time: 0:02:41 (avg: 0:02:33, remaining: 13:09:18)
# Exported lines 20400-20499 to steam_app_data.csv. Batch 24 time: 0:02:29 (avg: 0:02:33, remaining: 13:05:55)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 20500-20599 to steam_app_data.csv. Batch 25 time: 0:02:40 (avg: 0:02:33, remaining: 13:04:46)
# Exported lines 20600-20699 to steam_app_data.csv. Batch 26 time: 0:02:28 (avg: 0:02:33, remaining: 13:01:23)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 20700-20799 to steam_app_data.csv. Batch 27 time: 0:02:39 (avg: 0:02:33, remaining: 12:59:54)
# Exported lines 20800-20899 to steam_app_data.csv. Batch 28 time: 0:02:28 (avg: 0:02:33, remaining: 12:56:32)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 20900-20999 to steam_app_data.csv. Batch 29 time: 0:02:39 (avg: 0:02:33, remaining: 12:55:06)
# Exported lines 21000-21099 to steam_app_data.csv. Batch 30 time: 0:02:28 (avg: 0:02:33, remaining: 12:51:49)
# Exported lines 21100-21199 to steam_app_data.csv. Batch 31 time: 0:02:32 (avg: 0:02:33, remaining: 12:49:09)
# Exported lines 21200-21299 to steam_app_data.csv. Batch 32 time: 0:02:30 (avg: 0:02:33, remaining: 12:46:08)
# Exported lines 21300-21399 to steam_app_data.csv. Batch 33 time: 0:02:30 (avg: 0:02:33, remaining: 12:43:10)
# Exported lines 21400-21499 to steam_app_data.csv. Batch 34 time: 0:02:31 (avg: 0:02:33, remaining: 12:40:20)
# Exported lines 21500-21599 to steam_app_data.csv. Batch 35 time: 0:02:31 (avg: 0:02:33, remaining: 12:37:30)
# Exported lines 21600-21699 to steam_app_data.csv. Batch 36 time: 0:02:31 (avg: 0:02:32, remaining: 12:34:42)
# Exported lines 21700-21799 to steam_app_data.csv. Batch 37 time: 0:02:30 (avg: 0:02:32, remaining: 12:31:52)
# Exported lines 21800-21899 to steam_app_data.csv. Batch 38 time: 0:02:29 (avg: 0:02:32, remaining: 12:28:54)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 21900-21999 to steam_app_data.csv. Batch 39 time: 0:02:38 (avg: 0:02:32, remaining: 12:27:06)
# Exported lines 22000-22099 to steam_app_data.csv. Batch 40 time: 0:02:28 (avg: 0:02:32, remaining: 12:24:00)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 22100-22199 to steam_app_data.csv. Batch 41 time: 0:02:38 (avg: 0:02:32, remaining: 12:22:09)
# Exported lines 22200-22299 to steam_app_data.csv. Batch 42 time: 0:02:31 (avg: 0:02:32, remaining: 12:19:26)
# Exported lines 22300-22399 to steam_app_data.csv. Batch 43 time: 0:02:28 (avg: 0:02:32, remaining: 12:16:24)
# Exported lines 22400-22499 to steam_app_data.csv. Batch 44 time: 0:02:29 (avg: 0:02:32, remaining: 12:13:28)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 22500-22599 to steam_app_data.csv. Batch 45 time: 0:02:37 (avg: 0:02:32, remaining: 12:11:27)
# Exported lines 22600-22699 to steam_app_data.csv. Batch 46 time: 0:02:29 (avg: 0:02:32, remaining: 12:08:32)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 22700-22799 to steam_app_data.csv. Batch 47 time: 0:02:37 (avg: 0:02:32, remaining: 12:06:29)
# Exported lines 22800-22899 to steam_app_data.csv. Batch 48 time: 0:02:27 (avg: 0:02:32, remaining: 12:03:28)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 22900-22999 to steam_app_data.csv. Batch 49 time: 0:02:38 (avg: 0:02:32, remaining: 12:01:28)
# Exported lines 23000-23099 to steam_app_data.csv. Batch 50 time: 0:02:27 (avg: 0:02:32, remaining: 11:58:25)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 23100-23199 to steam_app_data.csv. Batch 51 time: 0:02:38 (avg: 0:02:32, remaining: 11:56:24)
# Exported lines 23200-23299 to steam_app_data.csv. Batch 52 time: 0:02:29 (avg: 0:02:32, remaining: 11:53:33)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 23300-23399 to steam_app_data.csv. Batch 53 time: 0:02:38 (avg: 0:02:32, remaining: 11:51:32)
# Exported lines 23400-23499 to steam_app_data.csv. Batch 54 time: 0:02:28 (avg: 0:02:32, remaining: 11:48:35)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 23500-23599 to steam_app_data.csv. Batch 55 time: 0:02:40 (avg: 0:02:33, remaining: 11:46:41)
# Exported lines 23600-23699 to steam_app_data.csv. Batch 56 time: 0:02:27 (avg: 0:02:32, remaining: 11:43:41)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 23700-23799 to steam_app_data.csv. Batch 57 time: 0:02:38 (avg: 0:02:33, remaining: 11:41:33)
# Exported lines 23800-23899 to steam_app_data.csv. Batch 58 time: 0:02:29 (avg: 0:02:32, remaining: 11:38:42)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 23900-23999 to steam_app_data.csv. Batch 59 time: 0:02:38 (avg: 0:02:33, remaining: 11:36:36)
# Exported lines 24000-24099 to steam_app_data.csv. Batch 60 time: 0:02:32 (avg: 0:02:33, remaining: 11:34:02)
# Exported lines 24100-24199 to steam_app_data.csv. Batch 61 time: 0:02:32 (avg: 0:02:33, remaining: 11:31:27)
# Exported lines 24200-24299 to steam_app_data.csv. Batch 62 time: 0:02:31 (avg: 0:02:33, remaining: 11:28:50)
# Exported lines 24300-24399 to steam_app_data.csv. Batch 63 time: 0:02:32 (avg: 0:02:32, remaining: 11:26:13)
# Exported lines 24400-24499 to steam_app_data.csv. Batch 64 time: 0:02:29 (avg: 0:02:32, remaining: 11:23:25)
# Exported lines 24500-24599 to steam_app_data.csv. Batch 65 time: 0:02:33 (avg: 0:02:32, remaining: 11:20:54)
# Exported lines 24600-24699 to steam_app_data.csv. Batch 66 time: 0:02:33 (avg: 0:02:32, remaining: 11:18:23)
# Exported lines 24700-24799 to steam_app_data.csv. Batch 67 time: 0:02:31 (avg: 0:02:32, remaining: 11:15:44)
# Exported lines 24800-24899 to steam_app_data.csv. Batch 68 time: 0:02:33 (avg: 0:02:32, remaining: 11:13:13)
# Exported lines 24900-24999 to steam_app_data.csv. Batch 69 time: 0:02:30 (avg: 0:02:32, remaining: 11:10:31)
# Exported lines 25000-25099 to steam_app_data.csv. Batch 70 time: 0:02:33 (avg: 0:02:32, remaining: 11:08:00)
# Exported lines 25100-25199 to steam_app_data.csv. Batch 71 time: 0:02:31 (avg: 0:02:32, remaining: 11:05:23)
# Exported lines 25200-25299 to steam_app_data.csv. Batch 72 time: 0:02:33 (avg: 0:02:32, remaining: 11:02:52)
# Exported lines 25300-25399 to steam_app_data.csv. Batch 73 time: 0:02:30 (avg: 0:02:32, remaining: 11:00:10)
# Exported lines 25400-25499 to steam_app_data.csv. Batch 74 time: 0:02:29 (avg: 0:02:32, remaining: 10:57:26)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 25500-25599 to steam_app_data.csv. Batch 75 time: 0:02:40 (avg: 0:02:32, remaining: 10:55:19)
# Exported lines 25600-25699 to steam_app_data.csv. Batch 76 time: 0:02:35 (avg: 0:02:32, remaining: 10:52:56)
# Exported lines 25700-25799 to steam_app_data.csv. Batch 77 time: 0:02:31 (avg: 0:02:32, remaining: 10:50:20)
# Exported lines 25800-25899 to steam_app_data.csv. Batch 78 time: 0:02:32 (avg: 0:02:32, remaining: 10:47:47)
# Exported lines 25900-25999 to steam_app_data.csv. Batch 79 time: 0:02:30 (avg: 0:02:32, remaining: 10:45:05)
# Exported lines 26000-26099 to steam_app_data.csv. Batch 80 time: 0:02:29 (avg: 0:02:32, remaining: 10:42:21)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 26100-26199 to steam_app_data.csv. Batch 81 time: 0:02:41 (avg: 0:02:32, remaining: 10:40:16)
# Exported lines 26200-26299 to steam_app_data.csv. Batch 82 time: 0:02:27 (avg: 0:02:32, remaining: 10:37:28)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 26300-26399 to steam_app_data.csv. Batch 83 time: 0:02:39 (avg: 0:02:32, remaining: 10:35:17)
# Exported lines 26400-26499 to steam_app_data.csv. Batch 84 time: 0:02:27 (avg: 0:02:32, remaining: 10:32:29)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 26500-26599 to steam_app_data.csv. Batch 85 time: 0:02:38 (avg: 0:02:32, remaining: 10:30:12)
# Exported lines 26600-26699 to steam_app_data.csv. Batch 86 time: 0:02:29 (avg: 0:02:32, remaining: 10:27:28)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 26700-26799 to steam_app_data.csv. Batch 87 time: 0:02:40 (avg: 0:02:33, remaining: 10:25:18)
# Exported lines 26800-26899 to steam_app_data.csv. Batch 88 time: 0:02:32 (avg: 0:02:33, remaining: 10:22:43)
# Exported lines 26900-26999 to steam_app_data.csv. Batch 89 time: 0:02:37 (avg: 0:02:33, remaining: 10:20:24)
# Exported lines 27000-27099 to steam_app_data.csv. Batch 90 time: 0:02:32 (avg: 0:02:33, remaining: 10:17:51)
# Exported lines 27100-27199 to steam_app_data.csv. Batch 91 time: 0:02:31 (avg: 0:02:33, remaining: 10:15:15)
# Exported lines 27200-27299 to steam_app_data.csv. Batch 92 time: 0:02:29 (avg: 0:02:32, remaining: 10:12:32)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 27300-27399 to steam_app_data.csv. Batch 93 time: 0:02:41 (avg: 0:02:33, remaining: 10:10:22)
# Exported lines 27400-27499 to steam_app_data.csv. Batch 94 time: 0:02:29 (avg: 0:02:33, remaining: 10:07:41)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 27500-27599 to steam_app_data.csv. Batch 95 time: 0:02:39 (avg: 0:02:33, remaining: 10:05:25)
# Exported lines 27600-27699 to steam_app_data.csv. Batch 96 time: 0:02:30 (avg: 0:02:33, remaining: 10:02:46)
# Exported lines 27700-27799 to steam_app_data.csv. Batch 97 time: 0:02:29 (avg: 0:02:33, remaining: 10:00:05)
# Exported lines 27800-27899 to steam_app_data.csv. Batch 98 time: 0:02:29 (avg: 0:02:33, remaining: 9:57:24)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 27900-27999 to steam_app_data.csv. Batch 99 time: 0:02:40 (avg: 0:02:33, remaining: 9:55:09)
# Exported lines 28000-28099 to steam_app_data.csv. Batch 100 time: 0:02:28 (avg: 0:02:33, remaining: 9:52:25)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 28100-28199 to steam_app_data.csv. Batch 101 time: 0:02:40 (avg: 0:02:33, remaining: 9:50:10)
# Exported lines 28200-28299 to steam_app_data.csv. Batch 102 time: 0:02:31 (avg: 0:02:33, remaining: 9:47:34)
# Exported lines 28300-28399 to steam_app_data.csv. Batch 103 time: 0:02:32 (avg: 0:02:33, remaining: 9:44:59)
# Exported lines 28400-28499 to steam_app_data.csv. Batch 104 time: 0:02:32 (avg: 0:02:33, remaining: 9:42:26)
# Exported lines 28500-28599 to steam_app_data.csv. Batch 105 time: 0:02:30 (avg: 0:02:33, remaining: 9:39:48)
# Exported lines 28600-28699 to steam_app_data.csv. Batch 106 time: 0:02:30 (avg: 0:02:33, remaining: 9:37:10)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 28700-28799 to steam_app_data.csv. Batch 107 time: 0:02:39 (avg: 0:02:33, remaining: 9:34:50)
# Exported lines 28800-28899 to steam_app_data.csv. Batch 108 time: 0:02:30 (avg: 0:02:33, remaining: 9:32:11)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 28900-28999 to steam_app_data.csv. Batch 109 time: 0:02:38 (avg: 0:02:33, remaining: 9:29:51)
# Exported lines 29000-29099 to steam_app_data.csv. Batch 110 time: 0:02:28 (avg: 0:02:33, remaining: 9:27:09)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 29100-29199 to steam_app_data.csv. Batch 111 time: 0:02:44 (avg: 0:02:33, remaining: 9:24:58)
# Exported lines 29200-29299 to steam_app_data.csv. Batch 112 time: 0:02:33 (avg: 0:02:33, remaining: 9:22:25)
# Exported lines 29300-29399 to steam_app_data.csv. Batch 113 time: 0:02:31 (avg: 0:02:33, remaining: 9:19:50)
# Exported lines 29400-29499 to steam_app_data.csv. Batch 114 time: 0:02:29 (avg: 0:02:33, remaining: 9:17:10)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 29500-29599 to steam_app_data.csv. Batch 115 time: 0:02:40 (avg: 0:02:33, remaining: 9:14:51)
# Exported lines 29600-29699 to steam_app_data.csv. Batch 116 time: 0:02:33 (avg: 0:02:33, remaining: 9:12:19)
# Exported lines 29700-29799 to steam_app_data.csv. Batch 117 time: 0:02:29 (avg: 0:02:33, remaining: 9:09:40)
# Exported lines 29800-29899 to steam_app_data.csv. Batch 118 time: 0:02:27 (avg: 0:02:33, remaining: 9:06:57)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 29900-29999 to steam_app_data.csv. Batch 119 time: 0:02:42 (avg: 0:02:33, remaining: 9:04:41)
# Exported lines 30000-30099 to steam_app_data.csv. Batch 120 time: 0:02:27 (avg: 0:02:33, remaining: 9:01:57)
# Exported lines 30100-30199 to steam_app_data.csv. Batch 121 time: 0:02:31 (avg: 0:02:33, remaining: 8:59:21)
# Exported lines 30200-30299 to steam_app_data.csv. Batch 122 time: 0:02:28 (avg: 0:02:33, remaining: 8:56:41)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 30300-30399 to steam_app_data.csv. Batch 123 time: 0:02:39 (avg: 0:02:33, remaining: 8:54:19)
# Exported lines 30400-30499 to steam_app_data.csv. Batch 124 time: 0:02:27 (avg: 0:02:33, remaining: 8:51:37)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 30500-30599 to steam_app_data.csv. Batch 125 time: 0:02:40 (avg: 0:02:33, remaining: 8:49:16)
# Exported lines 30600-30699 to steam_app_data.csv. Batch 126 time: 0:02:30 (avg: 0:02:33, remaining: 8:46:40)
# Exported lines 30700-30799 to steam_app_data.csv. Batch 127 time: 0:02:31 (avg: 0:02:33, remaining: 8:44:04)
# Exported lines 30800-30899 to steam_app_data.csv. Batch 128 time: 0:02:32 (avg: 0:02:33, remaining: 8:41:30)
# Exported lines 30900-30999 to steam_app_data.csv. Batch 129 time: 0:02:34 (avg: 0:02:33, remaining: 8:38:59)
# Exported lines 31000-31099 to steam_app_data.csv. Batch 130 time: 0:02:29 (avg: 0:02:33, remaining: 8:36:21)
# Exported lines 31100-31199 to steam_app_data.csv. Batch 131 time: 0:02:30 (avg: 0:02:33, remaining: 8:33:45)
# Exported lines 31200-31299 to steam_app_data.csv. Batch 132 time: 0:02:31 (avg: 0:02:33, remaining: 8:31:10)
# Exported lines 31300-31399 to steam_app_data.csv. Batch 133 time: 0:02:29 (avg: 0:02:33, remaining: 8:28:33)
# Exported lines 31400-31499 to steam_app_data.csv. Batch 134 time: 0:02:29 (avg: 0:02:33, remaining: 8:25:54)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 31500-31599 to steam_app_data.csv. Batch 135 time: 0:02:37 (avg: 0:02:33, remaining: 8:23:29)
# Exported lines 31600-31699 to steam_app_data.csv. Batch 136 time: 0:02:28 (avg: 0:02:33, remaining: 8:20:49)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 31700-31799 to steam_app_data.csv. Batch 137 time: 0:02:39 (avg: 0:02:33, remaining: 8:18:25)
# Exported lines 31800-31899 to steam_app_data.csv. Batch 138 time: 0:02:28 (avg: 0:02:33, remaining: 8:15:46)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 31900-31999 to steam_app_data.csv. Batch 139 time: 0:02:40 (avg: 0:02:33, remaining: 8:13:24)
# Exported lines 32000-32099 to steam_app_data.csv. Batch 140 time: 0:02:29 (avg: 0:02:33, remaining: 8:10:46)
# Exported lines 32100-32199 to steam_app_data.csv. Batch 141 time: 0:02:30 (avg: 0:02:33, remaining: 8:08:11)
# Exported lines 32200-32299 to steam_app_data.csv. Batch 142 time: 0:02:29 (avg: 0:02:33, remaining: 8:05:33)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 32300-32399 to steam_app_data.csv. Batch 143 time: 0:02:40 (avg: 0:02:33, remaining: 8:03:10)
# Exported lines 32400-32499 to steam_app_data.csv. Batch 144 time: 0:02:27 (avg: 0:02:33, remaining: 8:00:31)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 32500-32599 to steam_app_data.csv. Batch 145 time: 0:02:41 (avg: 0:02:33, remaining: 7:58:08)
# Exported lines 32600-32699 to steam_app_data.csv. Batch 146 time: 0:02:30 (avg: 0:02:33, remaining: 7:55:32)
# Exported lines 32700-32799 to steam_app_data.csv. Batch 147 time: 0:02:28 (avg: 0:02:33, remaining: 7:52:53)
# Exported lines 32800-32899 to steam_app_data.csv. Batch 148 time: 0:02:30 (avg: 0:02:33, remaining: 7:50:17)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 32900-32999 to steam_app_data.csv. Batch 149 time: 0:02:41 (avg: 0:02:33, remaining: 7:47:55)
# Exported lines 33000-33099 to steam_app_data.csv. Batch 150 time: 0:02:28 (avg: 0:02:33, remaining: 7:45:17)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 33100-33199 to steam_app_data.csv. Batch 151 time: 0:02:39 (avg: 0:02:33, remaining: 7:42:53)
# Exported lines 33200-33299 to steam_app_data.csv. Batch 152 time: 0:02:29 (avg: 0:02:33, remaining: 7:40:16)
# Exported lines 33300-33399 to steam_app_data.csv. Batch 153 time: 0:02:31 (avg: 0:02:33, remaining: 7:37:41)
# Exported lines 33400-33499 to steam_app_data.csv. Batch 154 time: 0:02:29 (avg: 0:02:33, remaining: 7:35:04)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 33500-33599 to steam_app_data.csv. Batch 155 time: 0:02:40 (avg: 0:02:33, remaining: 7:32:41)
# Exported lines 33600-33699 to steam_app_data.csv. Batch 156 time: 0:02:28 (avg: 0:02:33, remaining: 7:30:03)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 33700-33799 to steam_app_data.csv. Batch 157 time: 0:02:39 (avg: 0:02:33, remaining: 7:27:37)
# Exported lines 33800-33899 to steam_app_data.csv. Batch 158 time: 0:02:29 (avg: 0:02:33, remaining: 7:25:00)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 33900-33999 to steam_app_data.csv. Batch 159 time: 0:02:39 (avg: 0:02:33, remaining: 7:22:35)
# Exported lines 34000-34099 to steam_app_data.csv. Batch 160 time: 0:02:28 (avg: 0:02:33, remaining: 7:19:57)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 34100-34199 to steam_app_data.csv. Batch 161 time: 0:02:39 (avg: 0:02:33, remaining: 7:17:32)
# Exported lines 34200-34299 to steam_app_data.csv. Batch 162 time: 0:02:29 (avg: 0:02:33, remaining: 7:14:55)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 34300-34399 to steam_app_data.csv. Batch 163 time: 0:02:39 (avg: 0:02:33, remaining: 7:12:29)
# Exported lines 34400-34499 to steam_app_data.csv. Batch 164 time: 0:02:30 (avg: 0:02:33, remaining: 7:09:53)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 34500-34599 to steam_app_data.csv. Batch 165 time: 0:02:40 (avg: 0:02:33, remaining: 7:07:28)
# Exported lines 34600-34699 to steam_app_data.csv. Batch 166 time: 0:02:31 (avg: 0:02:33, remaining: 7:04:54)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 34700-34799 to steam_app_data.csv. Batch 167 time: 0:02:38 (avg: 0:02:33, remaining: 7:02:26)
# Exported lines 34800-34899 to steam_app_data.csv. Batch 168 time: 0:02:28 (avg: 0:02:33, remaining: 6:59:50)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 34900-34999 to steam_app_data.csv. Batch 169 time: 0:02:42 (avg: 0:02:33, remaining: 6:57:26)
# Exported lines 35000-35099 to steam_app_data.csv. Batch 170 time: 0:02:34 (avg: 0:02:33, remaining: 6:54:54)
# Exported lines 35100-35199 to steam_app_data.csv. Batch 171 time: 0:02:30 (avg: 0:02:33, remaining: 6:52:19)
# Exported lines 35200-35299 to steam_app_data.csv. Batch 172 time: 0:02:30 (avg: 0:02:33, remaining: 6:49:44)
# Exported lines 35300-35399 to steam_app_data.csv. Batch 173 time: 0:02:29 (avg: 0:02:33, remaining: 6:47:08)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 35400-35499 to steam_app_data.csv. Batch 174 time: 0:02:40 (avg: 0:02:33, remaining: 6:44:42)
# Exported lines 35500-35599 to steam_app_data.csv. Batch 175 time: 0:02:28 (avg: 0:02:33, remaining: 6:42:05)
# Exported lines 35600-35699 to steam_app_data.csv. Batch 176 time: 0:02:30 (avg: 0:02:33, remaining: 6:39:30)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 35700-35799 to steam_app_data.csv. Batch 177 time: 0:02:40 (avg: 0:02:33, remaining: 6:37:04)
# Exported lines 35800-35899 to steam_app_data.csv. Batch 178 time: 0:02:29 (avg: 0:02:33, remaining: 6:34:28)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 35900-35999 to steam_app_data.csv. Batch 179 time: 0:02:38 (avg: 0:02:33, remaining: 6:32:00)
# Exported lines 36000-36099 to steam_app_data.csv. Batch 180 time: 0:02:27 (avg: 0:02:33, remaining: 6:29:23)
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 36100-36199 to steam_app_data.csv. Batch 181 time: 0:12:42 (avg: 0:02:36, remaining: 6:35:18)
# Exported lines 36200-36299 to steam_app_data.csv. Batch 182 time: 0:02:47 (avg: 0:02:36, remaining: 6:32:51)
# Exported lines 36300-36399 to steam_app_data.csv. Batch 183 time: 0:02:33 (avg: 0:02:36, remaining: 6:30:12)
# Exported lines 36400-36499 to steam_app_data.csv. Batch 184 time: 0:02:52 (avg: 0:02:36, remaining: 6:27:49)
# Exported lines 36500-36599 to steam_app_data.csv. Batch 185 time: 0:02:58 (avg: 0:02:36, remaining: 6:25:31)
# Exported lines 36600-36699 to steam_app_data.csv. Batch 186 time: 0:02:34 (avg: 0:02:36, remaining: 6:22:53)
# Exported lines 36700-36799 to steam_app_data.csv. Batch 187 time: 0:02:38 (avg: 0:02:36, remaining: 6:20:18)
# Exported lines 36800-36899 to steam_app_data.csv. Batch 188 time: 0:02:34 (avg: 0:02:36, remaining: 6:17:40)
# Exported lines 36900-36999 to steam_app_data.csv. Batch 189 time: 0:02:34 (avg: 0:02:36, remaining: 6:15:02)
# Exported lines 37000-37099 to steam_app_data.csv. Batch 190 time: 0:02:45 (avg: 0:02:36, remaining: 6:12:32)
# Exported lines 37100-37199 to steam_app_data.csv. Batch 191 time: 0:02:41 (avg: 0:02:36, remaining: 6:10:00)
# Exported lines 37200-37299 to steam_app_data.csv. Batch 192 time: 0:02:34 (avg: 0:02:36, remaining: 6:07:21)
# Exported lines 37300-37399 to steam_app_data.csv. Batch 193 time: 0:02:32 (avg: 0:02:36, remaining: 6:04:42)
# Exported lines 37400-37499 to steam_app_data.csv. Batch 194 time: 0:02:32 (avg: 0:02:36, remaining: 6:02:03)
# Exported lines 37500-37599 to steam_app_data.csv. Batch 195 time: 0:02:32 (avg: 0:02:36, remaining: 5:59:23)
# Exported lines 37600-37699 to steam_app_data.csv. Batch 196 time: 0:02:31 (avg: 0:02:36, remaining: 5:56:43)
# Exported lines 37700-37799 to steam_app_data.csv. Batch 197 time: 0:02:30 (avg: 0:02:36, remaining: 5:54:03)
# Exported lines 37800-37899 to steam_app_data.csv. Batch 198 time: 0:02:33 (avg: 0:02:36, remaining: 5:51:24)
# Exported lines 37900-37999 to steam_app_data.csv. Batch 199 time: 0:02:33 (avg: 0:02:36, remaining: 5:48:46)
# Exported lines 38000-38099 to steam_app_data.csv. Batch 200 time: 0:02:31 (avg: 0:02:36, remaining: 5:46:06)
# Exported lines 38100-38199 to steam_app_data.csv. Batch 201 time: 0:02:31 (avg: 0:02:36, remaining: 5:43:27)
# Exported lines 38200-38299 to steam_app_data.csv. Batch 202 time: 0:02:34 (avg: 0:02:36, remaining: 5:40:49)
# Exported lines 38300-38399 to steam_app_data.csv. Batch 203 time: 0:02:46 (avg: 0:02:36, remaining: 5:38:20)
# Exported lines 38400-38499 to steam_app_data.csv. Batch 204 time: 0:02:35 (avg: 0:02:36, remaining: 5:35:43)
# Exported lines 38500-38599 to steam_app_data.csv. Batch 205 time: 0:02:43 (avg: 0:02:36, remaining: 5:33:11)
# Exported lines 38600-38699 to steam_app_data.csv. Batch 206 time: 0:02:56 (avg: 0:02:36, remaining: 5:30:47)
# Exported lines 38700-38799 to steam_app_data.csv. Batch 207 time: 0:02:34 (avg: 0:02:36, remaining: 5:28:10)
# Exported lines 38800-38899 to steam_app_data.csv. Batch 208 time: 0:02:34 (avg: 0:02:36, remaining: 5:25:32)
# Exported lines 38900-38999 to steam_app_data.csv. Batch 209 time: 0:02:35 (avg: 0:02:36, remaining: 5:22:55)
# Exported lines 39000-39099 to steam_app_data.csv. Batch 210 time: 0:02:35 (avg: 0:02:36, remaining: 5:20:18)
# Exported lines 39100-39199 to steam_app_data.csv. Batch 211 time: 0:02:36 (avg: 0:02:36, remaining: 5:17:42)
# Exported lines 39200-39299 to steam_app_data.csv. Batch 212 time: 0:02:36 (avg: 0:02:36, remaining: 5:15:05)
# Exported lines 39300-39399 to steam_app_data.csv. Batch 213 time: 0:02:52 (avg: 0:02:36, remaining: 5:12:38)
# Exported lines 39400-39499 to steam_app_data.csv. Batch 214 time: 0:02:36 (avg: 0:02:36, remaining: 5:10:01)
# Exported lines 39500-39599 to steam_app_data.csv. Batch 215 time: 0:02:37 (avg: 0:02:36, remaining: 5:07:25)
# Exported lines 39600-39699 to steam_app_data.csv. Batch 216 time: 0:02:41 (avg: 0:02:36, remaining: 5:04:51)
# Exported lines 39700-39799 to steam_app_data.csv. Batch 217 time: 0:02:40 (avg: 0:02:36, remaining: 5:02:17)
# Exported lines 39800-39899 to steam_app_data.csv. Batch 218 time: 0:02:38 (avg: 0:02:36, remaining: 4:59:41)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 39900-39999 to steam_app_data.csv. Batch 219 time: 0:02:49 (avg: 0:02:36, remaining: 4:57:12)
# Exported lines 40000-40099 to steam_app_data.csv. Batch 220 time: 0:02:46 (avg: 0:02:36, remaining: 4:54:40)
# Exported lines 40100-40199 to steam_app_data.csv. Batch 221 time: 0:02:34 (avg: 0:02:36, remaining: 4:52:03)
# Exported lines 40200-40299 to steam_app_data.csv. Batch 222 time: 0:02:39 (avg: 0:02:36, remaining: 4:49:28)
# Exported lines 40300-40399 to steam_app_data.csv. Batch 223 time: 0:02:40 (avg: 0:02:36, remaining: 4:46:53)
# Exported lines 40400-40499 to steam_app_data.csv. Batch 224 time: 0:02:34 (avg: 0:02:36, remaining: 4:44:16)
# Exported lines 40500-40599 to steam_app_data.csv. Batch 225 time: 0:02:43 (avg: 0:02:37, remaining: 4:41:42)
# Exported lines 40600-40699 to steam_app_data.csv. Batch 226 time: 0:02:36 (avg: 0:02:37, remaining: 4:39:06)
# Exported lines 40700-40799 to steam_app_data.csv. Batch 227 time: 0:02:37 (avg: 0:02:37, remaining: 4:36:29)
# Exported lines 40800-40899 to steam_app_data.csv. Batch 228 time: 0:02:37 (avg: 0:02:37, remaining: 4:33:53)
# Exported lines 40900-40999 to steam_app_data.csv. Batch 229 time: 0:02:31 (avg: 0:02:36, remaining: 4:31:14)
# Exported lines 41000-41099 to steam_app_data.csv. Batch 230 time: 0:02:39 (avg: 0:02:36, remaining: 4:28:39)
# Exported lines 41100-41199 to steam_app_data.csv. Batch 231 time: 0:02:32 (avg: 0:02:36, remaining: 4:26:00)
# Exported lines 41200-41299 to steam_app_data.csv. Batch 232 time: 0:02:31 (avg: 0:02:36, remaining: 4:23:21)
# Exported lines 41300-41399 to steam_app_data.csv. Batch 233 time: 0:02:31 (avg: 0:02:36, remaining: 4:20:42)
# Exported lines 41400-41499 to steam_app_data.csv. Batch 234 time: 0:02:31 (avg: 0:02:36, remaining: 4:18:04)
# Exported lines 41500-41599 to steam_app_data.csv. Batch 235 time: 0:02:30 (avg: 0:02:36, remaining: 4:15:24)
# Exported lines 41600-41699 to steam_app_data.csv. Batch 236 time: 0:02:30 (avg: 0:02:36, remaining: 4:12:46)
# Exported lines 41700-41799 to steam_app_data.csv. Batch 237 time: 0:02:29 (avg: 0:02:36, remaining: 4:10:06)
# Exported lines 41800-41899 to steam_app_data.csv. Batch 238 time: 0:02:30 (avg: 0:02:36, remaining: 4:07:27)
# Exported lines 41900-41999 to steam_app_data.csv. Batch 239 time: 0:02:34 (avg: 0:02:36, remaining: 4:04:50)
# Exported lines 42000-42099 to steam_app_data.csv. Batch 240 time: 0:02:33 (avg: 0:02:36, remaining: 4:02:13)
# Exported lines 42100-42199 to steam_app_data.csv. Batch 241 time: 0:02:32 (avg: 0:02:36, remaining: 3:59:35)
# Exported lines 42200-42299 to steam_app_data.csv. Batch 242 time: 0:02:32 (avg: 0:02:36, remaining: 3:56:57)
# Exported lines 42300-42399 to steam_app_data.csv. Batch 243 time: 0:02:31 (avg: 0:02:36, remaining: 3:54:19)
# Exported lines 42400-42499 to steam_app_data.csv. Batch 244 time: 0:02:31 (avg: 0:02:36, remaining: 3:51:41)
# Exported lines 42500-42599 to steam_app_data.csv. Batch 245 time: 0:02:31 (avg: 0:02:36, remaining: 3:49:03)
# Exported lines 42600-42699 to steam_app_data.csv. Batch 246 time: 0:02:36 (avg: 0:02:36, remaining: 3:46:27)
# Exported lines 42700-42799 to steam_app_data.csv. Batch 247 time: 0:02:43 (avg: 0:02:36, remaining: 3:43:53)
# Exported lines 42800-42899 to steam_app_data.csv. Batch 248 time: 0:02:34 (avg: 0:02:36, remaining: 3:41:16)
# Exported lines 42900-42999 to steam_app_data.csv. Batch 249 time: 0:02:28 (avg: 0:02:36, remaining: 3:38:37)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 43000-43099 to steam_app_data.csv. Batch 250 time: 0:02:38 (avg: 0:02:36, remaining: 3:36:01)
# Exported lines 43100-43199 to steam_app_data.csv. Batch 251 time: 0:02:29 (avg: 0:02:36, remaining: 3:33:23)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 43200-43299 to steam_app_data.csv. Batch 252 time: 0:02:38 (avg: 0:02:36, remaining: 3:30:47)
# Exported lines 43300-43399 to steam_app_data.csv. Batch 253 time: 0:02:30 (avg: 0:02:36, remaining: 3:28:09)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 43400-43499 to steam_app_data.csv. Batch 254 time: 0:02:40 (avg: 0:02:36, remaining: 3:25:34)
# Exported lines 43500-43599 to steam_app_data.csv. Batch 255 time: 0:02:29 (avg: 0:02:36, remaining: 3:22:56)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 43600-43699 to steam_app_data.csv. Batch 256 time: 0:02:39 (avg: 0:02:36, remaining: 3:20:21)
# Exported lines 43700-43799 to steam_app_data.csv. Batch 257 time: 0:02:27 (avg: 0:02:36, remaining: 3:17:42)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 43800-43899 to steam_app_data.csv. Batch 258 time: 0:02:40 (avg: 0:02:36, remaining: 3:15:07)
# Exported lines 43900-43999 to steam_app_data.csv. Batch 259 time: 0:02:27 (avg: 0:02:36, remaining: 3:12:28)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 44000-44099 to steam_app_data.csv. Batch 260 time: 0:02:41 (avg: 0:02:36, remaining: 3:09:54)
# Exported lines 44100-44199 to steam_app_data.csv. Batch 261 time: 0:02:26 (avg: 0:02:36, remaining: 3:07:15)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 44200-44299 to steam_app_data.csv. Batch 262 time: 0:02:39 (avg: 0:02:36, remaining: 3:04:40)
# Exported lines 44300-44399 to steam_app_data.csv. Batch 263 time: 0:02:30 (avg: 0:02:36, remaining: 3:02:02)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 44400-44499 to steam_app_data.csv. Batch 264 time: 0:02:39 (avg: 0:02:36, remaining: 2:59:27)
# Exported lines 44500-44599 to steam_app_data.csv. Batch 265 time: 0:02:34 (avg: 0:02:36, remaining: 2:56:50)
# Exported lines 44600-44699 to steam_app_data.csv. Batch 266 time: 0:02:34 (avg: 0:02:36, remaining: 2:54:14)
# Exported lines 44700-44799 to steam_app_data.csv. Batch 267 time: 0:02:36 (avg: 0:02:36, remaining: 2:51:37)
# Exported lines 44800-44899 to steam_app_data.csv. Batch 268 time: 0:02:35 (avg: 0:02:36, remaining: 2:49:01)
# Exported lines 44900-44999 to steam_app_data.csv. Batch 269 time: 0:02:35 (avg: 0:02:36, remaining: 2:46:25)
# Exported lines 45000-45099 to steam_app_data.csv. Batch 270 time: 0:02:36 (avg: 0:02:36, remaining: 2:43:49)
# Exported lines 45100-45199 to steam_app_data.csv. Batch 271 time: 0:04:35 (avg: 0:02:36, remaining: 2:41:40)
# Exported lines 45200-45299 to steam_app_data.csv. Batch 272 time: 0:02:35 (avg: 0:02:36, remaining: 2:39:03)
# Exported lines 45300-45399 to steam_app_data.csv. Batch 273 time: 0:02:33 (avg: 0:02:36, remaining: 2:36:26)
# Exported lines 45400-45499 to steam_app_data.csv. Batch 274 time: 0:02:32 (avg: 0:02:36, remaining: 2:33:49)
# Exported lines 45500-45599 to steam_app_data.csv. Batch 275 time: 0:02:32 (avg: 0:02:36, remaining: 2:31:11)
# Exported lines 45600-45699 to steam_app_data.csv. Batch 276 time: 0:02:31 (avg: 0:02:36, remaining: 2:28:34)
# Exported lines 45700-45799 to steam_app_data.csv. Batch 277 time: 0:02:30 (avg: 0:02:36, remaining: 2:25:56)
# Exported lines 45800-45899 to steam_app_data.csv. Batch 278 time: 0:02:31 (avg: 0:02:36, remaining: 2:23:19)
# Exported lines 45900-45999 to steam_app_data.csv. Batch 279 time: 0:02:31 (avg: 0:02:36, remaining: 2:20:41)
# Exported lines 46000-46099 to steam_app_data.csv. Batch 280 time: 0:02:30 (avg: 0:02:36, remaining: 2:18:04)
# Exported lines 46100-46199 to steam_app_data.csv. Batch 281 time: 0:02:31 (avg: 0:02:36, remaining: 2:15:27)
# Exported lines 46200-46299 to steam_app_data.csv. Batch 282 time: 0:02:31 (avg: 0:02:36, remaining: 2:12:49)
# Exported lines 46300-46399 to steam_app_data.csv. Batch 283 time: 0:02:32 (avg: 0:02:36, remaining: 2:10:12)
# Exported lines 46400-46499 to steam_app_data.csv. Batch 284 time: 0:02:32 (avg: 0:02:36, remaining: 2:07:35)
# Exported lines 46500-46599 to steam_app_data.csv. Batch 285 time: 0:02:33 (avg: 0:02:36, remaining: 2:04:58)
# Exported lines 46600-46699 to steam_app_data.csv. Batch 286 time: 0:02:31 (avg: 0:02:36, remaining: 2:02:21)
# Exported lines 46700-46799 to steam_app_data.csv. Batch 287 time: 0:02:31 (avg: 0:02:36, remaining: 1:59:44)
# Exported lines 46800-46899 to steam_app_data.csv. Batch 288 time: 0:02:31 (avg: 0:02:36, remaining: 1:57:07)
# Exported lines 46900-46999 to steam_app_data.csv. Batch 289 time: 0:02:31 (avg: 0:02:36, remaining: 1:54:30)
# Exported lines 47000-47099 to steam_app_data.csv. Batch 290 time: 0:02:31 (avg: 0:02:36, remaining: 1:51:54)
# Exported lines 47100-47199 to steam_app_data.csv. Batch 291 time: 0:02:31 (avg: 0:02:36, remaining: 1:49:17)
# Exported lines 47200-47299 to steam_app_data.csv. Batch 292 time: 0:02:32 (avg: 0:02:36, remaining: 1:46:40)
# Exported lines 47300-47399 to steam_app_data.csv. Batch 293 time: 0:02:31 (avg: 0:02:36, remaining: 1:44:03)
# Exported lines 47400-47499 to steam_app_data.csv. Batch 294 time: 0:02:30 (avg: 0:02:36, remaining: 1:41:26)
# Exported lines 47500-47599 to steam_app_data.csv. Batch 295 time: 0:02:33 (avg: 0:02:36, remaining: 1:38:50)
# Exported lines 47600-47699 to steam_app_data.csv. Batch 296 time: 0:02:32 (avg: 0:02:36, remaining: 1:36:13)
# Exported lines 47700-47799 to steam_app_data.csv. Batch 297 time: 0:02:32 (avg: 0:02:36, remaining: 1:33:37)
# Exported lines 47800-47899 to steam_app_data.csv. Batch 298 time: 0:02:33 (avg: 0:02:36, remaining: 1:31:00)
# Exported lines 47900-47999 to steam_app_data.csv. Batch 299 time: 0:02:32 (avg: 0:02:36, remaining: 1:28:24)
# Exported lines 48000-48099 to steam_app_data.csv. Batch 300 time: 0:02:31 (avg: 0:02:36, remaining: 1:25:47)
# Exported lines 48100-48199 to steam_app_data.csv. Batch 301 time: 0:02:29 (avg: 0:02:36, remaining: 1:23:11)
# Exported lines 48200-48299 to steam_app_data.csv. Batch 302 time: 0:02:30 (avg: 0:02:36, remaining: 1:20:34)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 48300-48399 to steam_app_data.csv. Batch 303 time: 0:02:41 (avg: 0:02:36, remaining: 1:17:59)
# Exported lines 48400-48499 to steam_app_data.csv. Batch 304 time: 0:02:32 (avg: 0:02:36, remaining: 1:15:22)
# Exported lines 48500-48599 to steam_app_data.csv. Batch 305 time: 0:02:31 (avg: 0:02:36, remaining: 1:12:46)
# Exported lines 48600-48699 to steam_app_data.csv. Batch 306 time: 0:02:32 (avg: 0:02:36, remaining: 1:10:10)
# Exported lines 48700-48799 to steam_app_data.csv. Batch 307 time: 0:02:30 (avg: 0:02:36, remaining: 1:07:33)
# Exported lines 48800-48899 to steam_app_data.csv. Batch 308 time: 0:02:29 (avg: 0:02:36, remaining: 1:04:57)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 48900-48999 to steam_app_data.csv. Batch 309 time: 0:02:38 (avg: 0:02:36, remaining: 1:02:21)
# Exported lines 49000-49099 to steam_app_data.csv. Batch 310 time: 0:02:30 (avg: 0:02:36, remaining: 0:59:45)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 49100-49199 to steam_app_data.csv. Batch 311 time: 0:02:39 (avg: 0:02:36, remaining: 0:57:09)
# Exported lines 49200-49299 to steam_app_data.csv. Batch 312 time: 0:02:26 (avg: 0:02:36, remaining: 0:54:33)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 49300-49399 to steam_app_data.csv. Batch 313 time: 0:02:38 (avg: 0:02:36, remaining: 0:51:57)
# Exported lines 49400-49499 to steam_app_data.csv. Batch 314 time: 0:02:27 (avg: 0:02:36, remaining: 0:49:20)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 49500-49599 to steam_app_data.csv. Batch 315 time: 0:02:37 (avg: 0:02:36, remaining: 0:46:45)
# Exported lines 49600-49699 to steam_app_data.csv. Batch 316 time: 0:02:27 (avg: 0:02:36, remaining: 0:44:08)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 49700-49799 to steam_app_data.csv. Batch 317 time: 0:02:37 (avg: 0:02:36, remaining: 0:41:33)
# Exported lines 49800-49899 to steam_app_data.csv. Batch 318 time: 0:02:28 (avg: 0:02:36, remaining: 0:38:57)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 49900-49999 to steam_app_data.csv. Batch 319 time: 0:02:37 (avg: 0:02:36, remaining: 0:36:21)
# Exported lines 50000-50099 to steam_app_data.csv. Batch 320 time: 0:02:27 (avg: 0:02:36, remaining: 0:33:45)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 50100-50199 to steam_app_data.csv. Batch 321 time: 0:02:37 (avg: 0:02:36, remaining: 0:31:09)
# Exported lines 50200-50299 to steam_app_data.csv. Batch 322 time: 0:02:26 (avg: 0:02:36, remaining: 0:28:33)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 50300-50399 to steam_app_data.csv. Batch 323 time: 0:02:36 (avg: 0:02:36, remaining: 0:25:57)
# Exported lines 50400-50499 to steam_app_data.csv. Batch 324 time: 0:02:26 (avg: 0:02:36, remaining: 0:23:21)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 50500-50599 to steam_app_data.csv. Batch 325 time: 0:02:36 (avg: 0:02:36, remaining: 0:20:46)
# Exported lines 50600-50699 to steam_app_data.csv. Batch 326 time: 0:02:26 (avg: 0:02:36, remaining: 0:18:10)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 50700-50799 to steam_app_data.csv. Batch 327 time: 0:02:36 (avg: 0:02:36, remaining: 0:15:34)
# Exported lines 50800-50899 to steam_app_data.csv. Batch 328 time: 0:02:26 (avg: 0:02:36, remaining: 0:12:58)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 50900-50999 to steam_app_data.csv. Batch 329 time: 0:02:38 (avg: 0:02:36, remaining: 0:10:23)
# Exported lines 51000-51099 to steam_app_data.csv. Batch 330 time: 0:02:27 (avg: 0:02:36, remaining: 0:07:47)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 51100-51199 to steam_app_data.csv. Batch 331 time: 0:02:38 (avg: 0:02:36, remaining: 0:05:11)
# Exported lines 51200-51299 to steam_app_data.csv. Batch 332 time: 0:02:26 (avg: 0:02:36, remaining: 0:02:36)
# No response, waiting 10 seconds...
# Retrying.
# Exported lines 51300-51353 to steam_app_data.csv. Batch 333 time: 0:01:28 (avg: 0:02:35, remaining: 0:00:00)
#
# Processing batches complete. 33353 apps written

# %%
# inspect downloaded data
pd.read_csv('../data/download/steam_app_data.csv').info()
# Out:
# G:\WPy64-3870\python-3.8.7.amd64\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51353 entries, 0 to 51352
# Data columns (total 39 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   type                     51199 non-null  object
#  1   name                     51343 non-null  object
#  2   steam_appid              51353 non-null  int64
#  3   required_age             51199 non-null  object
#  4   is_free                  51199 non-null  object
#  5   controller_support       10647 non-null  object
#  6   dlc                      8615 non-null   object
#  7   detailed_description     51157 non-null  object
#  8   about_the_game           51156 non-null  object
#  9   short_description        51160 non-null  object
#  10  fullgame                 0 non-null      float64
#  11  supported_languages      51165 non-null  object
#  12  header_image             51199 non-null  object
#  13  website                  29258 non-null  object
#  14  pc_requirements          51199 non-null  object
#  15  mac_requirements         51199 non-null  object
#  16  linux_requirements       51199 non-null  object
#  17  legal_notice             16244 non-null  object
#  18  drm_notice               253 non-null    object
#  19  ext_user_account_notice  902 non-null    object
#  20  developers               51066 non-null  object
#  21  publishers               51199 non-null  object
#  22  demos                    4189 non-null   object
#  23  price_overview           43646 non-null  object
#  24  packages                 44224 non-null  object
#  25  package_groups           51199 non-null  object
#  26  platforms                51199 non-null  object
#  27  metacritic               3726 non-null   object
#  28  reviews                  8414 non-null   object
#  29  categories               50238 non-null  object
#  30  genres                   51106 non-null  object
#  31  screenshots              51119 non-null  object
#  32  movies                   48812 non-null  object
#  33  recommendations          11381 non-null  object
#  34  achievements             28398 non-null  object
#  35  release_date             51199 non-null  object
#  36  support_info             51199 non-null  object
#  37  background               51125 non-null  object
#  38  content_descriptors      51199 non-null  object
# dtypes: float64(1), int64(1), object(37)
# memory usage: 15.3+ MB

# %%
# inspect downloaded steamspy data
pd.read_csv('../data/download/steamspy_data.csv').head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-a61f4b2f0542> in <module>
#       1 # inspect downloaded steamspy data
# ----> 2 pd.read_csv('../data/download/steamspy_data.csv').head()
#
# G:\WPy64-3870\python-3.8.7.amd64\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# G:\WPy64-3870\python-3.8.7.amd64\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# G:\WPy64-3870\python-3.8.7.amd64\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# G:\WPy64-3870\python-3.8.7.amd64\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# G:\WPy64-3870\python-3.8.7.amd64\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/download/steamspy_data.csv'

# %% [markdown]
# ## Next Steps
#
# Here we have defined and demonstrated the download process used to generate the data sets. This was completed separately but the full, raw data can be found [on Kaggle](https://kaggle.com/nikdavis/steam-store-raw).
#
# We now have two tables of data with a variety of information about apps on the Steam store. From the Steam data it looks like there are some useful columns like `required_age`, `developers` and `genres` which we can eventually turn into features for analysis, and a `price_overview` column which may inform the success and sales of each game. The `owners` column of the SteamSpy data could be useful, however the [margin of error](https://steamspy.com/about) means data may not be accurate enough for meaningful analysis, we'll have to see what we can manage after cleaning. Instead we may have to use the `positive` and `negative` ratings or average play-time to create our metrics. There is also a `tags` column which appears to crossover with the `categories` and `genres` columns in the Steam data. We may wish to merge these, or keep one over the other.
#
# These are all decisions we'll come to in later stages of the project. With the data downloaded, this stage is now complete. In the next step, we'll take care of preparing and cleaning the data, readying a complete data set to use for analysis.
